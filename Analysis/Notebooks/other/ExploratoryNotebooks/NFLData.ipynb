# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np

# %%
import nfl_data_py as nfl

# %%
ftn = nfl.import_ftn_data(years=[2022], columns=None, downcast=True, thread_requests=False)
# Out:
# Downcasting floats.

# %%
ftn.head()
# Out:
#    ftn_game_id nflverse_game_id  season  week  ftn_play_id  nflverse_play_id  \
# 0         6015  2022_10_ATL_CAR    2022    10       985889                74
# 1         6015  2022_10_ATL_CAR    2022    10       985890                95
# 2         6015  2022_10_ATL_CAR    2022    10       985891               128
# 3         6015  2022_10_ATL_CAR    2022    10       985892               157
# 4         6015  2022_10_ATL_CAR    2022    10       985893               178
#
#   starting_hash qb_location  n_offense_backfield  n_defense_box  ...  \
# 0             L           P                    1              7  ...
# 1             R           P                    1              7  ...
# 2             R           S                    1              6  ...
# 3             R           P                    2              8  ...
# 4             L           U                    1              7  ...
#
#    read_thrown  is_catchable_ball  is_contested_ball  is_created_reception  \
# 0         None              False              False                 False
# 1            1              False              False                 False
# 2            1               True               True                 False
# 3         None              False              False                 False
# 4         None              False              False                 False
#
#    is_drop  is_qb_sneak  n_blitzers  n_pass_rushers  is_qb_fault_sack  \
# 0    False        False           0               0             False
# 1    False        False           0               4             False
# 2    False        False           1               5             False
# 3    False        False           0               0             False
# 4    False        False           0               0             False
#
#                  date_pulled
# 0 2023-09-16 00:39:45.386755
# 1 2023-09-16 00:39:45.386755
# 2 2023-09-16 00:39:45.386755
# 3 2023-09-16 00:39:45.386755
# 4 2023-09-16 00:39:45.386755
#
# [5 rows x 29 columns]

# %%
ngs = nfl.import_ngs_data(stat_type="passing", years=[2022])

# %%
ngs.head()
# Out:
#       season season_type  week player_display_name player_position team_abbr  \
# 3491    2022         REG     0           Matt Ryan              QB       IND
# 3492    2022         REG     0        Daniel Jones              QB       NYG
# 3493    2022         REG     0    Matthew Stafford              QB       LAR
# 3494    2022         REG     0         Davis Mills              QB       HOU
# 3495    2022         REG     0      Baker Mayfield              QB       LAR
#
#       avg_time_to_throw  avg_completed_air_yards  avg_intended_air_yards  \
# 3491           2.686250                 5.222039                6.384533
# 3492           2.899330                 4.852397                6.333183
# 3493           2.715713                 4.643252                6.687331
# 3494           2.782921                 5.354966                7.876293
# 3495           2.818392                 4.961095                6.763447
#
#       avg_air_yards_differential  ...  completion_percentage  \
# 3491                   -1.162494  ...              67.028200
# 3492                   -1.480785  ...              67.161017
# 3493                   -2.044079  ...              67.986799
# 3494                   -2.521327  ...              60.960334
# 3495                   -1.802353  ...              60.000000
#
#       expected_completion_percentage  completion_percentage_above_expectation  \
# 3491                       65.281175                                 1.747024
# 3492                       65.229089                                 1.931928
# 3493                       68.364111                                -0.377312
# 3494                       63.639179                                -2.678845
# 3495                       67.047820                                -7.047820
#
#       avg_air_distance  max_air_distance  player_gsis_id  player_first_name  \
# 3491         18.853119         51.879789      00-0026143            Matthew
# 3492         18.486036         56.150356      00-0035710             Daniel
# 3493         20.696094         58.661276      00-0026498               John
# 3494         21.610351         69.050521      00-0036898              Davis
# 3495         20.841823         56.811447      00-0034855              Baker
#
#       player_last_name  player_jersey_number  player_short_name
# 3491              Ryan                     2             M.Ryan
# 3492             Jones                     8            D.Jones
# 3493          Stafford                     9         M.Stafford
# 3494             Mills                    10            D.Mills
# 3495          Mayfield                    17         B.Mayfield
#
# [5 rows x 29 columns]

# %%
df = nfl.import_seasonal_pfr(s_type="rush", years=[2022])

# %%
df.head()
# Out:
#       season          player    pfr_id   tm   age pos     g    gs    att  \
# 1418    2022   Derrick Henry  HenrDe00  TEN  28.0  RB  16.0  16.0  349.0
# 1419    2022     Josh Jacobs  JacoJo01   LV  24.0  RB  17.0  17.0  340.0
# 1420    2022      Nick Chubb  ChubNi00  CLE  27.0  RB  17.0  17.0  302.0
# 1421    2022  Saquon Barkley  BarkSa00  NYG  25.0  RB  16.0  16.0  295.0
# 1422    2022    Najee Harris  HarrNa00  PIT  24.0  RB  17.0  17.0  272.0
#
#          yds    td   x1d    ybc  ybc_att    yac  yac_att  brk_tkl  att_br  \
# 1418  1538.0  13.0  65.0  739.0      2.1  799.0      2.3     35.0    10.0
# 1419  1653.0  12.0  93.0  832.0      2.4  821.0      2.4     31.0    11.0
# 1420  1525.0  12.0  69.0  830.0      2.7  695.0      2.3     28.0    10.8
# 1421  1312.0  10.0  62.0  749.0      2.5  563.0      1.9     12.0    24.6
# 1422  1034.0   7.0  45.0  577.0      2.1  457.0      1.7     21.0    13.0
#
#          loaded
# 1418 2023-08-28
# 1419 2023-08-28
# 1420 2023-08-28
# 1421 2023-08-28
# 1422 2023-08-28

# %%
qbr = nfl.import_qbr(years=[2022])

# %%
qbr.head()
# Out:
#       season season_type     game_week team_abb  player_id     name_short  \
# 1202    2022     Regular  Season Total       KC    3139477     P. Mahomes
# 1203    2022     Regular  Season Total      BUF    3918298       J. Allen
# 1204    2022     Regular  Season Total      MIA    4241479  T. Tagovailoa
# 1205    2022     Regular  Season Total      PHI    4040715       J. Hurts
# 1206    2022     Regular  Season Total      DET    3046779        J. Goff
#
#       rank  qbr_total  pts_added  qb_plays  ...  exp_sack  penalty  qbr_raw  \
# 1202   1.0       79.0       71.4       763  ...         0      1.5     79.0
# 1203   2.0       73.4       60.0       746  ...         0      2.2     75.7
# 1204   3.0       70.6       27.5       456  ...         0      2.8     70.1
# 1205   4.0       68.3       42.8       683  ...         0      2.3     70.8
# 1206   5.0       63.3       28.8       668  ...         0      3.2     64.8
#
#       sack  name_first   name_last     name_display  \
# 1202 -10.7     Patrick     Mahomes  Patrick Mahomes
# 1203 -12.1        Josh       Allen       Josh Allen
# 1204  -8.9         Tua  Tagovailoa   Tua Tagovailoa
# 1205 -13.9       Jalen       Hurts      Jalen Hurts
# 1206  -9.9       Jared        Goff       Jared Goff
#
#                                           headshot_href      team qualified
# 1202  https://a.espncdn.com/i/headshots/nfl/players/...    Chiefs      True
# 1203  https://a.espncdn.com/i/headshots/nfl/players/...     Bills      True
# 1204  https://a.espncdn.com/i/headshots/nfl/players/...  Dolphins      True
# 1205  https://a.espncdn.com/i/headshots/nfl/players/...    Eagles      True
# 1206  https://a.espncdn.com/i/headshots/nfl/players/...     Lions      True
#
# [5 rows x 23 columns]

# %% [markdown]
# # Data

# %% [markdown]
# Some explantions for stats:
#
# **WOPR** is a weighted combination of the share of team targets a player receives and the share of team air yards. The formula is: WOPR = 1.5 × Target Market Share + 0.7 × Air Yards Market Share. Elite wide receivers are seen having 0.70+ WOPRs.
#
# **Expected Points Added (EPA)** is a commonly used advanced statistic in football. In short, this stat measures how well a team performs compared to their expectation on a play-by-play basis. EPA and EPA per Play, along with other stats using EPA, can help us evaluate team and player performance.
#
# **Passing Air Conversion Ratio (PACR)** measures the rate at which air yards are converted to passing yards. The formula is PACR = (passing yards)/(air yards).
#
# **Receiver Air Conversion Ratio (RACR)** measures the rate at which targeted air yards are converted to receiving yards. The formula is RACR = (receiving yards)/(air yards).
#
# **Completion Percentage Over Expectation (CPOE)**: (Completion percentage) - (expected completion percentage) for passers.
#
# **dakota** is the adjusted EPA + CPOE composite based on coefficients which best predict adjusted EPA/play in the following year.

# %%
years = [2023]

# %% [markdown]
# ## Play-By-Play

# %% [markdown]
# Returns play-by-play data for the years and columns specified
#
# years : required, list of years to pull data for (earliest available is 1999)
#
# columns : optional, list of columns to pull data for
#
# downcast : optional, converts float64 columns to float32, reducing memory usage by ~30%. Will slow down initial load speed ~50%
#
# cache : optional, determines whether to pull pbp data from github repo or local cache generated by nfl.cache_pbp()
#
# alt_path : optional, required if nfl.cache_pbp() is called using an alternate path to the default cache

# %%
columns = None
df_play = nfl.import_pbp_data(years, columns, downcast=True, cache=False, alt_path=None)
# Out:
# 2023 done.
# Downcasting floats.

# %%
df_play.head(1)
# Out:
#    play_id          game_id old_game_id home_team away_team season_type  week  \
# 0      1.0  2023_01_ARI_WAS  2023091007       WAS       ARI         REG     1
#
#   posteam posteam_type defteam  ... offense_formation  offense_personnel  \
# 0    None         None    None  ...              None               None
#
#   defenders_in_box  defense_personnel  number_of_pass_rushers  \
# 0              NaN               None                     NaN
#
#    players_on_play offense_players  defense_players  n_offense  n_defense
# 0                                                            0          0
#
# [1 rows x 384 columns]

# %%
play = df_play.iloc[1]
for i in range(0, len(play), 10):
    print(play[i: i + 10])
    print()
# Out:
# play_id                    39.0
# game_id         2023_01_ARI_WAS
# old_game_id          2023091007
# home_team                   WAS
# away_team                   ARI
# season_type                 REG
# week                          1
# posteam                     WAS
# posteam_type               home
# defteam                     ARI
# Name: 1, dtype: object
#
# side_of_field                       ARI
# yardline_100                       35.0
# game_date                    2023-09-10
# quarter_seconds_remaining         900.0
# half_seconds_remaining           1800.0
# game_seconds_remaining           3600.0
# game_half                         Half1
# quarter_end                         0.0
# drive                               1.0
# sp                                  0.0
# Name: 1, dtype: object
#
# qtr                                                           1.0
# down                                                          NaN
# goal_to_go                                                    0.0
# time                                                        15:00
# yrdln                                                      ARI 35
# ydstogo                                                       0.0
# ydsnet                                                       26.0
# desc            5-M.Prater kicks 65 yards from ARI 35 to end z...
# play_type                                                 kickoff
# yards_gained                                                  0.0
# Name: 1, dtype: object
#
# shotgun               0.0
# no_huddle             0.0
# qb_dropback           0.0
# qb_kneel              0.0
# qb_spike              0.0
# qb_scramble           0.0
# pass_length          None
# pass_location        None
# air_yards             NaN
# yards_after_catch     NaN
# Name: 1, dtype: object
#
# run_location               None
# run_gap                    None
# field_goal_result          None
# kick_distance              65.0
# extra_point_result         None
# two_point_conv_result      None
# home_timeouts_remaining     3.0
# away_timeouts_remaining     3.0
# timeout                     0.0
# timeout_team               None
# Name: 1, dtype: object
#
# td_team                       None
# td_player_name                None
# td_player_id                  None
# posteam_timeouts_remaining     3.0
# defteam_timeouts_remaining     3.0
# total_home_score               0.0
# total_away_score               0.0
# posteam_score                  0.0
# defteam_score                  0.0
# score_differential             0.0
# Name: 1, dtype: object
#
# posteam_score_post              0.0
# defteam_score_post              0.0
# score_differential_post         0.0
# no_score_prob              0.004661
# opp_fg_prob                0.144037
# opp_safety_prob            0.002072
# opp_td_prob                0.226051
# fg_prob                    0.212601
# safety_prob                0.003828
# td_prob                     0.40675
# Name: 1, dtype: object
#
# extra_point_prob                  0.0
# two_point_conversion_prob         0.0
# ep                           1.474098
# epa                               0.0
# total_home_epa                    0.0
# total_away_epa                    0.0
# total_home_rush_epa               0.0
# total_away_rush_epa               0.0
# total_home_pass_epa               0.0
# total_away_pass_epa               0.0
# Name: 1, dtype: object
#
# air_epa                    NaN
# yac_epa                    NaN
# comp_air_epa               0.0
# comp_yac_epa               0.0
# total_home_comp_air_epa    0.0
# total_away_comp_air_epa    0.0
# total_home_comp_yac_epa    0.0
# total_away_comp_yac_epa    0.0
# total_home_raw_air_epa     0.0
# total_away_raw_air_epa     0.0
# Name: 1, dtype: object
#
# total_home_raw_yac_epa         0.0
# total_away_raw_yac_epa         0.0
# wp                        0.546262
# def_wp                    0.453738
# home_wp                   0.546262
# away_wp                   0.453738
# wpa                            0.0
# vegas_wpa                      0.0
# vegas_home_wpa                 0.0
# home_wp_post              0.546262
# Name: 1, dtype: object
#
# away_wp_post           0.453738
# vegas_wp               0.737399
# vegas_home_wp          0.737399
# total_home_rush_wpa         0.0
# total_away_rush_wpa         0.0
# total_home_pass_wpa         0.0
# total_away_pass_wpa         0.0
# air_wpa                     NaN
# yac_wpa                     NaN
# comp_air_wpa                0.0
# Name: 1, dtype: object
#
# comp_yac_wpa               0.0
# total_home_comp_air_wpa    0.0
# total_away_comp_air_wpa    0.0
# total_home_comp_yac_wpa    0.0
# total_away_comp_yac_wpa    0.0
# total_home_raw_air_wpa     0.0
# total_away_raw_air_wpa     0.0
# total_home_raw_yac_wpa     0.0
# total_away_raw_yac_wpa     0.0
# punt_blocked               0.0
# Name: 1, dtype: object
#
# first_down_rush          0.0
# first_down_pass          0.0
# first_down_penalty       0.0
# third_down_converted     0.0
# third_down_failed        0.0
# fourth_down_converted    0.0
# fourth_down_failed       0.0
# incomplete_pass          0.0
# touchback                1.0
# interception             0.0
# Name: 1, dtype: object
#
# punt_inside_twenty       0.0
# punt_in_endzone          0.0
# punt_out_of_bounds       0.0
# punt_downed              0.0
# punt_fair_catch          0.0
# kickoff_inside_twenty    0.0
# kickoff_in_endzone       0.0
# kickoff_out_of_bounds    0.0
# kickoff_downed           0.0
# kickoff_fair_catch       0.0
# Name: 1, dtype: object
#
# fumble_forced              0.0
# fumble_not_forced          0.0
# fumble_out_of_bounds       0.0
# solo_tackle                0.0
# safety                     0.0
# penalty                    0.0
# tackled_for_loss           0.0
# fumble_lost                0.0
# own_kickoff_recovery       0.0
# own_kickoff_recovery_td    0.0
# Name: 1, dtype: object
#
# qb_hit                 0.0
# rush_attempt           0.0
# pass_attempt           0.0
# sack                   0.0
# touchdown              0.0
# pass_touchdown         0.0
# rush_touchdown         0.0
# return_touchdown       0.0
# extra_point_attempt    0.0
# two_point_attempt      0.0
# Name: 1, dtype: object
#
# field_goal_attempt    0.0
# kickoff_attempt       1.0
# punt_attempt          0.0
# fumble                0.0
# complete_pass         0.0
# assist_tackle         0.0
# lateral_reception     0.0
# lateral_rush          0.0
# lateral_return        0.0
# lateral_recovery      0.0
# Name: 1, dtype: object
#
# passer_player_id              None
# passer_player_name            None
# passing_yards                  NaN
# receiver_player_id            None
# receiver_player_name          None
# receiving_yards                NaN
# rusher_player_id              None
# rusher_player_name            None
# rushing_yards                  NaN
# lateral_receiver_player_id    None
# Name: 1, dtype: object
#
# lateral_receiver_player_name      None
# lateral_receiving_yards            NaN
# lateral_rusher_player_id          None
# lateral_rusher_player_name        None
# lateral_rushing_yards              NaN
# lateral_sack_player_id            None
# lateral_sack_player_name          None
# interception_player_id            None
# interception_player_name          None
# lateral_interception_player_id    None
# Name: 1, dtype: object
#
# lateral_interception_player_name        None
# punt_returner_player_id                 None
# punt_returner_player_name               None
# lateral_punt_returner_player_id         None
# lateral_punt_returner_player_name       None
# kickoff_returner_player_name            None
# kickoff_returner_player_id              None
# lateral_kickoff_returner_player_id      None
# lateral_kickoff_returner_player_name    None
# punter_player_id                        None
# Name: 1, dtype: object
#
# punter_player_name                        None
# kicker_player_name                    M.Prater
# kicker_player_id                    00-0023853
# own_kickoff_recovery_player_id            None
# own_kickoff_recovery_player_name          None
# blocked_player_id                         None
# blocked_player_name                       None
# tackle_for_loss_1_player_id               None
# tackle_for_loss_1_player_name             None
# tackle_for_loss_2_player_id               None
# Name: 1, dtype: object
#
# tackle_for_loss_2_player_name         None
# qb_hit_1_player_id                    None
# qb_hit_1_player_name                  None
# qb_hit_2_player_id                    None
# qb_hit_2_player_name                  None
# forced_fumble_player_1_team           None
# forced_fumble_player_1_player_id      None
# forced_fumble_player_1_player_name    None
# forced_fumble_player_2_team           None
# forced_fumble_player_2_player_id      None
# Name: 1, dtype: object
#
# forced_fumble_player_2_player_name    None
# solo_tackle_1_team                    None
# solo_tackle_2_team                    None
# solo_tackle_1_player_id               None
# solo_tackle_2_player_id               None
# solo_tackle_1_player_name             None
# solo_tackle_2_player_name             None
# assist_tackle_1_player_id             None
# assist_tackle_1_player_name           None
# assist_tackle_1_team                  None
# Name: 1, dtype: object
#
# assist_tackle_2_player_id      None
# assist_tackle_2_player_name    None
# assist_tackle_2_team           None
# assist_tackle_3_player_id      None
# assist_tackle_3_player_name    None
# assist_tackle_3_team           None
# assist_tackle_4_player_id      None
# assist_tackle_4_player_name    None
# assist_tackle_4_team           None
# tackle_with_assist              0.0
# Name: 1, dtype: object
#
# tackle_with_assist_1_player_id      None
# tackle_with_assist_1_player_name    None
# tackle_with_assist_1_team           None
# tackle_with_assist_2_player_id      None
# tackle_with_assist_2_player_name    None
# tackle_with_assist_2_team           None
# pass_defense_1_player_id            None
# pass_defense_1_player_name          None
# pass_defense_2_player_id            None
# pass_defense_2_player_name          None
# Name: 1, dtype: object
#
# fumbled_1_team                   None
# fumbled_1_player_id              None
# fumbled_1_player_name            None
# fumbled_2_player_id              None
# fumbled_2_player_name            None
# fumbled_2_team                   None
# fumble_recovery_1_team           None
# fumble_recovery_1_yards           NaN
# fumble_recovery_1_player_id      None
# fumble_recovery_1_player_name    None
# Name: 1, dtype: object
#
# fumble_recovery_2_team           None
# fumble_recovery_2_yards           NaN
# fumble_recovery_2_player_id      None
# fumble_recovery_2_player_name    None
# sack_player_id                   None
# sack_player_name                 None
# half_sack_1_player_id            None
# half_sack_1_player_name          None
# half_sack_2_player_id            None
# half_sack_2_player_name          None
# Name: 1, dtype: object
#
# return_team                     WAS
# return_yards                    0.0
# penalty_team                   None
# penalty_player_id              None
# penalty_player_name            None
# penalty_yards                   NaN
# replay_or_challenge             0.0
# replay_or_challenge_result     None
# penalty_type                   None
# defensive_two_point_attempt     0.0
# Name: 1, dtype: object
#
# defensive_two_point_conv          0.0
# defensive_extra_point_attempt     0.0
# defensive_extra_point_conv        0.0
# safety_player_name               None
# safety_player_id                 None
# season                           2023
# cp                                NaN
# cpoe                              NaN
# series                            1.0
# series_success                    1.0
# Name: 1, dtype: object
#
# series_result                                           First down
# order_sequence                                                39.0
# start_time                                       9/10/23, 13:02:43
# time_of_day                               2023-09-10T17:02:43.600Z
# stadium                                                 FedExField
# weather           Cloudy Temp: 76° F, Humidity: 84%, Wind: S 2 mph
# nfl_api_id                    b07c705e-f053-11ed-b4a7-bab79e4492fa
# play_clock                                                       0
# play_deleted                                                   0.0
# play_type_nfl                                             KICK_OFF
# Name: 1, dtype: object
#
# special_teams_play                               1.0
# st_play_type                                    None
# end_clock_time              2023-09-10T17:02:47.537Z
# end_yard_line                                   None
# fixed_drive                                      1.0
# fixed_drive_result                              Punt
# drive_real_start_time       2023-09-10T17:02:43.600Z
# drive_play_count                                 8.0
# drive_time_of_possession                        4:01
# drive_first_downs                                2.0
# Name: 1, dtype: object
#
# drive_inside20                0.0
# drive_ended_with_score        0.0
# drive_quarter_start           1.0
# drive_quarter_end             1.0
# drive_yards_penalized         0.0
# drive_start_transition    KICKOFF
# drive_end_transition         PUNT
# drive_game_clock_start      15:00
# drive_game_clock_end        10:59
# drive_start_yard_line      WAS 25
# Name: 1, dtype: object
#
# drive_end_yard_line      ARI 49
# drive_play_id_started      39.0
# drive_play_id_ended       245.0
# away_score                   16
# home_score                   20
# location                   Home
# result                        4
# total                        36
# spread_line                 7.0
# total_line                 38.0
# Name: 1, dtype: object
#
# div_game                      0
# roof                   outdoors
# surface
# temp                        NaN
# wind                        NaN
# home_coach           Ron Rivera
# away_coach      Jonathan Gannon
# stadium_id                WAS00
# game_stadium         FedExField
# aborted_play                0.0
# Name: 1, dtype: object
#
# success                    0.0
# passer                    None
# passer_jersey_number       NaN
# rusher                    None
# rusher_jersey_number       NaN
# receiver                  None
# receiver_jersey_number     NaN
# pass                       0.0
# rush                       0.0
# first_down                 0.0
# Name: 1, dtype: object
#
# special                 1.0
# play                    0.0
# passer_id              None
# rusher_id              None
# receiver_id            None
# name                   None
# jersey_number           NaN
# id                     None
# fantasy_player_name    None
# fantasy_player_id      None
# Name: 1, dtype: object
#
# fantasy                 None
# fantasy_id              None
# out_of_bounds            0.0
# home_opening_kickoff     1.0
# qb_epa                   0.0
# xyac_epa                 NaN
# xyac_mean_yardage        NaN
# xyac_median_yardage      NaN
# xyac_success             NaN
# xyac_fd                  NaN
# Name: 1, dtype: object
#
# xpass                                                                   NaN
# pass_oe                                                                 NaN
# nflverse_game_id                                            2023_01_ARI_WAS
# possession_team                                                         ARI
# offense_formation                                                      None
# offense_personnel                                                      None
# defenders_in_box                                                        NaN
# defense_personnel                                                      None
# number_of_pass_rushers                                                  NaN
# players_on_play           48000;52641;54721;56098;53639;53448;55912;4510...
# Name: 1, dtype: object
#
# offense_players    00-0035150;00-0037330;00-0036896;00-0033251;00...
# defense_players    00-0036403;00-0038635;00-0036614;00-0039149;00...
# n_offense                                                         11
# n_defense                                                         11
# Name: 1, dtype: object

# %% [markdown]
# # Who Throws Deep?

# %% [markdown]
# Finding average depth of target (adot) for quarterbacks.

# %% [markdown]
# Grab only the pass plays. Note, in pandas, you should use the `&` operator for element-wise logical AND operations.

# %%
df_pass_plays = df_play[(df_play["play_type"] == "pass") & (df_play["air_yards"].notna())]

# %% [markdown]
# Group by 'passer_id' and 'passer', then aggregate air yards by count and mean.

# %%
grouped = df_pass_plays.groupby(['passer_id', 'passer']).agg({"air_yards": ["count", "mean"]})

# %% [markdown]
# Creating a refined data frame where we only keep players who have attempted over 100 passes. We sort, descending, by adot.

# %%
grouped.columns = list(map("_".join, grouped.columns.values))
sort_crit = "air_yards_count > 100"
print(grouped.query(sort_crit).sort_values(by="air_yards_mean", ascending=[False]).to_string())
# Out:
#                                 air_yards_count  air_yards_mean
# passer_id  passer
# 00-0039152 W.Levis                          150       10.193334
# 00-0029701 R.Tannehill                      157        9.375796
# 00-0033537 D.Watson                         170        9.370588
# 00-0035228 K.Murray                         107        9.308412
# 00-0039163 C.Stroud                         385        9.241558
# 00-0036264 J.Love                           370        8.967567
# 00-0036389 J.Hurts                          358        8.575419
# 00-0034855 B.Mayfield                       380        8.497369
# 00-0034857 J.Allen                          432        8.284722
# 00-0033077 D.Prescott                       370        8.270270
# 00-0031280 D.Carr                           372        8.223118
# 00-0033275 P.Walker                         110        8.200000
# 00-0031345 J.Garoppolo                      167        8.119761
# 00-0037834 B.Purdy                          303        8.108911
# 00-0034796 L.Jackson                        333        8.108109
# 00-0038122 D.Ridder                         266        8.037594
# 00-0033949 J.Dobbs                          362        8.002763
# 00-0026498 M.Stafford                       339        7.988201
# 00-0036945 J.Fields                         185        7.962162
# 00-0036355 J.Herbert                        402        7.746269
# 00-0037077 S.Howell                         486        7.576132
# 00-0037013 Z.Wilson                         318        7.562893
# 00-0036212 T.Tagovailoa                     375        7.429333
# 00-0030565 G.Smith                          358        7.377095
# 00-0038579 A.O'Connell                      178        7.376404
# 00-0029604 K.Cousins                        309        7.284790
# 00-0036971 T.Lawrence                       370        7.275676
# 00-0038476 T.DeVito                         105        7.219048
# 00-0038102 K.Pickett                        313        7.162939
# 00-0036972 M.Jones                          345        6.985507
# 00-0035289 G.Minshew II                     297        6.915825
# 00-0035710 D.Jones                          160        6.850000
# 00-0033873 P.Mahomes                        409        6.801956
# 00-0033106 J.Goff                           404        6.754951
# 00-0029263 R.Wilson                         316        6.743671
# 00-0039150 B.Young                          350        6.491428
# 00-0036442 J.Burrow                         363        6.465565
# 00-0038583 D.Thompson-Robinson              107        6.271028
# 00-0038416 T.Bagent                         143        5.692307

# %% [markdown]
# ## ADOT For Receivers

# %%
list(df_pass_plays.columns)
# Out:
# ['play_id',
#  'game_id',
#  'old_game_id',
#  'home_team',
#  'away_team',
#  'season_type',
#  'week',
#  'posteam',
#  'posteam_type',
#  'defteam',
#  'side_of_field',
#  'yardline_100',
#  'game_date',
#  'quarter_seconds_remaining',
#  'half_seconds_remaining',
#  'game_seconds_remaining',
#  'game_half',
#  'quarter_end',
#  'drive',
#  'sp',
#  'qtr',
#  'down',
#  'goal_to_go',
#  'time',
#  'yrdln',
#  'ydstogo',
#  'ydsnet',
#  'desc',
#  'play_type',
#  'yards_gained',
#  'shotgun',
#  'no_huddle',
#  'qb_dropback',
#  'qb_kneel',
#  'qb_spike',
#  'qb_scramble',
#  'pass_length',
#  'pass_location',
#  'air_yards',
#  'yards_after_catch',
#  'run_location',
#  'run_gap',
#  'field_goal_result',
#  'kick_distance',
#  'extra_point_result',
#  'two_point_conv_result',
#  'home_timeouts_remaining',
#  'away_timeouts_remaining',
#  'timeout',
#  'timeout_team',
#  'td_team',
#  'td_player_name',
#  'td_player_id',
#  'posteam_timeouts_remaining',
#  'defteam_timeouts_remaining',
#  'total_home_score',
#  'total_away_score',
#  'posteam_score',
#  'defteam_score',
#  'score_differential',
#  'posteam_score_post',
#  'defteam_score_post',
#  'score_differential_post',
#  'no_score_prob',
#  'opp_fg_prob',
#  'opp_safety_prob',
#  'opp_td_prob',
#  'fg_prob',
#  'safety_prob',
#  'td_prob',
#  'extra_point_prob',
#  'two_point_conversion_prob',
#  'ep',
#  'epa',
#  'total_home_epa',
#  'total_away_epa',
#  'total_home_rush_epa',
#  'total_away_rush_epa',
#  'total_home_pass_epa',
#  'total_away_pass_epa',
#  'air_epa',
#  'yac_epa',
#  'comp_air_epa',
#  'comp_yac_epa',
#  'total_home_comp_air_epa',
#  'total_away_comp_air_epa',
#  'total_home_comp_yac_epa',
#  'total_away_comp_yac_epa',
#  'total_home_raw_air_epa',
#  'total_away_raw_air_epa',
#  'total_home_raw_yac_epa',
#  'total_away_raw_yac_epa',
#  'wp',
#  'def_wp',
#  'home_wp',
#  'away_wp',
#  'wpa',
#  'vegas_wpa',
#  'vegas_home_wpa',
#  'home_wp_post',
#  'away_wp_post',
#  'vegas_wp',
#  'vegas_home_wp',
#  'total_home_rush_wpa',
#  'total_away_rush_wpa',
#  'total_home_pass_wpa',
#  'total_away_pass_wpa',
#  'air_wpa',
#  'yac_wpa',
#  'comp_air_wpa',
#  'comp_yac_wpa',
#  'total_home_comp_air_wpa',
#  'total_away_comp_air_wpa',
#  'total_home_comp_yac_wpa',
#  'total_away_comp_yac_wpa',
#  'total_home_raw_air_wpa',
#  'total_away_raw_air_wpa',
#  'total_home_raw_yac_wpa',
#  'total_away_raw_yac_wpa',
#  'punt_blocked',
#  'first_down_rush',
#  'first_down_pass',
#  'first_down_penalty',
#  'third_down_converted',
#  'third_down_failed',
#  'fourth_down_converted',
#  'fourth_down_failed',
#  'incomplete_pass',
#  'touchback',
#  'interception',
#  'punt_inside_twenty',
#  'punt_in_endzone',
#  'punt_out_of_bounds',
#  'punt_downed',
#  'punt_fair_catch',
#  'kickoff_inside_twenty',
#  'kickoff_in_endzone',
#  'kickoff_out_of_bounds',
#  'kickoff_downed',
#  'kickoff_fair_catch',
#  'fumble_forced',
#  'fumble_not_forced',
#  'fumble_out_of_bounds',
#  'solo_tackle',
#  'safety',
#  'penalty',
#  'tackled_for_loss',
#  'fumble_lost',
#  'own_kickoff_recovery',
#  'own_kickoff_recovery_td',
#  'qb_hit',
#  'rush_attempt',
#  'pass_attempt',
#  'sack',
#  'touchdown',
#  'pass_touchdown',
#  'rush_touchdown',
#  'return_touchdown',
#  'extra_point_attempt',
#  'two_point_attempt',
#  'field_goal_attempt',
#  'kickoff_attempt',
#  'punt_attempt',
#  'fumble',
#  'complete_pass',
#  'assist_tackle',
#  'lateral_reception',
#  'lateral_rush',
#  'lateral_return',
#  'lateral_recovery',
#  'passer_player_id',
#  'passer_player_name',
#  'passing_yards',
#  'receiver_player_id',
#  'receiver_player_name',
#  'receiving_yards',
#  'rusher_player_id',
#  'rusher_player_name',
#  'rushing_yards',
#  'lateral_receiver_player_id',
#  'lateral_receiver_player_name',
#  'lateral_receiving_yards',
#  'lateral_rusher_player_id',
#  'lateral_rusher_player_name',
#  'lateral_rushing_yards',
#  'lateral_sack_player_id',
#  'lateral_sack_player_name',
#  'interception_player_id',
#  'interception_player_name',
#  'lateral_interception_player_id',
#  'lateral_interception_player_name',
#  'punt_returner_player_id',
#  'punt_returner_player_name',
#  'lateral_punt_returner_player_id',
#  'lateral_punt_returner_player_name',
#  'kickoff_returner_player_name',
#  'kickoff_returner_player_id',
#  'lateral_kickoff_returner_player_id',
#  'lateral_kickoff_returner_player_name',
#  'punter_player_id',
#  'punter_player_name',
#  'kicker_player_name',
#  'kicker_player_id',
#  'own_kickoff_recovery_player_id',
#  'own_kickoff_recovery_player_name',
#  'blocked_player_id',
#  'blocked_player_name',
#  'tackle_for_loss_1_player_id',
#  'tackle_for_loss_1_player_name',
#  'tackle_for_loss_2_player_id',
#  'tackle_for_loss_2_player_name',
#  'qb_hit_1_player_id',
#  'qb_hit_1_player_name',
#  'qb_hit_2_player_id',
#  'qb_hit_2_player_name',
#  'forced_fumble_player_1_team',
#  'forced_fumble_player_1_player_id',
#  'forced_fumble_player_1_player_name',
#  'forced_fumble_player_2_team',
#  'forced_fumble_player_2_player_id',
#  'forced_fumble_player_2_player_name',
#  'solo_tackle_1_team',
#  'solo_tackle_2_team',
#  'solo_tackle_1_player_id',
#  'solo_tackle_2_player_id',
#  'solo_tackle_1_player_name',
#  'solo_tackle_2_player_name',
#  'assist_tackle_1_player_id',
#  'assist_tackle_1_player_name',
#  'assist_tackle_1_team',
#  'assist_tackle_2_player_id',
#  'assist_tackle_2_player_name',
#  'assist_tackle_2_team',
#  'assist_tackle_3_player_id',
#  'assist_tackle_3_player_name',
#  'assist_tackle_3_team',
#  'assist_tackle_4_player_id',
#  'assist_tackle_4_player_name',
#  'assist_tackle_4_team',
#  'tackle_with_assist',
#  'tackle_with_assist_1_player_id',
#  'tackle_with_assist_1_player_name',
#  'tackle_with_assist_1_team',
#  'tackle_with_assist_2_player_id',
#  'tackle_with_assist_2_player_name',
#  'tackle_with_assist_2_team',
#  'pass_defense_1_player_id',
#  'pass_defense_1_player_name',
#  'pass_defense_2_player_id',
#  'pass_defense_2_player_name',
#  'fumbled_1_team',
#  'fumbled_1_player_id',
#  'fumbled_1_player_name',
#  'fumbled_2_player_id',
#  'fumbled_2_player_name',
#  'fumbled_2_team',
#  'fumble_recovery_1_team',
#  'fumble_recovery_1_yards',
#  'fumble_recovery_1_player_id',
#  'fumble_recovery_1_player_name',
#  'fumble_recovery_2_team',
#  'fumble_recovery_2_yards',
#  'fumble_recovery_2_player_id',
#  'fumble_recovery_2_player_name',
#  'sack_player_id',
#  'sack_player_name',
#  'half_sack_1_player_id',
#  'half_sack_1_player_name',
#  'half_sack_2_player_id',
#  'half_sack_2_player_name',
#  'return_team',
#  'return_yards',
#  'penalty_team',
#  'penalty_player_id',
#  'penalty_player_name',
#  'penalty_yards',
#  'replay_or_challenge',
#  'replay_or_challenge_result',
#  'penalty_type',
#  'defensive_two_point_attempt',
#  'defensive_two_point_conv',
#  'defensive_extra_point_attempt',
#  'defensive_extra_point_conv',
#  'safety_player_name',
#  'safety_player_id',
#  'season',
#  'cp',
#  'cpoe',
#  'series',
#  'series_success',
#  'series_result',
#  'order_sequence',
#  'start_time',
#  'time_of_day',
#  'stadium',
#  'weather',
#  'nfl_api_id',
#  'play_clock',
#  'play_deleted',
#  'play_type_nfl',
#  'special_teams_play',
#  'st_play_type',
#  'end_clock_time',
#  'end_yard_line',
#  'fixed_drive',
#  'fixed_drive_result',
#  'drive_real_start_time',
#  'drive_play_count',
#  'drive_time_of_possession',
#  'drive_first_downs',
#  'drive_inside20',
#  'drive_ended_with_score',
#  'drive_quarter_start',
#  'drive_quarter_end',
#  'drive_yards_penalized',
#  'drive_start_transition',
#  'drive_end_transition',
#  'drive_game_clock_start',
#  'drive_game_clock_end',
#  'drive_start_yard_line',
#  'drive_end_yard_line',
#  'drive_play_id_started',
#  'drive_play_id_ended',
#  'away_score',
#  'home_score',
#  'location',
#  'result',
#  'total',
#  'spread_line',
#  'total_line',
#  'div_game',
#  'roof',
#  'surface',
#  'temp',
#  'wind',
#  'home_coach',
#  'away_coach',
#  'stadium_id',
#  'game_stadium',
#  'aborted_play',
#  'success',
#  'passer',
#  'passer_jersey_number',
#  'rusher',
#  'rusher_jersey_number',
#  'receiver',
#  'receiver_jersey_number',
#  'pass',
#  'rush',
#  'first_down',
#  'special',
#  'play',
#  'passer_id',
#  'rusher_id',
#  'receiver_id',
#  'name',
#  'jersey_number',
#  'id',
#  'fantasy_player_name',
#  'fantasy_player_id',
#  'fantasy',
#  'fantasy_id',
#  'out_of_bounds',
#  'home_opening_kickoff',
#  'qb_epa',
#  'xyac_epa',
#  'xyac_mean_yardage',
#  'xyac_median_yardage',
#  'xyac_success',
#  'xyac_fd',
#  'xpass',
#  'pass_oe',
#  'nflverse_game_id',
#  'possession_team',
#  'offense_formation',
#  'offense_personnel',
#  'defenders_in_box',
#  'defense_personnel',
#  'number_of_pass_rushers',
#  'players_on_play',
#  'offense_players',
#  'defense_players',
#  'n_offense',
#  'n_defense']

# %%
[x for x in list(df_pass_plays.columns) if "po" in x]
# Out:
# ['posteam',
#  'posteam_type',
#  'extra_point_result',
#  'two_point_conv_result',
#  'posteam_timeouts_remaining',
#  'posteam_score',
#  'posteam_score_post',
#  'defteam_score_post',
#  'score_differential_post',
#  'extra_point_prob',
#  'two_point_conversion_prob',
#  'home_wp_post',
#  'away_wp_post',
#  'extra_point_attempt',
#  'two_point_attempt',
#  'defensive_two_point_attempt',
#  'defensive_two_point_conv',
#  'defensive_extra_point_attempt',
#  'defensive_extra_point_conv',
#  'cpoe',
#  'drive_time_of_possession',
#  'possession_team']

# %%
receivers = df_pass_plays.groupby(['receiver_id', 'receiver']).agg({"air_yards": ["count", "mean"]})

# %%
receivers.columns = list(map("_".join, receivers.columns.values))
sort_crit = "air_yards_count > 50"
print(receivers.query(sort_crit).sort_values(by="air_yards_mean", ascending=[False]).to_string())
# Out:
#                             air_yards_count  air_yards_mean
# receiver_id receiver
# 00-0036261  B.Aiyuk                      65       15.107693
# 00-0037545  R.Shaheed                    55       14.781818
# 00-0030564  D.Hopkins                    83       14.674699
# 00-0031408  M.Evans                      91       14.274725
# 00-0038977  N.Dell                       75       14.266666
# 00-0031544  A.Cooper                     86       14.139535
# 00-0036196  G.Davis                      67       13.880597
# 00-0037239  C.Olave                     103       13.757281
# 00-0035640  D.Metcalf                    80       13.550000
# 00-0037247  G.Pickens                    73       12.945206
# 00-0034837  C.Ridley                     76       12.671053
# 00-0036912  D.Smith                      76       12.460526
# 00-0035676  A.Brown                     105       12.447619
# 00-0035662  M.Brown                      98       11.959184
# 00-0035216  D.Johnson                    55       11.890909
# 00-0035535  D.Slayton                    53       11.811320
# 00-0031381  D.Adams                     118       11.788136
# 00-0034827  D.Moore                      80       11.762500
# 00-0037816  R.Doubs                      69       11.724638
# 00-0036407  J.Jeudy                      53       11.679245
# 00-0036849  T.Atwell                     60       11.600000
# 00-0039146  J.Reed                       59       11.389831
# 00-0038994  J.Addison                    72       11.375000
# 00-0036410  T.Higgins                    51       11.254902
# 00-0036554  N.Collins                    73       11.164384
# 00-0036358  C.Lamb                      104       10.980769
# 00-0036970  K.Pitts                      60       10.850000
# 00-0035659  T.McLaurin                   97       10.845361
# 00-0036322  J.Jefferson                  53       10.679245
# 00-0037740  G.Wilson                    113       10.663717
# 00-0032211  T.Lockett                    79       10.658228
# 00-0033307  K.Bourne                     55       10.436363
# 00-0039062  J.Mingo                      57       10.385965
# 00-0033908  C.Kupp                       51       10.274509
# 00-0034960  J.Meyers                     76       10.157895
# 00-0032765  M.Thomas                     64       10.156250
# 00-0037238  D.London                     68       10.088235
# 00-0031588  S.Diggs                     121       10.016529
# 00-0036613  J.Waddle                     75       10.000000
# 00-0033040  T.Hill                      120        9.975000
# 00-0034348  C.Sutton                     68        9.955882
# 00-0030431  R.Woods                      57        9.789474
# 00-0034775  C.Kirk                       84        9.738095
# 00-0036980  E.Moore                      73        9.424658
# 00-0037741  J.Dotson                     69        9.376812
# 00-0030279  K.Allen                     129        9.372093
# 00-0033288  G.Kittle                     61        9.262295
# 00-0036900  J.Chase                     112        8.991072
# 00-0039075  P.Nacua                     111        8.819819
# 00-0036345  K.Osborn                     51        8.666667
# 00-0033921  C.Godwin                     82        8.365853
# 00-0031610  D.Waller                     51        8.333333
# 00-0039064  Z.Flowers                    80        8.212500
# 00-0036252  M.Pittman                   111        7.936937
# 00-0034383  D.Schultz                    61        7.770492
# 00-0036963  A.St. Brown                 109        7.623853
# 00-0038621  D.Douglas                    55        7.527273
# 00-0038997  J.Downs                      73        7.438356
# 00-0039065  S.LaPorta                    77        7.363636
# 00-0034753  M.Andrews                    61        7.262295
# 00-0035229  T.Hockenson                 102        7.235294
# 00-0030035  A.Thielen                   100        7.000000
# 00-0037744  T.McBride                    65        6.861538
# 00-0030506  T.Kelce                      88        6.852273
# 00-0033110  T.Higbee                     51        6.647059
# 00-0033009  T.Boyd                       72        6.638889
# 00-0038543  J.Smith-Njigba               57        6.438597
# 00-0033282  C.Samuel                     63        6.428571
# 00-0031260  L.Thomas                     62        6.306452
# 00-0038041  J.Ferguson                   58        5.879310
# 00-0034351  D.Goedert                    52        5.288462
# 00-0036290  C.Kmet                       61        5.245902
# 00-0039067  R.Rice                       56        4.857143
# 00-0038933  D.Kincaid                    64        4.781250
# 00-0033881  E.Engram                     82        4.548780
# 00-0033885  D.Njoku                      78        3.615385
# 00-0033280  C.McCaffrey                  58        1.017241
# 00-0039139  J.Gibbs                      52        0.903846
# 00-0035700  J.Jacobs                     52        0.788462
# 00-0033906  A.Kamara                     61        0.131148

# %% [markdown]
# # Sticky Stats

# %%
seasons = range(2016, 2023 + 1)
df_pbp = nfl.import_pbp_data(seasons)
# Out:
# 2016 done.
# 2017 done.
# 2018 done.
# 2019 done.
# 2020 done.
# 2021 done.
# 2022 done.
# 2023 done.
# Downcasting floats.

# %%
df_passes = df_pbp.query("play_type == 'pass' & air_yards.notnull()").reset_index()

# %% [markdown]
# A *long pass* is a pass that is 20+ yards, and a *short pass* as less than 20 yards.

# %%
df_passes["pass_length_air_yards"] = np.where(
      df_passes["air_yards"] >= 20, "long", "short"
)

# %%
df_passes["passing_yards"] = np.where(
          df_passes["passing_yards"].isnull(), 0,
          df_passes["passing_yards"]
        )

# %%
df_passes["passing_yards"].describe()
# Out:
# count    143732.000000
# mean          7.176259
# std           9.645344
# min         -20.000000
# 25%           0.000000
# 50%           5.000000
# 75%          11.000000
# max          98.000000
# Name: passing_yards, dtype: float64

# %% [markdown]
# ## Passing yards by pass type

# %%
df_passes.query("pass_length_air_yards == 'short'")["passing_yards"].describe()
# Out:
# count    126811.000000
# mean          6.514490
# std           7.688124
# min         -20.000000
# 25%           0.000000
# 50%           5.000000
# 75%          10.000000
# max          95.000000
# Name: passing_yards, dtype: float64

# %%
df_passes.query("pass_length_air_yards == 'long'")["passing_yards"].describe()
# Out:
# count    16921.000000
# mean        12.135749
# std         17.872271
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%         26.000000
# max         98.000000
# Name: passing_yards, dtype: float64

# %% [markdown]
# ## EPA by pass type

# %%
df_passes.query("pass_length_air_yards == 'short'")["epa"].describe()
# Out:
# count    126810.000000
# mean          0.116065
# std           1.428156
# min         -13.031219
# 25%          -0.608661
# 50%          -0.005850
# 75%           0.954895
# max           8.241420
# Name: epa, dtype: float64

# %%
df_passes.query("pass_length_air_yards == 'long'")["epa"].describe()
# Out:
# count    16921.000000
# mean         0.377189
# std          2.179605
# min        -10.477921
# 25%         -0.829438
# 50%         -0.466574
# 75%          2.129708
# max          8.789743
# Name: epa, dtype: float64

# %% [markdown]
# ## Weekly Data

# %% [markdown]
# Returns weekly data for the years and columns specified. The weekly data is by player.
#
# years : required, list of years to pull data for (earliest available is 1999)
#
# columns : optional, list of columns to pull data for
#
# downcast : converts float64 columns to float32, reducing memory usage by ~30%. Will slow down initial load speed ~50%

# %%
columns = None
df_weekly = nfl.import_weekly_data(years, columns, downcast=True)

# %%
df_weekly.head()

# %%
play = df_weekly.iloc[0]
for i in range(0, len(play), 10):
    print(play[i: i + 10])
    print()

# %%
# each row represents the performance of that player for the week
for row in df_weekly.itertuples():
    print(row.Index, row.player_name)

# %% [markdown]
# ## Seasonal Data

# %% [markdown]
# Returns seasonal data, including various calculated market share stats specific to receivers
#
# years (List[int]) : required, list of years to pull data for (earliest available is 1999)
#
# s_type (str) : optional (default 'REG') season type to include in average ('ALL','REG','POST')

# %%
df_seasonal = nfl.import_seasonal_data(years)

# %%
df_seasonal.head

# %%
play = df_seasonal.iloc[0]
for i in range(0, len(play), 10):
    print(play[i: i + 10])
    print()

# %% [markdown]
# ## Season Rosters

# %% [markdown]
# Returns yearly roster information for the seasons specified
#
# years : required, list of years to pull data for (earliest available is 1999)
#
# columns : optional, list of columns to pull data for

# %%
columns = ["player_name", "player_id", "position"]
df_roster = nfl.import_seasonal_rosters(years, columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 columns = ["player_name", "player_id", "position"]
# ----> 2 df_roster = nfl.import_seasonal_rosters(years, columns)
#
# NameError: name 'nfl' is not defined

# %%
df_roster.iloc[0]

# %% [markdown]
# # Creating Player Map

# %%
player_map = dict()
id_map = dict()

# %%
for row in df_roster.itertuples():
    player_map[row.player_id] = dict()
    player_map[row.player_id]["name"] = row.player_name
    player_map[row.player_id]["position"] = row.position
    
    id_map[row.player_name] = row.player_id

# %%
for row in df_seasonal.itertuples():
    if row.player_id in player_map:
        player_map[row.player_id]["seasonal_df"] = row._asdict()

# %%
# each row represents the performance of that player for the week
for row in df_weekly.itertuples():
    if row.player_display_name in id_map:
        player_id = id_map[row.player_display_name]
        if "week_dfs" in player_map[player_id]:
            player_map[player_id]["week_dfs"].append(row._asdict())
        else:
            player_map[player_id]["week_dfs"] = [row._asdict()]

# %% [markdown]
# ### Travis Kelce

# %%
kelce_id = id_map["Travis Kelce"]

# %%
player_map[kelce_id]["seasonal_df"]

# %%
player_map[kelce_id]["week_dfs"][0]

# %% [markdown]
# # Data by Position Group

# %%
qbs = list()
rbs = list()
wrs = list()
tes = list()

# %%
for key in player_map:
    player = player_map[key]
    if "seasonal_df" in player:  # not all players have a seasonal df
        if player["position"] == "QB":
            qbs.append(player)
        if player["position"] == "RB":
            rbs.append(player)
        if player["position"] == "WR":
            wrs.append(player)
        if player["position"] == "TE":
            tes.append(player)

# %%
df_qb = pd.DataFrame(columns=['Name', 'Passing EPA', 'Rushing EPA', 'Total EPA', 'EPA Per Game', 'Fantasy Points', 'Fantasy Points Per Game', 'Dakota', 'Dakota Per Game', 'PACR', 'PACR Per Game'])
i = 1
for player in qbs:
    print(player["seasonal_df"].keys())
    if player["seasonal_df"]["fantasy_points_ppr"] > -500 and player["seasonal_df"]["games"] > 1:
        print(player["seasonal_df"].keys())
        break
        name = player['name']
        games = player['seasonal_df']['games']
        fantasy_points_ppr = player['seasonal_df']['fantasy_points_ppr']
        dakota = player['seasonal_df']['dakota']
        pacr = player['seasonal_df']['pacr']
        passing_epa = player['seasonal_df']['passing_epa']
        rushing_epa = player['seasonal_df']['rushing_epa']
        total_epa = passing_epa + rushing_epa
        
        df_qb.loc[i] = [name, passing_epa, rushing_epa, total_epa, total_epa / games, fantasy_points_ppr, fantasy_points_ppr / games, dakota, dakota / games, pacr, pacr / games]
        i += 1
    break

# %%
names = ["Brock Purdy", "C.J. Stroud", "Trevor Lawrence", "Justin Herbert", "Justin Fields"]
def highlight_names(row):
    """"""
    if row['Name'] in names:
        return ['background-color: yellow']*len(row)
    return ['']*len(row)

# %%
df_qb

# %%
df_qb.sort_values(by='Fantasy Points', ascending=False).style.apply(highlight_names, axis=1)

# %%
df_qb.sort_values(by='Total EPA', ascending=False).style.apply(highlight_names, axis=1)

# %%
df_qb.sort_values(by='EPA Per Game', ascending=False).style.apply(highlight_names, axis=1)

# %%
df_qb.sort_values(by='Dakota', ascending=False).style.apply(highlight_names, axis=1)

# %%
df_qb.sort_values(by='Dakota Per Game', ascending=False).style.apply(highlight_names, axis=1)

# %%
df_qb.sort_values(by='PACR', ascending=False).style.apply(highlight_names, axis=1)

# %%
df_qb.sort_values(by='PACR Per Game', ascending=False).style.apply(highlight_names, axis=1)

# %%
df_qb.head(1)

# %%
ls

# %%
df_qb.to_csv()

# %% [markdown]
# ## WRs

# %%
df_wr = pd.DataFrame(columns=['Name', 'Target Share', 'Weighted Opportunity X', 'Rushing EPA', 'Receiving EPA', 'Total EPA', 'EPA Per Game', 'Fantasy Points', 'Fantasy Points Per Game', 'RACR', 'RACR Per Game'])
i = 1
for player in wrs:
    if player["seasonal_df"]["fantasy_points_ppr"] > -500 and player["seasonal_df"]["games"] > 1:
        name = player['name']
        games = player['seasonal_df']['games']
        fantasy_points_ppr = player['seasonal_df']['fantasy_points_ppr']
    
        tgt_sh =  player['seasonal_df']['tgt_sh']
        wopr_x = player['seasonal_df']['wopr_x']
        racr = player['seasonal_df']['racr']
        receiving_epa = player['seasonal_df']['receiving_epa']
        rushing_epa = player['seasonal_df']['rushing_epa']
        total_epa = receiving_epa + rushing_epa
        
        df_wr.loc[i] = [name, tgt_sh, wopr_x, rushing_epa, receiving_epa, total_epa, total_epa / games, fantasy_points_ppr, fantasy_points_ppr / games, racr, racr / games]
        i += 1

# %%
df_wr

# %%
df_wr.sort_values(by='Fantasy Points Per Game', ascending=False).head(48)

# %%
df_wr.sort_values(by='Total EPA', ascending=False).head(48)

# %%
df_wr.sort_values(by='RACR', ascending=False).head(48)

# %%
df_wr.sort_values(by='RACR Per Game', ascending=False).head(48)

# %%
df_wr.sort_values(by='Target Share', ascending=False).head(48)

# %%
df_wr.sort_values(by='Weighted Opportunity X', ascending=False).head(48)
