# %%
import nfl_data_py
import pandas as pd

# %%
pip list | grep nfl
# Out:
# nfl-data-py         0.3.1
# WARNING: You are using pip version 21.2.3; however, version 24.0 is available.
# You should consider upgrading via the '/Users/alexbishka/Documents/Projects/Fantasy/Analysis/nfldata/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
df_season = pd.read_pickle("../interactive/df_all_2005_2023.pkl")

# %%
df_qbs = df_season.query("position == 'QB' and dakota > 3")

# %%
df_qbs[["season", "fantasy_points", "dakota", "player_name"]]
# Out:
#        season  fantasy_points    dakota      player_name
# 315      2006          309.48  3.126724   Peyton Manning
# 316      2007          275.10  3.146298   Peyton Manning
# 317      2008          254.18  3.086874   Peyton Manning
# 318      2009          278.70  3.258342   Peyton Manning
# 320      2012          310.96  3.358401   Peyton Manning
# 321      2013          409.98  3.427002   Peyton Manning
# 644      2007          390.04  3.942845        Tom Brady
# 997      2009          292.42  3.089267       Drew Brees
# 999      2011          391.64  3.295610       Drew Brees
# 1006     2018          303.98  3.160498       Drew Brees
# 1364     2015          309.24  3.124538    Carson Palmer
# 1440     2014          266.30  3.302592        Tony Romo
# 2270     2009          269.16  3.421059    Philip Rivers
# 2271     2010          281.60  3.173291    Philip Rivers
# 2274     2013          288.32  3.114082    Philip Rivers
# ...

# %%
for p in df_qbs["player_name"].unique():
    print(f"<li>{p}</li>")
# Out:
# <li>Peyton Manning</li>
# <li>Tom Brady</li>
# <li>Drew Brees</li>
# <li>Carson Palmer</li>
# <li>Tony Romo</li>
# <li>Philip Rivers</li>
# <li>Aaron Rodgers</li>
# <li>Matt Ryan</li>
# <li>Patrick Mahomes</li>
# <li>Lamar Jackson</li>
# <li>Brock Purdy</li>

# %%
for p in df_qbs["player_name"].unique():
    print(f"<li>{p}</li>")
# Out:
# <li>Peyton Manning</li>
# <li>Tom Brady</li>
# <li>Drew Brees</li>
# <li>Carson Palmer</li>
# <li>Tony Romo</li>
# <li>Ben Roethlisberger</li>
# <li>Philip Rivers</li>
# <li>Aaron Rodgers</li>
# <li>Matt Ryan</li>
# <li>Patrick Mahomes</li>
# <li>Lamar Jackson</li>
# <li>Josh Allen</li>
# <li>Brock Purdy</li>
