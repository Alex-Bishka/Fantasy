# %% [markdown]
# # QB Filter For Success

# %% [markdown]
# Was your sack rate 8.7% or above?
# - sack rate > 8.7% => bust
# - sack rate < 8.7% => not sure yet, go to filter 2
#
# If not, was your adjusted yards gained per pass attempt 6.5 or below? (because of the ''if not'' we are now at filter 2)
# - AY/A < 6.5 => bust
# - AY/A > 6.5 => hit

# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import nfl_data_py as nfl

# %% [markdown]
# # Grabbing Data

# %%
years = range(1999, 2023 + 1)

# %%
df_pbp = pd.read_pickle("./df_pbp_99_23.pkl")

# %%
df_roster = pd.read_pickle("./df_roster_99_23.pkl")

# %%
df_fantasy = pd.read_pickle("../../DataManagementNotebooks/basic_99_23.pkl")

# %% [markdown]
# # Filter Data

# %%
df_pass = df_pbp.query("season_type == 'REG'")

# %%
df = df_pass \
    .groupby(["season", "passer_player_id"]) \
    .agg({"sack": "sum", "passing_yards": "sum", "interception": "sum", "pass_touchdown": "sum", 
          "complete_pass": "sum", "incomplete_pass": "sum", "pass_attempt": "sum"})

# %%
clean_df = df.reset_index() \
    .query("pass_attempt >= 1") \
    .rename(columns={"pass_attempt": "drop_backs", "passer_player_id": "player_id"})

# %%
clean_df["pass_attempts"] = clean_df["complete_pass"] + clean_df["incomplete_pass"] + clean_df["interception"]

# %%
clean_df = clean_df.query("pass_attempts >= 100")

# %% [markdown]
# **Note:** snaps and passing attempts are the same as we have filtered the play by play data to only have passing plays.

# %% [markdown]
# # Adding Two Heuristics
#
# 1. Sack rate: caluclated as `sacks / snaps`.
# 2. Adjusted yards gained per pass attempt (or ay_a): `(Passing Yards + 20(Passing Touchdowns) – 45(Interceptions Thrown))/(Passing Attempts)`
#
# Remember, snaps and passing attempts are synonymous for our dataset

# %%
clean_df["sack_rate"] = clean_df["sack"] / clean_df["drop_backs"]

# %%
num = (clean_df["passing_yards"] + 20 * (clean_df["pass_touchdown"]) - 45 * (clean_df["interception"]))
denom = clean_df["pass_attempts"]
clean_df["ay_a"] = num / denom

# %%
clean_df.head()
# Out:
#    season   player_id  sack  passing_yards  interception  pass_touchdown  \
# 0    1999  00-0000104  19.0         2964.0          12.0            17.0
# 1    1999  00-0000722  33.0         2136.0           8.0            17.0
# 2    1999  00-0000865  36.0         1957.0           7.0            13.0
# 5    1999  00-0001218  50.0         4436.0          15.0            36.0
# 6    1999  00-0001335  30.0         2670.0          12.0            16.0
#
#    complete_pass  incomplete_pass  drop_backs  pass_attempts  sack_rate  \
# 0          263.0            166.0       460.0          441.0   0.041304
# 1          169.0            143.0       353.0          320.0   0.093484
# 2          151.0            111.0       307.0          269.0   0.117264
# 5          343.0            211.0       621.0          569.0   0.080515
# 6          215.0            162.0       421.0          389.0   0.071259
#
#        ay_a
# 0  6.267574
# 1  6.612500
# 2  7.070632
# 5  7.875220
# 6  6.298201

# %% [markdown]
# ### Rookie DF

# %%
min_season_df = clean_df.groupby("player_id")['season'].min().reset_index()
min_season_df.rename(columns={'season': 'min_season'}, inplace=True)

# Merge on 'player_id' to add the 'min_season' to each row of 'clean_df'
temp_df = pd.merge(clean_df, min_season_df, on="player_id")

# Filter rows where 'season' matches 'min_season'
temp_rook_df = temp_df[temp_df['season'] == temp_df['min_season']]

# %%
rook_df = temp_rook_df.query("drop_backs > 5")

# %%
rook_df.head()
# Out:
#    season   player_id  sack  passing_yards  interception  pass_touchdown  \
# 0    1999  00-0000104  19.0         2964.0          12.0            17.0
# 1    1999  00-0000722  33.0         2136.0           8.0            17.0
# 2    1999  00-0000865  36.0         1957.0           7.0            13.0
# 3    1999  00-0001218  50.0         4436.0          15.0            36.0
# 4    1999  00-0001335  30.0         2670.0          12.0            16.0
#
#    complete_pass  incomplete_pass  drop_backs  pass_attempts  sack_rate  \
# 0          263.0            166.0       460.0          441.0   0.041304
# 1          169.0            143.0       353.0          320.0   0.093484
# 2          151.0            111.0       307.0          269.0   0.117264
# 3          343.0            211.0       621.0          569.0   0.080515
# 4          215.0            162.0       421.0          389.0   0.071259
#
#        ay_a  min_season
# 0  6.267574        1999
# 1  6.612500        1999
# 2  7.070632        1999
# 3  7.875220        1999
# 4  6.298201        1999

# %% [markdown]
# # Magic Time

# %% [markdown]
# ## Sack Rate - Filter 1

# %%
low_sack_rate = rook_df.query("sack_rate < 0.087")

# %%
low_sack_rate.head(10)
# Out:
#     season   player_id  sack  passing_yards  interception  pass_touchdown  \
# 0     1999  00-0000104  19.0         2964.0          12.0            17.0
# 3     1999  00-0001218  50.0         4436.0          15.0            36.0
# 4     1999  00-0001335  30.0         2670.0          12.0            16.0
# 7     1999  00-0002110  29.0         3060.0           9.0            14.0
# 10    1999  00-0003292  16.0         2318.0          11.0             8.0
# 12    1999  00-0003761  15.0         1475.0           9.0             8.0
# 14    1999  00-0005106  35.0         4091.0          23.0            22.0
# 15    1999  00-0005363  26.0         3171.0          16.0            19.0
# 17    1999  00-0005741  49.0         3840.0          14.0            24.0
# 18    1999  00-0005755  15.0         2544.0          11.0            11.0
#
#     complete_pass  incomplete_pass  drop_backs  pass_attempts  sack_rate  \
# 0           263.0            166.0       460.0          441.0   0.041304
# 3           343.0            211.0       621.0          569.0   0.080515
# 4           215.0            162.0       421.0          389.0   0.071259
# 7           259.0            173.0       473.0          441.0   0.061311
# 10          190.0            130.0       347.0          331.0   0.046110
# 12          124.0             66.0       214.0          199.0   0.070093
# 14          341.0            230.0       631.0          594.0   0.055468
# 15          264.0            198.0       504.0          478.0   0.051587
# 17          304.0            197.0       566.0          515.0   0.086572
# 18          225.0            137.0       390.0          373.0   0.038462
#
#         ay_a  min_season
# 0   6.267574        1999
# 3   7.875220        1999
# 4   6.298201        1999
# 7   6.655329        1999
# 10  5.990937        1999
# 12  6.180904        1999
# 14  5.885522        1999
# 15  5.922594        1999
# 17  7.165049        1999
# 18  6.083110        1999

# %% [markdown]
# # Grabbing Filtered Info

# %%
df_rost_clean = df_roster.query("position == 'QB'")[["season", "player_name", "player_id", "depth_chart_position", 
                                     "college", "height", "weight"]]

# %% [markdown]
# ## Those Filtered Out

# %%
bust_one = rook_df.query("sack_rate >= 0.087")

# %%
bust_one_clean = pd.merge(bust_one, df_rost_clean, on=["season", "player_id"], how="left")

# %%
nfl_qbs_rounds_combined = {
    "Tim Couch": 1, "Donovan McNabb": 1, "Akili Smith": 1,
    "Daunte Culpepper": 1, "Cade McNown": 1, "Mike Vick": 1,
    "David Carr": 1, "Chad Hutchinson": "Unknown", "Mike McMahon": 5,
    "Anthony Wright": 0, "Jesse Palmer": 4, "Josh McCown": 3,
    "Craig Krenzel": 5, "Ben Roethlisberger": 1, "Brooks Bollinger": 6,
    "J.P. Losman": 1, "Alex Smith": 1, "Charlie Frye": 3,
    "Andrew Walter": 3, "Luke McCown": 4, "Kellen Clemens": 2,
    "J.T. O'Sullivan": 6, "Keith Null": 6, "Troy Smith": 5,
    "Jimmy Clausen": 2, "Colt McCoy": 3, "Caleb Hanie": 0,
    "Tim Tebow": 1, "Blaine Gabbert": 1, "Christian Ponder": 1,
    "T.J. Yates": 5, "Matt Flynn": 7, "Thaddeus Lewis": 0,
    "Terrelle Pryor": 3, "Mike Glennon": 3, "Geno Smith": 2,
    "Charlie Whitehurst": 3, "Austin Davis": 0, "Teddy Bridgewater": 1,
    "Zach Mettenberger": 6, "Blake Bortles": 1, "A.J. McCarron": 5,
    "Marcus Mariota": 1, "Bryce Petty": 4, "Cody Kessler": 3,
    "Jared Goff": 1, "Jacoby Brissett": 3, "Josh Rosen": 1,
    "Dwayne Haskins": 1, "Taysom Hill": 0, "Justin Fields": 1,
    "Zach Wilson": 1, "Sam Ehlinger": 6, "Jake Browning": 0,
    "Sam Howell": 5, "Bailey Zappe": 6, "Tommy DeVito": 0,
    "Bryce Young": 1, "Will Levis": 2,
}

# %%
bust_one_clean["round"] = bust_one_clean["player_name"].map(nfl_qbs_rounds_combined).fillna(-1)

# %%
bust_one_clean.query("round == 1")[["player_name", "sack_rate", "ay_a"]].reset_index()
# Out:
#     index         player_name  sack_rate      ay_a
# 0       6           Tim Couch   0.123077  5.445844
# 1      12      Donovan McNabb   0.114286  3.671296
# 2      14         Akili Smith   0.110465  3.782895
# 3      21           Mike Vick   0.156716  6.106194
# 4      24          David Carr   0.145594  4.722973
# 5      29  Ben Roethlisberger   0.092025  8.359322
# 6      31         J.P. Losman   0.098425  4.978166
# 7      32          Alex Smith   0.149485  2.424242
# 8      43           Tim Tebow   0.108197  6.269372
# 9      44      Blaine Gabbert   0.088300  4.743341
# 10     45    Christian Ponder   0.093458  5.250859
# 11     56   Teddy Bridgewater   0.088036  6.614428
# 12     58       Blake Bortles   0.102996  4.974737
# 13     60      Marcus Mariota   0.092457  7.427027
# 14     63          Jared Goff   0.112554  4.263415
# 15     65          Josh Rosen   0.102506  4.753181
# 16     66      Dwayne Haskins   0.123404  5.862069
# 17     68       Justin Fields   0.117647  5.777778
# 18     69         Zach Wilson   0.102326  5.271541
# 19     75         Bryce Young   0.105085  5.022770

# %%
len(bust_one_clean.query("round == 1"))
# Out:
# 20

# %%
df_fail_one = bust_one_clean \
    .copy() \
    .query("round == 1")[["player_id", "player_name", "sack_rate", "ay_a"]] \
    .reset_index()

# %%
df_fail_one.head()
# Out:
#    index   player_id     player_name  sack_rate      ay_a
# 0      6  00-0003535       Tim Couch   0.123077  5.445844
# 1     12  00-0011022  Donovan McNabb   0.114286  3.671296
# 2     14  00-0015082     Akili Smith   0.110465  3.782895
# 3     21  00-0020245       Mike Vick   0.156716  6.106194
# 4     24  00-0020608      David Carr   0.145594  4.722973

# %% [markdown]
# Model failures:
# - Donovan McNabb 	0.114286 	3.671296
# - Mike Vick 	0.156716 	6.106194
# - Ben Roethlisberger 	0.092025 	8.359322
# - Alex Smith 	0.149485 	2.424242
# - Jared Goff 	0.112554 	4.263415
#
# 5 out of 20 or 25% chance of still going against the odds. This falls to 4 of 20 (20% chance) if we remove Vick's first season, since he only played two games.

# %% [markdown]
# ## AY_A - Filter 2

# %%
df_success = low_sack_rate.query("ay_a > 6.5")

# %%
df_success.head(10)
# Out:
#     season   player_id  sack  passing_yards  interception  pass_touchdown  \
# 3     1999  00-0001218  50.0         4436.0          15.0            36.0
# 7     1999  00-0002110  29.0         3060.0           9.0            14.0
# 17    1999  00-0005741  49.0         3840.0          14.0            24.0
# 19    1999  00-0005885  28.0         2816.0          12.0            23.0
# 27    1999  00-0008442  29.0         4005.0          13.0            24.0
# 32    1999  00-0010346  14.0         4135.0          15.0            26.0
# 40    1999  00-0012261   9.0         1382.0           5.0            10.0
# 48    1999  00-0017200  26.0         4044.0          11.0            38.0
# 55    2000  00-0001823  15.0         1514.0           6.0             9.0
# 60    2000  00-0003739  34.0         3937.0          16.0            33.0
#
#     complete_pass  incomplete_pass  drop_backs  pass_attempts  sack_rate  \
# 3           343.0            211.0       621.0          569.0   0.080515
# 7           259.0            173.0       473.0          441.0   0.061311
# 17          304.0            197.0       566.0          515.0   0.086572
# 19          191.0            125.0       358.0          328.0   0.078212
# 27          316.0            190.0       549.0          519.0   0.052823
# 32          331.0            186.0       548.0          532.0   0.025547
# 40          116.0             74.0       204.0          195.0   0.044118
# 48          297.0            147.0       482.0          455.0   0.053942
# 55          113.0             75.0       210.0          194.0   0.071429
# 60          297.0            161.0       510.0          474.0   0.066667
#
#         ay_a  min_season
# 3   7.875220        1999
# 7   6.655329        1999
# 17  7.165049        1999
# 19  8.341463        1999
# 27  7.514451        1999
# 32  7.481203        1999
# 40  6.958974        1999
# 48  9.470329        1999
# 55  7.340206        2000
# 60  8.179325        2000

# %% [markdown]
# ## Those filtered out by Sacks

# %%
df_bust_two = low_sack_rate.query("ay_a <= 6.5")

# %%
df_bust_two_clean = pd.merge(df_bust_two, df_rost_clean, on=["season", "player_id"], how="left")

# %%
nfl_qbs_rounds_post_1998 = {
    "Drew Brees": 2, "Joey Harrington": 1, "Patrick Ramsey": 1,
    "Kyle Boller": 1, "Byron Leftwich": 1, "Carson Palmer": 1,
    "Eli Manning": 1, "Chris Simms": 3, "Kyle Orton": 4,
    "Ryan Fitzpatrick": 7, "Jason Campbell": 1, "Derek Anderson": 6,
    "Vince Young": 1, "Matt Leinart": 1, "Bruce Gradkowski": 6,
    "Tarvaris Jackson": 2, "Brodie Croyle": 3, "John Beck": 2,
    "Trent Edwards": 3, "JaMarcus Russell": 1, "Joe Flacco": 1,
    "Brady Quinn": 1, "Chad Henne": 2, "Josh Johnson": 5,
    "Matthew Stafford": 1, "Mark Sanchez": 1, "Josh Freeman": 1,
    "Kevin Kolb": 2, "Sam Bradford": 1, "Andy Dalton": 2,
    "Jake Locker": 1, "Ryan Lindley": 6, "Nick Foles": 3,
    "Andrew Luck": 1, "Brandon Weeden": 1, "Ryan Tannehill": 1,
    "Kirk Cousins": 4, "E.J. Manuel": 1, "Derek Carr": 2,
    "Ryan Mallett": 3, "Johnny Manziel": 1, "Matt Barkley": 4,
    "Carson Wentz": 1, "Mitchell Trubisky": 1, "DeShone Kizer": 2,
    "C.J. Beathard": 3, "Josh Allen": 1, "Sam Darnold": 1,
    "Mason Rudolph": 3, "Daniel Jones": 1, "Tua Tagovailoa": 1,
    "Jake Luton": 6, "Mike White": 5, "Davis Mills": 3,
    "Trevor Lawrence": 1, "Kenny Pickett": 1, "Joshua Dobbs": 4,
    "Jeff Garcia": 0, "Jon Kitna": 0, "Erik Kramer": 0, "Ray Lucas": 0,
    "Shane Matthews": 0, "Doug Pederson": 0, "Mike Tomczak": 0,
    "Jay Fiedler": 0, "Jamie Martin": 0, "Todd Bouman": 0,
    "Jake Delhomme": 0, "Doug Johnson": 0, "Tim Hasselbeck": 0,
    "Kurt Kittner": 5, "Matthew McGloin": 0, "Kellen Moore": 0,
    "Cleo Lemon": 0, "Matt Moore": 0, "Tyler Thigpen": 7,
    "Tyler Palko": 0, "Curtis Painter": 6, "Kyle Allen": 0,
    "David Blough": 0, "Devlin Hodges": 0, "Brandon Allen": 0,
    "Taylor Heinicke": 0, "Tyler Huntley": 0, "Phillip Walker": 0,
    "Cooper Rush": 0, "Tyson Bagent": 0, "Aidan O'Connell": 0,
    "Dorian Thompson-Robinson": 0
}

# %%
df_bust_two_clean["round"] = df_bust_two_clean["player_name"].map(nfl_qbs_rounds_post_1998).fillna(-1)

# %%
df_bust_two_clean.query("round == 1")[["player_name", "sack_rate", "ay_a"]].reset_index()
# Out:
#     index        player_name  sack_rate      ay_a
# 0      38    Joey Harrington   0.018307  4.228438
# 1      39     Patrick Ramsey   0.072874  5.986784
# 2      44        Kyle Boller   0.069106  4.441964
# 3      45     Byron Leftwich   0.043478  5.691388
# 4      46      Carson Palmer   0.054705  5.664352
# 5      48        Eli Manning   0.061611  3.847716
# 6      55     Jason Campbell   0.037209  5.927536
# 7      57        Vince Young   0.068063  5.207865
# 8      58       Matt Leinart   0.050378  5.909575
# 9      68   JaMarcus Russell   0.075377  6.329700
# 10     70         Joe Flacco   0.071429  6.334112
# 11     71        Brady Quinn   0.069091  4.625000
# 12     74   Matthew Stafford   0.057214  4.315650
# 13     75       Mark Sanchez   0.065990  4.914600
# 14     76       Josh Freeman   0.060897  4.285223
# 15     80       Sam Bradford   0.054487  5.418644
# 16     84        Jake Locker   0.073746  5.990446
# 17     87        Andrew Luck   0.061285  6.417863
# 18     88     Brandon Weeden   0.051376  5.609284
# 19     89     Ryan Tannehill   0.067179  6.092975
# 20     92        E.J. Manuel   0.083333  5.839869
# 21     97     Johnny Manziel   0.078512  6.345292
# 22     99       Carson Wentz   0.051322  5.719934
# 23    102  Mitchell Trubisky   0.085635  6.115151
# 24    106         Josh Allen   0.080460  5.341693
# 25    107        Sam Darnold   0.067416  6.111111
# 26    112       Daniel Jones   0.076000  6.464052
# 27    114     Tua Tagovailoa   0.063898  6.237931
# 28    120    Trevor Lawrence   0.050078  5.176080
# 29    124      Kenny Pickett   0.064593  5.498714

# %%
df_fail_two = df_bust_two_clean \
    .copy() \
    .query("round == 1")[["player_id", "player_name", "sack_rate", "ay_a"]] \
    .reset_index()

# %%
df_fail_two.head()
# Out:
#    index   player_id      player_name  sack_rate      ay_a
# 0     38  00-0021141  Joey Harrington   0.018307  4.228438
# 1     39  00-0021379   Patrick Ramsey   0.072874  5.986784
# 2     44  00-0022164      Kyle Boller   0.069106  4.441964
# 3     45  00-0022177   Byron Leftwich   0.043478  5.691388
# 4     46  00-0021429    Carson Palmer   0.054705  5.664352

# %% [markdown]
# Potential outliers:
# - Carson Palmer 	0.054705 	5.664352
# - Eli Manning 	0.061611 	3.847716
# - Joe Flacco 	0.071429 	6.334112
# - Matthew Stafford 	0.057214 	4.315650
# - Andrew Luck 	0.061285 	6.417863
# - Ryan Tannehill 	0.067179 	6.092975
# - Carson Wentz 	0.051322 	5.719934
# - Josh Allen 	0.080460 	5.341693
# - Daniel Jones 	0.076000 	6.464052
# - Tua Tagovailoa 	0.063898 	6.237931
# - Trevor Lawrence 	0.050078 	5.176080
#
# 11 players out of 30. Success rate for filtering out busts is still 63% effective.

# %% [markdown]
# # Merge in Roster DF

# %%
merged_df = pd.merge(df_success, df_rost_clean, on=["season", "player_id"], how="left")

# %%
merged_df.dropna(subset="player_name", inplace=True)

# %% [markdown]
# ## Successful QBs

# %%
nfl_qbs_rounds = {
    "Daunte Culpepper": 1,
    "Chad Pennington": 1,
    "Marc Bulger": 6,
    "David Garrard": 4,
    "Tony Romo": 0,  # Representing undrafted with 0
    "Philip Rivers": 1,
    "Aaron Rodgers": 1,
    "Jay Cutler": 1,
    "Matt Schaub": 3,
    "Matt Ryan": 1,
    "Cam Newton": 1,
    "Colin Kaepernick": 2,
    "Russell Wilson": 3,
    "Robert Griffin III": 1,
    "Case Keenum": 0,  # Representing undrafted with 0
    "Jimmy Garoppolo": 2,
    "Jameis Winston": 1,
    "Dak Prescott": 4,
    "Patrick Mahomes": 1,
    "Deshaun Watson": 1,
    "Lamar Jackson": 1,
    "Baker Mayfield": 1,
    "Kyler Murray": 1,
    "Gardner Minshew": 6,
    "Drew Lock": 2,
    "Justin Herbert": 1,
    "Jalen Hurts": 2,
    "Joe Burrow": 1,
    "Mac Jones": 1,
    "Brock Purdy": 7,
    "Desmond Ridder": 3,
    "Jordan Love": 1,
    "C.J. Stroud": 1,
}

# %%
merged_df["round"] = merged_df["player_name"].map(nfl_qbs_rounds).fillna(-1)

# %%
final_df = merged_df.query("round >= 0")

# %%
final_df["completion_percentage"] = final_df["complete_pass"] / final_df["pass_attempts"]
# Out:
# /tmp/ipykernel_12680/3107923885.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["completion_percentage"] = final_df["complete_pass"] / final_df["pass_attempts"]

# %%
final_df["bmi"] = final_df["weight"] / np.sqrt(final_df["height"])
# Out:
# /tmp/ipykernel_12680/838482218.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["bmi"] = final_df["weight"] / np.sqrt(final_df["height"])

# %%
round_one = final_df.query("round == 1")[["player_id", "player_name", 'sack', 'passing_yards', 'interception',
       'pass_touchdown', 'complete_pass', 'incomplete_pass', 'drop_backs',
       'pass_attempts', 'sack_rate', 'ay_a', 'height', 'weight', "bmi", "completion_percentage"]]

# %%
round_one
# Out:
#      player_id       player_name  sack  passing_yards  interception  \
# 9   00-0003739  Daunte Culpepper  34.0         3937.0          16.0
# 12  00-0019559   Chad Pennington  22.0         3120.0           6.0
# 18  00-0022942     Philip Rivers  28.0         3387.0           9.0
# 19  00-0024226        Jay Cutler  13.0         1001.0           5.0
# 24  00-0023459     Aaron Rodgers  34.0         4038.0          13.0
# 26  00-0026143         Matt Ryan  17.0         3440.0          11.0
# 27  00-0027939        Cam Newton  35.0         4051.0          17.0
# 35  00-0031503    Jameis Winston  27.0         4042.0          15.0
# 39  00-0033537    Deshaun Watson  19.0         1699.0           8.0
# 41  00-0033873   Patrick Mahomes  26.0         5097.0          12.0
# 42  00-0034796     Lamar Jackson  16.0         1201.0           3.0
# 43  00-0034855    Baker Mayfield  25.0         3725.0          14.0
# 44  00-0035228      Kyler Murray  48.0         3722.0          12.0
# 47  00-0036355    Justin Herbert  32.0         4336.0          10.0
# 49  00-0036442        Joe Burrow  32.0         2688.0           5.0
# 50  00-0036972         Mac Jones  28.0         3801.0          13.0
# 54  00-0036264       Jordan Love  30.0         4159.0          11.0
# 55  00-0039163       C.J. Stroud  38.0         4108.0           5.0
#
#     pass_touchdown  complete_pass  incomplete_pass  drop_backs  pass_attempts  \
# 9             33.0          297.0            161.0       510.0          474.0
# 12            22.0          275.0            118.0       422.0          399.0
# 18            22.0          284.0            167.0       489.0          460.0
# 19             9.0           81.0             51.0       150.0          137.0
# 24            28.0          341.0            182.0       572.0          536.0
# 26            16.0          265.0            158.0       452.0          434.0
# 27            21.0          310.0            190.0       555.0          517.0
# 35            22.0          312.0            208.0       565.0          535.0
# 39            19.0          126.0             70.0       226.0          204.0
# 41            50.0          383.0            185.0       607.0          580.0
# 42             6.0           99.0             68.0       186.0          170.0
# 43            27.0          310.0            162.0       518.0          486.0
# 44            20.0          349.0            181.0       593.0          542.0
# 47            31.0          396.0            189.0       630.0          595.0
# 49            13.0          264.0            135.0       436.0          404.0
# 50            22.0          352.0            156.0       551.0          521.0
# 54            32.0          372.0            196.0       611.0          579.0
# 55            23.0          319.0            175.0       541.0          499.0
#
#     sack_rate      ay_a  height  weight        bmi  completion_percentage
# 9    0.066667  8.179325    76.0   266.0  30.512293               0.626582
# 12   0.052133  8.245614    75.0   225.0  25.980762               0.689223
# 18   0.057260  7.439130    77.0   228.0  25.983011               0.617391
# 19   0.086667  6.978102    75.0   233.0  26.904523               0.591241
# 24   0.059441  7.486940    74.0   220.0  25.574481               0.636194
# 26   0.037611  7.523041    76.0   220.0  25.235731               0.610599
# 27   0.063063  7.168279    77.0   248.0  28.262223               0.599613
# 35   0.047788  7.115888    76.0   231.0  26.497517               0.583178
# 39   0.084071  8.426471    74.0   215.0  24.993242               0.617647
# 41   0.042834  9.581035    75.0   230.0  26.558112               0.660345
# 42   0.086022  6.976470    74.0   205.0  23.830766               0.582353
# 43   0.048263  7.479424    73.0   220.0  25.749052               0.637860
# 44   0.080944  6.608856    70.0   207.0  24.741232               0.643911
# 47   0.050794  7.573109    78.0   237.0  26.834966               0.665546
# 49   0.073394  6.740099    76.0   216.0  24.776899               0.653465
# 50   0.050817  7.017274    75.0   214.0  24.710592               0.675624
# 54   0.049100  7.433506    76.0   220.0  25.235731               0.642487
# 55   0.070240  8.703407    75.0   218.0  25.172472               0.639279

# %%
df_success = round_one.copy()

# %% [markdown]
# # Add In Fantasy Numbers

# %%
def add_fantasy(df):
    # Initialize new columns in the df DataFrame with NaN values
    df['min_rank'] = np.nan
    df['avg_rank'] = np.nan
    df['min_tier'] = np.nan
    df['avg_tier'] = np.nan
    
    # Iterate through each row of the df DataFrame
    for i, row in df.iterrows():
        p_id = row["player_id"]

        # Query player information from df_fantasy based on player_id
        player = df_fantasy.query(f"player_id == '{p_id}'")

        # Calculate minimum and average rank and tier for the player
        min_rank = player["rank"].min()
        avg_rank = player["rank"].mean()
        min_tier = player["tier"].min()
        avg_tier = player["tier"].mean()

        # Assign calculated values back to df at the current index
        df.loc[i, 'min_rank'] = min_rank
        df.loc[i, 'avg_rank'] = avg_rank
        df.loc[i, 'min_tier'] = min_tier
        df.loc[i, 'avg_tier'] = avg_tier
        
    # Return the modified DataFrame
    return df

# %% [markdown]
# # Full Picture Success

# %%
df_success_fantasy = add_fantasy(df_success.copy())
df_success_fantasy.reset_index()
# Out:
#     index   player_id       player_name  sack  passing_yards  interception  \
# 0       9  00-0003739  Daunte Culpepper  34.0         3937.0          16.0
# 1      12  00-0019559   Chad Pennington  22.0         3120.0           6.0
# 2      18  00-0022942     Philip Rivers  28.0         3387.0           9.0
# 3      19  00-0024226        Jay Cutler  13.0         1001.0           5.0
# 4      24  00-0023459     Aaron Rodgers  34.0         4038.0          13.0
# 5      26  00-0026143         Matt Ryan  17.0         3440.0          11.0
# 6      27  00-0027939        Cam Newton  35.0         4051.0          17.0
# 7      35  00-0031503    Jameis Winston  27.0         4042.0          15.0
# 8      39  00-0033537    Deshaun Watson  19.0         1699.0           8.0
# 9      41  00-0033873   Patrick Mahomes  26.0         5097.0          12.0
# 10     42  00-0034796     Lamar Jackson  16.0         1201.0           3.0
# 11     43  00-0034855    Baker Mayfield  25.0         3725.0          14.0
# 12     44  00-0035228      Kyler Murray  48.0         3722.0          12.0
# 13     47  00-0036355    Justin Herbert  32.0         4336.0          10.0
# 14     49  00-0036442        Joe Burrow  32.0         2688.0           5.0
# 15     50  00-0036972         Mac Jones  28.0         3801.0          13.0
# 16     54  00-0036264       Jordan Love  30.0         4159.0          11.0
# 17     55  00-0039163       C.J. Stroud  38.0         4108.0           5.0
#
#     pass_touchdown  complete_pass  incomplete_pass  drop_backs  ...  \
# 0             33.0          297.0            161.0       510.0  ...
# 1             22.0          275.0            118.0       422.0  ...
# 2             22.0          284.0            167.0       489.0  ...
# 3              9.0           81.0             51.0       150.0  ...
# 4             28.0          341.0            182.0       572.0  ...
# 5             16.0          265.0            158.0       452.0  ...
# 6             21.0          310.0            190.0       555.0  ...
# 7             22.0          312.0            208.0       565.0  ...
# 8             19.0          126.0             70.0       226.0  ...
# 9             50.0          383.0            185.0       607.0  ...
# 10             6.0           99.0             68.0       186.0  ...
# 11            27.0          310.0            162.0       518.0  ...
# 12            20.0          349.0            181.0       593.0  ...
# 13            31.0          396.0            189.0       630.0  ...
# 14            13.0          264.0            135.0       436.0  ...
# 15            22.0          352.0            156.0       551.0  ...
# 16            32.0          372.0            196.0       611.0  ...
# 17            23.0          319.0            175.0       541.0  ...
#
#     sack_rate      ay_a  height  weight        bmi  completion_percentage  \
# 0    0.066667  8.179325    76.0   266.0  30.512293               0.626582
# 1    0.052133  8.245614    75.0   225.0  25.980762               0.689223
# 2    0.057260  7.439130    77.0   228.0  25.983011               0.617391
# 3    0.086667  6.978102    75.0   233.0  26.904523               0.591241
# 4    0.059441  7.486940    74.0   220.0  25.574481               0.636194
# 5    0.037611  7.523041    76.0   220.0  25.235731               0.610599
# 6    0.063063  7.168279    77.0   248.0  28.262223               0.599613
# 7    0.047788  7.115888    76.0   231.0  26.497517               0.583178
# 8    0.084071  8.426471    74.0   215.0  24.993242               0.617647
# 9    0.042834  9.581035    75.0   230.0  26.558112               0.660345
# 10   0.086022  6.976470    74.0   205.0  23.830766               0.582353
# 11   0.048263  7.479424    73.0   220.0  25.749052               0.637860
# 12   0.080944  6.608856    70.0   207.0  24.741232               0.643911
# 13   0.050794  7.573109    78.0   237.0  26.834966               0.665546
# 14   0.073394  6.740099    76.0   216.0  24.776899               0.653465
# 15   0.050817  7.017274    75.0   214.0  24.710592               0.675624
# 16   0.049100  7.433506    76.0   220.0  25.235731               0.642487
# 17   0.070240  8.703407    75.0   218.0  25.172472               0.639279
#
#     min_rank   avg_rank  min_tier  avg_tier
# 0        1.0  24.454545       1.0  2.727273
# 1        9.0  35.636364       1.0  3.454545
# 2        3.0  17.764706       1.0  1.882353
# 3        4.0  20.833333       1.0  2.166667
# 4        1.0  20.263158       1.0  2.315789
# 5        2.0  12.400000       1.0  1.533333
# 6        1.0  14.636364       1.0  1.909091
# 7        5.0  31.555556       1.0  3.111111
# 8        4.0  18.666667       1.0  2.166667
# 9        1.0  10.857143       1.0  1.571429
# 10       1.0  12.333333       1.0  1.666667
# 11      10.0  19.666667       1.0  2.166667
# 12       3.0  13.200000       1.0  1.600000
# 13       2.0   9.750000       1.0  1.250000
# 14       4.0  15.500000       1.0  2.000000
# 15      18.0  24.333333       2.0  2.333333
# 16       5.0  40.333333       1.0  4.000000
# 17       9.0   9.000000       1.0  1.000000
#
# [18 rows x 21 columns]

# %%
df_success_fantasy.query("min_rank <= 12")[["player_name", "min_rank", 
                                                                "min_tier", "avg_rank", "avg_tier"]] \
    .reset_index()
# Out:
#     index       player_name  min_rank  min_tier   avg_rank  avg_tier
# 0       9  Daunte Culpepper       1.0       1.0  24.454545  2.727273
# 1      12   Chad Pennington       9.0       1.0  35.636364  3.454545
# 2      18     Philip Rivers       3.0       1.0  17.764706  1.882353
# 3      19        Jay Cutler       4.0       1.0  20.833333  2.166667
# 4      24     Aaron Rodgers       1.0       1.0  20.263158  2.315789
# 5      26         Matt Ryan       2.0       1.0  12.400000  1.533333
# 6      27        Cam Newton       1.0       1.0  14.636364  1.909091
# 7      35    Jameis Winston       5.0       1.0  31.555556  3.111111
# 8      39    Deshaun Watson       4.0       1.0  18.666667  2.166667
# 9      41   Patrick Mahomes       1.0       1.0  10.857143  1.571429
# 10     42     Lamar Jackson       1.0       1.0  12.333333  1.666667
# 11     43    Baker Mayfield      10.0       1.0  19.666667  2.166667
# 12     44      Kyler Murray       3.0       1.0  13.200000  1.600000
# 13     47    Justin Herbert       2.0       1.0   9.750000  1.250000
# 14     49        Joe Burrow       4.0       1.0  15.500000  2.000000
# 15     54       Jordan Love       5.0       1.0  40.333333  4.000000
# 16     55       C.J. Stroud       9.0       1.0   9.000000  1.000000

# %% [markdown]
# # Bust One

# %%
fail_one_fantasy = add_fantasy(df_fail_one.copy())
fail_one_fantasy
# Out:
#     index   player_id         player_name  sack_rate      ay_a  min_rank  \
# 0       6  00-0003535           Tim Couch   0.123077  5.445844      18.0
# 1      12  00-0011022      Donovan McNabb   0.114286  3.671296       3.0
# 2      14  00-0015082         Akili Smith   0.110465  3.782895      39.0
# 3      21  00-0020245           Mike Vick   0.156716  6.106194       1.0
# 4      24  00-0020608          David Carr   0.145594  4.722973      14.0
# 5      29  00-0022924  Ben Roethlisberger   0.092025  8.359322       3.0
# 6      31  00-0022912         J.P. Losman   0.098425  4.978166      15.0
# 7      32  00-0023436          Alex Smith   0.149485  2.424242       4.0
# 8      43  00-0027876           Tim Tebow   0.108197  6.269372      18.0
# 9      44  00-0027948      Blaine Gabbert   0.088300  4.743341      28.0
# 10     45  00-0027950    Christian Ponder   0.093458  5.250859      22.0
# 11     56  00-0031237   Teddy Bridgewater   0.088036  6.614428      18.0
# 12     58  00-0031407       Blake Bortles   0.102996  4.974737       4.0
# 13     60  00-0032268      Marcus Mariota   0.092457  7.427027      13.0
# 14     63  00-0033106          Jared Goff   0.112554  4.263415       7.0
# 15     65  00-0034343          Josh Rosen   0.102506  4.753181      34.0
# 16     66  00-0035232      Dwayne Haskins   0.123404  5.862069      36.0
# 17     68  00-0036945       Justin Fields   0.117647  5.777778       6.0
# 18     69  00-0037013         Zach Wilson   0.102326  5.271541      30.0
# 19     75  00-0039150         Bryce Young   0.105085  5.022770      23.0
#
#      avg_rank  min_tier  avg_tier
# 0   26.000000       2.0  2.400000
# 1   14.384615       1.0  1.615385
# 2   52.750000       4.0  5.000000
# 3   24.000000       1.0  2.461538
# 4   39.000000       2.0  3.700000
# 5   15.944444       1.0  1.833333
# 6   48.857143       2.0  4.571429
# 7   25.071429       1.0  2.642857
# 8   32.000000       2.0  3.333333
# 9   48.083333       3.0  4.416667
# 10  33.750000       2.0  3.250000
# 11  41.111111       2.0  3.777778
# 12  24.166667       1.0  2.500000
# 13  32.888889       2.0  3.111111
# 14  16.125000       1.0  1.750000
# 15  55.333333       3.0  5.000000
# 16  37.000000       3.0  3.500000
# 17  18.333333       1.0  2.000000
# 18  31.333333       3.0  3.000000
# 19  23.000000       2.0  2.000000

# %%
df_success_fail_one = fail_one_fantasy.query("min_rank <= 12")[["player_name", "min_rank", 
                                                                "min_tier", "avg_rank", "avg_tier"]] \
    .reset_index()
df_success_fail_one
# Out:
#    index         player_name  min_rank  min_tier   avg_rank  avg_tier
# 0      1      Donovan McNabb       3.0       1.0  14.384615  1.615385
# 1      3           Mike Vick       1.0       1.0  24.000000  2.461538
# 2      5  Ben Roethlisberger       3.0       1.0  15.944444  1.833333
# 3      7          Alex Smith       4.0       1.0  25.071429  2.642857
# 4     12       Blake Bortles       4.0       1.0  24.166667  2.500000
# 5     14          Jared Goff       7.0       1.0  16.125000  1.750000
# 6     17       Justin Fields       6.0       1.0  18.333333  2.000000

# %% [markdown]
# ### Success Rate from First Group Filtered

# %%
len(df_success_fail_one) / len(fail_one_fantasy)
# Out:
# 0.35

# %% [markdown]
# ### Failure Rate from First Group Filtered

# %%
(len(fail_one_fantasy) - len(df_success_fail_one)) / len(fail_one_fantasy)
# Out:
# 0.65

# %% [markdown]
# # Bust Two

# %%
df_fail_two_fantasy = add_fantasy(df_fail_two.copy())
df_fail_two_fantasy
# Out:
#     index   player_id        player_name  sack_rate      ay_a  min_rank  \
# 0      38  00-0021141    Joey Harrington   0.018307  4.228438      16.0
# 1      39  00-0021379     Patrick Ramsey   0.072874  5.986784      22.0
# 2      44  00-0022164        Kyle Boller   0.069106  4.441964      25.0
# 3      45  00-0022177     Byron Leftwich   0.043478  5.691388      15.0
# 4      46  00-0021429      Carson Palmer   0.054705  5.664352       1.0
# 5      48  00-0022803        Eli Manning   0.061611  3.847716       5.0
# 6      55  00-0023460     Jason Campbell   0.037209  5.927536      13.0
# 7      57  00-0024218        Vince Young   0.068063  5.207865       9.0
# 8      58  00-0024225       Matt Leinart   0.050378  5.909575      23.0
# 9      68  00-0025388   JaMarcus Russell   0.075377  6.329700      26.0
# 10     70  00-0026158         Joe Flacco   0.071429  6.334112      10.0
# 11     71  00-0025409        Brady Quinn   0.069091  4.625000      29.0
# 12     74  00-0026498   Matthew Stafford   0.057214  4.315650       5.0
# 13     75  00-0026898       Mark Sanchez   0.065990  4.914600      10.0
# 14     76  00-0026993       Josh Freeman   0.060897  4.285223       7.0
# 15     80  00-0027854       Sam Bradford   0.054487  5.418644      16.0
# 16     84  00-0027946        Jake Locker   0.073746  5.990446      28.0
# 17     87  00-0029668        Andrew Luck   0.061285  6.417863       2.0
# 18     88  00-0029677     Brandon Weeden   0.051376  5.609284      26.0
# 19     89  00-0029701     Ryan Tannehill   0.067179  6.092975       7.0
# 20     92  00-0030526        E.J. Manuel   0.083333  5.839869      29.0
# 21     97  00-0031409     Johnny Manziel   0.078512  6.345292      33.0
# 22     99  00-0032950       Carson Wentz   0.051322  5.719934       5.0
# 23    102  00-0033869  Mitchell Trubisky   0.085635  6.115151      15.0
# 24    106  00-0034857         Josh Allen   0.080460  5.341693       1.0
# 25    107  00-0034869        Sam Darnold   0.067416  6.111111      27.0
# 26    112  00-0035710       Daniel Jones   0.076000  6.464052       9.0
# 27    114  00-0036212     Tua Tagovailoa   0.063898  6.237931      11.0
# 28    120  00-0036971    Trevor Lawrence   0.050078  5.176080       7.0
# 29    124  00-0038102      Kenny Pickett   0.064593  5.498714      28.0
#
#      avg_rank  min_tier  avg_tier
# 0   23.166667       2.0  2.500000
# 1   49.428571       2.0  4.428571
# 2   42.500000       3.0  4.125000
# 3   39.222222       2.0  3.666667
# 4   18.214286       1.0  2.071429
# 5   16.687500       1.0  1.750000
# 6   30.666667       2.0  3.000000
# 7   29.666667       1.0  2.833333
# 8   49.500000       2.0  4.500000
# 9   44.000000       3.0  4.333333
# 10  25.812500       1.0  2.625000
# 11  45.750000       3.0  4.500000
# 12  16.200000       1.0  1.866667
# 13  36.625000       1.0  3.625000
# 14  31.142857       1.0  3.142857
# 15  30.375000       2.0  2.875000
# 16  36.500000       3.0  3.750000
# 17   8.833333       1.0  1.333333
# 18  43.666667       3.0  4.333333
# 19  20.545455       1.0  2.181818
# 20  44.600000       3.0  4.200000
# 21  44.000000       3.0  4.000000
# 22  22.500000       1.0  2.250000
# 23  34.857143       2.0  3.571429
# 24   5.333333       1.0  1.166667
# 25  34.166667       3.0  3.333333
# 26  25.800000       1.0  2.400000
# 27  20.750000       1.0  2.250000
# 28  14.000000       1.0  1.333333
# 29  29.500000       3.0  3.000000

# %%
df_success_fail_two = df_fail_two_fantasy.query("min_rank <= 12")[["player_name", "min_rank", 
                                                                   "min_tier", "avg_rank", "avg_tier"]] \
    .reset_index()
df_success_fail_two
# Out:
#     index       player_name  min_rank  min_tier   avg_rank  avg_tier
# 0       4     Carson Palmer       1.0       1.0  18.214286  2.071429
# 1       5       Eli Manning       5.0       1.0  16.687500  1.750000
# 2       7       Vince Young       9.0       1.0  29.666667  2.833333
# 3      10        Joe Flacco      10.0       1.0  25.812500  2.625000
# 4      12  Matthew Stafford       5.0       1.0  16.200000  1.866667
# 5      13      Mark Sanchez      10.0       1.0  36.625000  3.625000
# 6      14      Josh Freeman       7.0       1.0  31.142857  3.142857
# 7      17       Andrew Luck       2.0       1.0   8.833333  1.333333
# 8      19    Ryan Tannehill       7.0       1.0  20.545455  2.181818
# 9      22      Carson Wentz       5.0       1.0  22.500000  2.250000
# 10     24        Josh Allen       1.0       1.0   5.333333  1.166667
# 11     26      Daniel Jones       9.0       1.0  25.800000  2.400000
# 12     27    Tua Tagovailoa      11.0       1.0  20.750000  2.250000
# 13     28   Trevor Lawrence       7.0       1.0  14.000000  1.333333

# %% [markdown]
# ### Success Rate from Second Group Filtered

# %%
(len(df_success_fail_two)) / len(df_fail_two_fantasy)
# Out:
# 0.4666666666666667

# %% [markdown]
# ### Failure Rate from First Group Filtered

# %%
(len(df_fail_two_fantasy) - len(df_success_fail_two)) / len(df_fail_two_fantasy)
# Out:
# 0.5333333333333333

# %% [markdown]
# # Further Exploration

# %%
df_success_fantasy.columns
# Out:
# Index(['player_id', 'player_name', 'sack', 'passing_yards', 'interception',
#        'pass_touchdown', 'complete_pass', 'incomplete_pass', 'drop_backs',
#        'pass_attempts', 'sack_rate', 'ay_a', 'height', 'weight', 'bmi',
#        'completion_percentage', 'min_rank', 'avg_rank', 'min_tier',
#        'avg_tier'],
#       dtype='object')

# %%
df_success_fantasy.player_name.unique()
# Out:
# array(['Daunte Culpepper', 'Chad Pennington', 'Philip Rivers',
#        'Jay Cutler', 'Aaron Rodgers', 'Matt Ryan', 'Cam Newton',
#        'Jameis Winston', 'Deshaun Watson', 'Patrick Mahomes',
#        'Lamar Jackson', 'Baker Mayfield', 'Kyler Murray',
#        'Justin Herbert', 'Joe Burrow', 'Mac Jones', 'Jordan Love',
#        'C.J. Stroud'], dtype=object)

# %%
import plotly.express as px

# %%
df_success_fantasy["color"] = np.where(df_success_fantasy["player_name"] == "Mac Jones", "red", "blue")

# %%
fig = px.bar(df_success_fantasy, x='player_name', y='sack', color="color")
# fig.show()

# %%
for col in df_success_fantasy.columns[3:]:
    fig = px.bar(df_success_fantasy, x='player_name', y=col, color="color")
#     fig.show()

# %% [markdown]
# # For HTML Conversion

# %%
def html_ready_df(df):
    df["Sack Rate Percentage"] = df["sack_rate"] * 100
    df["Adjusted Air Yards"] = df["ay_a"]
    df["Player Name"] = df["player_name"]
    df["Best Finish"] = df["min_rank"]    
    
    return df[["Player Name", "Sack Rate Percentage", "Adjusted Air Yards", "Best Finish"]]

# %%
success_html = html_ready_df(df_success_fantasy.copy())

# %%
def highlight_mac_jones(row):
    # Check if the player_name in the row is 'Mac Jones'
    if row['Player Name'] == 'Mac Jones':
        # Return a list of CSS properties 'background-color: yellow' for each cell in the row
        return ['background-color: yellow']*len(row)
    else:
        # Return a list of empty strings (no styling) for each cell in the row
        return ['']*len(row)

# Assuming df is your DataFrame
# Apply the highlighting function row-wise (axis=1)
styled_df = success_html.style.apply(highlight_mac_jones, axis=1)

# Display the styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_752d0_row15_col0, #T_752d0_row15_col1, #T_752d0_row15_col2, #T_752d0_row15_col3 {
#   background-color: yellow;
# }
# </style>
# <table id="T_752d0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_752d0_level0_col0" class="col_heading level0 col0" >Player Name</th>
#       <th id="T_752d0_level0_col1" class="col_heading level0 col1" >Sack Rate Percentage</th>
#       <th id="T_752d0_level0_col2" class="col_heading level0 col2" >Adjusted Air Yards</th>
#       <th id="T_752d0_level0_col3" class="col_heading level0 col3" >Best Finish</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_752d0_level0_row0" class="row_heading level0 row0" >9</th>
#       <td id="T_752d0_row0_col0" class="data row0 col0" >Daunte Culpepper</td>
#       <td id="T_752d0_row0_col1" class="data row0 col1" >6.666667</td>
#       <td id="T_752d0_row0_col2" class="data row0 col2" >8.179325</td>
#       <td id="T_752d0_row0_col3" class="data row0 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_752d0_level0_row1" class="row_heading level0 row1" >12</th>
#       <td id="T_752d0_row1_col0" class="data row1 col0" >Chad Pennington</td>
#       <td id="T_752d0_row1_col1" class="data row1 col1" >5.213270</td>
#       <td id="T_752d0_row1_col2" class="data row1 col2" >8.245614</td>
#       <td id="T_752d0_row1_col3" class="data row1 col3" >9.000000</td>
#     </tr>
#     <tr>
#       <th id="T_752d0_level0_row2" class="row_heading level0 row2" >18</th>
#       <td id="T_752d0_row2_col0" class="data row2 col0" >Philip Rivers</td>
#       <td id="T_752d0_row2_col1" class="data row2 col1" >5.725971</td>
#       <td id="T_752d0_row2_col2" class="data row2 col2" >7.439130</td>
#       <td id="T_752d0_row2_col3" class="data row2 col3" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_752d0_level0_row3" class="row_heading level0 row3" >19</th>
#       <td id="T_752d0_row3_col0" class="data row3 col0" >Jay Cutler</td>
#       <td id="T_752d0_row3_col1" class="data row3 col1" >8.666667</td>
#       <td id="T_752d0_row3_col2" class="data row3 col2" >6.978102</td>
#       <td id="T_752d0_row3_col3" class="data row3 col3" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_752d0_level0_row4" class="row_heading level0 row4" >24</th>
#       <td id="T_752d0_row4_col0" class="data row4 col0" >Aaron Rodgers</td>
#       <td id="T_752d0_row4_col1" class="data row4 col1" >5.944056</td>
#       <td id="T_752d0_row4_col2" class="data row4 col2" >7.486940</td>
#       <td id="T_752d0_row4_col3" class="data row4 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_752d0_level0_row5" class="row_heading level0 row5" >26</th>
#       <td id="T_752d0_row5_col0" class="data row5 col0" >Matt Ryan</td>
#       <td id="T_752d0_row5_col1" class="data row5 col1" >3.761062</td>
#       <td id="T_752d0_row5_col2" class="data row5 col2" >7.523041</td>
#       <td id="T_752d0_row5_col3" class="data row5 col3" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_752d0_level0_row6" class="row_heading level0 row6" >27</th>
#       <td id="T_752d0_row6_col0" class="data row6 col0" >Cam Newton</td>
#       <td id="T_752d0_row6_col1" class="data row6 col1" >6.306306</td>
#       <td id="T_752d0_row6_col2" class="data row6 col2" >7.168279</td>
#       <td id="T_752d0_row6_col3" class="data row6 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_752d0_level0_row7" class="row_heading level0 row7" >35</th>
#       <td id="T_752d0_row7_col0" class="data row7 col0" >Jameis Winston</td>
#       <td id="T_752d0_row7_col1" class="data row7 col1" >4.778761</td>
#       <td id="T_752d0_row7_col2" class="data row7 col2" >7.115888</td>
#       <td id="T_752d0_row7_col3" class="data row7 col3" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_752d0_level0_row8" class="row_heading level0 row8" >39</th>
#       <td id="T_752d0_row8_col0" class="data row8 col0" >Deshaun Watson</td>
#       <td id="T_752d0_row8_col1" class="data row8 col1" >8.407080</td>
#       <td id="T_752d0_row8_col2" class="data row8 col2" >8.426471</td>
#       <td id="T_752d0_row8_col3" class="data row8 col3" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_752d0_level0_row9" class="row_heading level0 row9" >41</th>
#       <td id="T_752d0_row9_col0" class="data row9 col0" >Patrick Mahomes</td>
#       <td id="T_752d0_row9_col1" class="data row9 col1" >4.283361</td>
#       <td id="T_752d0_row9_col2" class="data row9 col2" >9.581035</td>
#       <td id="T_752d0_row9_col3" class="data row9 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_752d0_level0_row10" class="row_heading level0 row10" >42</th>
#       <td id="T_752d0_row10_col0" class="data row10 col0" >Lamar Jackson</td>
#       <td id="T_752d0_row10_col1" class="data row10 col1" >8.602151</td>
#       <td id="T_752d0_row10_col2" class="data row10 col2" >6.976470</td>
#       <td id="T_752d0_row10_col3" class="data row10 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_752d0_level0_row11" class="row_heading level0 row11" >43</th>
#       <td id="T_752d0_row11_col0" class="data row11 col0" >Baker Mayfield</td>
#       <td id="T_752d0_row11_col1" class="data row11 col1" >4.826255</td>
#       <td id="T_752d0_row11_col2" class="data row11 col2" >7.479424</td>
#       <td id="T_752d0_row11_col3" class="data row11 col3" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_752d0_level0_row12" class="row_heading level0 row12" >44</th>
#       <td id="T_752d0_row12_col0" class="data row12 col0" >Kyler Murray</td>
#       <td id="T_752d0_row12_col1" class="data row12 col1" >8.094435</td>
#       <td id="T_752d0_row12_col2" class="data row12 col2" >6.608856</td>
#       <td id="T_752d0_row12_col3" class="data row12 col3" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_752d0_level0_row13" class="row_heading level0 row13" >47</th>
#       <td id="T_752d0_row13_col0" class="data row13 col0" >Justin Herbert</td>
#       <td id="T_752d0_row13_col1" class="data row13 col1" >5.079365</td>
#       <td id="T_752d0_row13_col2" class="data row13 col2" >7.573109</td>
#       <td id="T_752d0_row13_col3" class="data row13 col3" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_752d0_level0_row14" class="row_heading level0 row14" >49</th>
#       <td id="T_752d0_row14_col0" class="data row14 col0" >Joe Burrow</td>
#       <td id="T_752d0_row14_col1" class="data row14 col1" >7.339449</td>
#       <td id="T_752d0_row14_col2" class="data row14 col2" >6.740099</td>
#       <td id="T_752d0_row14_col3" class="data row14 col3" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_752d0_level0_row15" class="row_heading level0 row15" >50</th>
#       <td id="T_752d0_row15_col0" class="data row15 col0" >Mac Jones</td>
#       <td id="T_752d0_row15_col1" class="data row15 col1" >5.081670</td>
#       <td id="T_752d0_row15_col2" class="data row15 col2" >7.017274</td>
#       <td id="T_752d0_row15_col3" class="data row15 col3" >18.000000</td>
#     </tr>
#     <tr>
#       <th id="T_752d0_level0_row16" class="row_heading level0 row16" >54</th>
#       <td id="T_752d0_row16_col0" class="data row16 col0" >Jordan Love</td>
#       <td id="T_752d0_row16_col1" class="data row16 col1" >4.909984</td>
#       <td id="T_752d0_row16_col2" class="data row16 col2" >7.433506</td>
#       <td id="T_752d0_row16_col3" class="data row16 col3" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_752d0_level0_row17" class="row_heading level0 row17" >55</th>
#       <td id="T_752d0_row17_col0" class="data row17 col0" >C.J. Stroud</td>
#       <td id="T_752d0_row17_col1" class="data row17 col1" >7.024030</td>
#       <td id="T_752d0_row17_col2" class="data row17 col2" >8.703407</td>
#       <td id="T_752d0_row17_col3" class="data row17 col3" >9.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
save_path = f"../../../interactive-2.0/QB/draft-capital"

# %%
with open(f'{save_path}/passing-qbs.html', 'w') as file:
    file.write(styled_df.to_html())

# %% [markdown]
# # Prepping the Fail

# %% [markdown]
# ### First Threshold Fail

# %%
def highlight_qb_one_seasons(row):
    # Check if the player_name in the row is 'Mac Jones'
    if row['Best Finish'] <= 12:
        # Return a list of CSS properties 'background-color: yellow' for each cell in the row
        return ['background-color: yellow']*len(row)
    else:
        # Return a list of empty strings (no styling) for each cell in the row
        return ['']*len(row)

# %%
fail_one_html = html_ready_df(fail_one_fantasy)

# %%
styled_df_fail_one = fail_one_html.style.apply(highlight_qb_one_seasons, axis=1)
styled_df_fail_one
# Out:
# <style type="text/css">
# #T_42a34_row1_col0, #T_42a34_row1_col1, #T_42a34_row1_col2, #T_42a34_row1_col3, #T_42a34_row3_col0, #T_42a34_row3_col1, #T_42a34_row3_col2, #T_42a34_row3_col3, #T_42a34_row5_col0, #T_42a34_row5_col1, #T_42a34_row5_col2, #T_42a34_row5_col3, #T_42a34_row7_col0, #T_42a34_row7_col1, #T_42a34_row7_col2, #T_42a34_row7_col3, #T_42a34_row12_col0, #T_42a34_row12_col1, #T_42a34_row12_col2, #T_42a34_row12_col3, #T_42a34_row14_col0, #T_42a34_row14_col1, #T_42a34_row14_col2, #T_42a34_row14_col3, #T_42a34_row17_col0, #T_42a34_row17_col1, #T_42a34_row17_col2, #T_42a34_row17_col3 {
#   background-color: yellow;
# }
# </style>
# <table id="T_42a34">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_42a34_level0_col0" class="col_heading level0 col0" >Player Name</th>
#       <th id="T_42a34_level0_col1" class="col_heading level0 col1" >Sack Rate Percentage</th>
#       <th id="T_42a34_level0_col2" class="col_heading level0 col2" >Adjusted Air Yards</th>
#       <th id="T_42a34_level0_col3" class="col_heading level0 col3" >Best Finish</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_42a34_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_42a34_row0_col0" class="data row0 col0" >Tim Couch</td>
#       <td id="T_42a34_row0_col1" class="data row0 col1" >12.307693</td>
#       <td id="T_42a34_row0_col2" class="data row0 col2" >5.445844</td>
#       <td id="T_42a34_row0_col3" class="data row0 col3" >18.000000</td>
#     </tr>
#     <tr>
#       <th id="T_42a34_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_42a34_row1_col0" class="data row1 col0" >Donovan McNabb</td>
#       <td id="T_42a34_row1_col1" class="data row1 col1" >11.428572</td>
#       <td id="T_42a34_row1_col2" class="data row1 col2" >3.671296</td>
#       <td id="T_42a34_row1_col3" class="data row1 col3" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_42a34_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_42a34_row2_col0" class="data row2 col0" >Akili Smith</td>
#       <td id="T_42a34_row2_col1" class="data row2 col1" >11.046512</td>
#       <td id="T_42a34_row2_col2" class="data row2 col2" >3.782895</td>
#       <td id="T_42a34_row2_col3" class="data row2 col3" >39.000000</td>
#     </tr>
#     <tr>
#       <th id="T_42a34_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_42a34_row3_col0" class="data row3 col0" >Mike Vick</td>
#       <td id="T_42a34_row3_col1" class="data row3 col1" >15.671642</td>
#       <td id="T_42a34_row3_col2" class="data row3 col2" >6.106194</td>
#       <td id="T_42a34_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_42a34_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_42a34_row4_col0" class="data row4 col0" >David Carr</td>
#       <td id="T_42a34_row4_col1" class="data row4 col1" >14.559386</td>
#       <td id="T_42a34_row4_col2" class="data row4 col2" >4.722973</td>
#       <td id="T_42a34_row4_col3" class="data row4 col3" >14.000000</td>
#     </tr>
#     <tr>
#       <th id="T_42a34_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_42a34_row5_col0" class="data row5 col0" >Ben Roethlisberger</td>
#       <td id="T_42a34_row5_col1" class="data row5 col1" >9.202455</td>
#       <td id="T_42a34_row5_col2" class="data row5 col2" >8.359322</td>
#       <td id="T_42a34_row5_col3" class="data row5 col3" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_42a34_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_42a34_row6_col0" class="data row6 col0" >J.P. Losman</td>
#       <td id="T_42a34_row6_col1" class="data row6 col1" >9.842520</td>
#       <td id="T_42a34_row6_col2" class="data row6 col2" >4.978166</td>
#       <td id="T_42a34_row6_col3" class="data row6 col3" >15.000000</td>
#     </tr>
#     <tr>
#       <th id="T_42a34_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_42a34_row7_col0" class="data row7 col0" >Alex Smith</td>
#       <td id="T_42a34_row7_col1" class="data row7 col1" >14.948453</td>
#       <td id="T_42a34_row7_col2" class="data row7 col2" >2.424242</td>
#       <td id="T_42a34_row7_col3" class="data row7 col3" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_42a34_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_42a34_row8_col0" class="data row8 col0" >Tim Tebow</td>
#       <td id="T_42a34_row8_col1" class="data row8 col1" >10.819672</td>
#       <td id="T_42a34_row8_col2" class="data row8 col2" >6.269372</td>
#       <td id="T_42a34_row8_col3" class="data row8 col3" >18.000000</td>
#     </tr>
#     <tr>
#       <th id="T_42a34_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_42a34_row9_col0" class="data row9 col0" >Blaine Gabbert</td>
#       <td id="T_42a34_row9_col1" class="data row9 col1" >8.830022</td>
#       <td id="T_42a34_row9_col2" class="data row9 col2" >4.743341</td>
#       <td id="T_42a34_row9_col3" class="data row9 col3" >28.000000</td>
#     </tr>
#     <tr>
#       <th id="T_42a34_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_42a34_row10_col0" class="data row10 col0" >Christian Ponder</td>
#       <td id="T_42a34_row10_col1" class="data row10 col1" >9.345795</td>
#       <td id="T_42a34_row10_col2" class="data row10 col2" >5.250859</td>
#       <td id="T_42a34_row10_col3" class="data row10 col3" >22.000000</td>
#     </tr>
#     <tr>
#       <th id="T_42a34_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_42a34_row11_col0" class="data row11 col0" >Teddy Bridgewater</td>
#       <td id="T_42a34_row11_col1" class="data row11 col1" >8.803612</td>
#       <td id="T_42a34_row11_col2" class="data row11 col2" >6.614428</td>
#       <td id="T_42a34_row11_col3" class="data row11 col3" >18.000000</td>
#     </tr>
#     <tr>
#       <th id="T_42a34_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_42a34_row12_col0" class="data row12 col0" >Blake Bortles</td>
#       <td id="T_42a34_row12_col1" class="data row12 col1" >10.299625</td>
#       <td id="T_42a34_row12_col2" class="data row12 col2" >4.974737</td>
#       <td id="T_42a34_row12_col3" class="data row12 col3" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_42a34_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_42a34_row13_col0" class="data row13 col0" >Marcus Mariota</td>
#       <td id="T_42a34_row13_col1" class="data row13 col1" >9.245742</td>
#       <td id="T_42a34_row13_col2" class="data row13 col2" >7.427027</td>
#       <td id="T_42a34_row13_col3" class="data row13 col3" >13.000000</td>
#     </tr>
#     <tr>
#       <th id="T_42a34_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_42a34_row14_col0" class="data row14 col0" >Jared Goff</td>
#       <td id="T_42a34_row14_col1" class="data row14 col1" >11.255411</td>
#       <td id="T_42a34_row14_col2" class="data row14 col2" >4.263415</td>
#       <td id="T_42a34_row14_col3" class="data row14 col3" >7.000000</td>
#     </tr>
#     <tr>
#       <th id="T_42a34_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_42a34_row15_col0" class="data row15 col0" >Josh Rosen</td>
#       <td id="T_42a34_row15_col1" class="data row15 col1" >10.250569</td>
#       <td id="T_42a34_row15_col2" class="data row15 col2" >4.753181</td>
#       <td id="T_42a34_row15_col3" class="data row15 col3" >34.000000</td>
#     </tr>
#     <tr>
#       <th id="T_42a34_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_42a34_row16_col0" class="data row16 col0" >Dwayne Haskins</td>
#       <td id="T_42a34_row16_col1" class="data row16 col1" >12.340425</td>
#       <td id="T_42a34_row16_col2" class="data row16 col2" >5.862069</td>
#       <td id="T_42a34_row16_col3" class="data row16 col3" >36.000000</td>
#     </tr>
#     <tr>
#       <th id="T_42a34_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_42a34_row17_col0" class="data row17 col0" >Justin Fields</td>
#       <td id="T_42a34_row17_col1" class="data row17 col1" >11.764706</td>
#       <td id="T_42a34_row17_col2" class="data row17 col2

# %%
with open(f'{save_path}/fail-one-qbs.html', 'w') as file:
    file.write(styled_df_fail_one.to_html())

# %% [markdown]
# ### Second Threshold Fail

# %%
fail_two_html = html_ready_df(df_fail_two_fantasy)

# %%
styled_df_fail_two = fail_two_html.style.apply(highlight_qb_one_seasons, axis=1)
styled_df_fail_two
# Out:
# <style type="text/css">
# #T_bdc8f_row4_col0, #T_bdc8f_row4_col1, #T_bdc8f_row4_col2, #T_bdc8f_row4_col3, #T_bdc8f_row5_col0, #T_bdc8f_row5_col1, #T_bdc8f_row5_col2, #T_bdc8f_row5_col3, #T_bdc8f_row7_col0, #T_bdc8f_row7_col1, #T_bdc8f_row7_col2, #T_bdc8f_row7_col3, #T_bdc8f_row10_col0, #T_bdc8f_row10_col1, #T_bdc8f_row10_col2, #T_bdc8f_row10_col3, #T_bdc8f_row12_col0, #T_bdc8f_row12_col1, #T_bdc8f_row12_col2, #T_bdc8f_row12_col3, #T_bdc8f_row13_col0, #T_bdc8f_row13_col1, #T_bdc8f_row13_col2, #T_bdc8f_row13_col3, #T_bdc8f_row14_col0, #T_bdc8f_row14_col1, #T_bdc8f_row14_col2, #T_bdc8f_row14_col3, #T_bdc8f_row17_col0, #T_bdc8f_row17_col1, #T_bdc8f_row17_col2, #T_bdc8f_row17_col3, #T_bdc8f_row19_col0, #T_bdc8f_row19_col1, #T_bdc8f_row19_col2, #T_bdc8f_row19_col3, #T_bdc8f_row22_col0, #T_bdc8f_row22_col1, #T_bdc8f_row22_col2, #T_bdc8f_row22_col3, #T_bdc8f_row24_col0, #T_bdc8f_row24_col1, #T_bdc8f_row24_col2, #T_bdc8f_row24_col3, #T_bdc8f_row26_col0, #T_bdc8f_row26_col1, #T_bdc8f_row26_col2, #T_bdc8f_row26_col3, #T_bdc8f_row27_col0, #T_bdc8f_row27_col1, #T_bdc8f_row27_col2, #T_bdc8f_row27_col3, #T_bdc8f_row28_col0, #T_bdc8f_row28_col1, #T_bdc8f_row28_col2, #T_bdc8f_row28_col3 {
#   background-color: yellow;
# }
# </style>
# <table id="T_bdc8f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bdc8f_level0_col0" class="col_heading level0 col0" >Player Name</th>
#       <th id="T_bdc8f_level0_col1" class="col_heading level0 col1" >Sack Rate Percentage</th>
#       <th id="T_bdc8f_level0_col2" class="col_heading level0 col2" >Adjusted Air Yards</th>
#       <th id="T_bdc8f_level0_col3" class="col_heading level0 col3" >Best Finish</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bdc8f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bdc8f_row0_col0" class="data row0 col0" >Joey Harrington</td>
#       <td id="T_bdc8f_row0_col1" class="data row0 col1" >1.830664</td>
#       <td id="T_bdc8f_row0_col2" class="data row0 col2" >4.228438</td>
#       <td id="T_bdc8f_row0_col3" class="data row0 col3" >16.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bdc8f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bdc8f_row1_col0" class="data row1 col0" >Patrick Ramsey</td>
#       <td id="T_bdc8f_row1_col1" class="data row1 col1" >7.287449</td>
#       <td id="T_bdc8f_row1_col2" class="data row1 col2" >5.986784</td>
#       <td id="T_bdc8f_row1_col3" class="data row1 col3" >22.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bdc8f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bdc8f_row2_col0" class="data row2 col0" >Kyle Boller</td>
#       <td id="T_bdc8f_row2_col1" class="data row2 col1" >6.910569</td>
#       <td id="T_bdc8f_row2_col2" class="data row2 col2" >4.441964</td>
#       <td id="T_bdc8f_row2_col3" class="data row2 col3" >25.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bdc8f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bdc8f_row3_col0" class="data row3 col0" >Byron Leftwich</td>
#       <td id="T_bdc8f_row3_col1" class="data row3 col1" >4.347826</td>
#       <td id="T_bdc8f_row3_col2" class="data row3 col2" >5.691388</td>
#       <td id="T_bdc8f_row3_col3" class="data row3 col3" >15.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bdc8f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bdc8f_row4_col0" class="data row4 col0" >Carson Palmer</td>
#       <td id="T_bdc8f_row4_col1" class="data row4 col1" >5.470459</td>
#       <td id="T_bdc8f_row4_col2" class="data row4 col2" >5.664352</td>
#       <td id="T_bdc8f_row4_col3" class="data row4 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bdc8f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_bdc8f_row5_col0" class="data row5 col0" >Eli Manning</td>
#       <td id="T_bdc8f_row5_col1" class="data row5 col1" >6.161137</td>
#       <td id="T_bdc8f_row5_col2" class="data row5 col2" >3.847716</td>
#       <td id="T_bdc8f_row5_col3" class="data row5 col3" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bdc8f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_bdc8f_row6_col0" class="data row6 col0" >Jason Campbell</td>
#       <td id="T_bdc8f_row6_col1" class="data row6 col1" >3.720930</td>
#       <td id="T_bdc8f_row6_col2" class="data row6 col2" >5.927536</td>
#       <td id="T_bdc8f_row6_col3" class="data row6 col3" >13.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bdc8f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_bdc8f_row7_col0" class="data row7 col0" >Vince Young</td>
#       <td id="T_bdc8f_row7_col1" class="data row7 col1" >6.806283</td>
#       <td id="T_bdc8f_row7_col2" class="data row7 col2" >5.207865</td>
#       <td id="T_bdc8f_row7_col3" class="data row7 col3" >9.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bdc8f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_bdc8f_row8_col0" class="data row8 col0" >Matt Leinart</td>
#       <td id="T_bdc8f_row8_col1" class="data row8 col1" >5.037784</td>
#       <td id="T_bdc8f_row8_col2" class="data row8 col2" >5.909575</td>
#       <td id="T_bdc8f_row8_col3" class="data row8 col3" >23.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bdc8f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_bdc8f_row9_col0" class="data row9 col0" >JaMarcus Russell</td>
#       <td id="T_bdc8f_row9_col1" class="data row9 col1" >7.537688</td>
#       <td id="T_bdc8f_row9_col2" class="data row9 col2" >6.329700</td>
#       <td id="T_bdc8f_row9_col3" class="data row9 col3" >26.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bdc8f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_bdc8f_row10_col0" class="data row10 col0" >Joe Flacco</td>
#       <td id="T_bdc8f_row10_col1" class="data row10 col1" >7.142858</td>
#       <td id="T_bdc8f_row10_col2" class="data row10 col2" >6.334112</td>
#       <td id="T_bdc8f_row10_col3" class="data row10 col3" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bdc8f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_bdc8f_row11_col0" class="data row11 col0" >Brady Quinn</td>
#       <td id="T_bdc8f_row11_col1" class="data row11 col1" >6.909091</td>
#       <td id="T_bdc8f_row11_col2" class="data row11 col2" >4.625000</td>
#       <td id="T_bdc8f_row11_col3" class="data row11 col3" >29.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bdc8f_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_bdc8f_row12_col0" class="data row12 col0" >Matthew Stafford</td>
#       <td id="T_bdc8f_row12_col1" class="data row12 col1" >5.721393</td>
#       <td id="T_bdc8f_row12_col2" class="data row12 col2" >4.315650</td>
#       <td id="T_bdc8f_row12_col3" class="data row12 col3" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bdc8f_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_bdc8f_row13_col0" class="data row13 col0" >Mark Sanchez</td>
#       <td id="T_bdc8f_row13_col1" class="data row13 col1" >6.598984</td>
#       <td id="T_bdc8f_row13_col2" class="data row13 col2" >4.914600</td>
#       <td id="T_bdc8f_row13_col3" class="data row13 col3" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bdc8f_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_bdc8f_row14_col0" class="data row14 col0" >Josh Freeman</td>
#       <td id="T_bdc8f_row14_col1" class="data row14 col1" >6.089744</td>
#       <td id="T_bdc8f_row14_col2" class="data row14 col2" >4.285223</td>
#       <td id="T_bdc8f_row14_col3" class="data row14 col3" >7.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bdc8f_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_bdc8f_row15_col0" class="data row15 col0" >Sam Bradford</td>
#       <td id="T_bdc8f_row15_col1" class="data row15 col1" >5.448718</td>
#       <td id="T_bdc8f_row15_col2" class="data row15 col2" >5.418644</td>
#       <td id="T_bdc8f_row15_col3" class="data row15 col3" >16.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bdc8f_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id=

# %%
with open(f'{save_path}/fail-two-qbs.html', 'w') as file:
    file.write(styled_df_fail_two.to_html())
