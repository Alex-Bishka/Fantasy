# %% [markdown]
# # Examining RB Health in the Proceeding Season Based on Workload

# %% [markdown]
# ## Get Data

# %%
import nfl_data_py as nfl

# %%
years = range(1999, 2024 + 1)
s_type = "ALL"
df_seasons_all = nfl.import_seasonal_data(years, s_type)

# %%
df_roster = nfl.import_seasonal_rosters(years)

# %%
df_roster.columns
# Out:
# Index(['season', 'team', 'position', 'depth_chart_position', 'jersey_number',
#        'status', 'player_name', 'first_name', 'last_name', 'birth_date',
#        'height', 'weight', 'college', 'player_id', 'espn_id', 'sportradar_id',
#        'yahoo_id', 'rotowire_id', 'pff_id', 'pfr_id', 'fantasy_data_id',
#        'sleeper_id', 'years_exp', 'headshot_url', 'esb_id', 'gsis_it_id',
#        'smart_id', 'entry_year', 'rookie_year', 'draft_club', 'ngs_position',
#        'week', 'game_type', 'status_description_abbr', 'football_name',
#        'draft_number', 'age'],
#       dtype='object')

# %%
df_roster_clean = df_roster[["season", "player_id", "player_name", "age"]]

# %%
df_roster_clean.query("player_id == '00-0034844'")
# Out:
#        season   player_id     player_name   age
# 44701    2018  00-0034844  Saquon Barkley  21.0
# 47076    2019  00-0034844  Saquon Barkley  22.0
# 49813    2020  00-0034844  Saquon Barkley  23.0
# 52439    2021  00-0034844  Saquon Barkley  24.0
# 55076    2022  00-0034844  Saquon Barkley  25.0
# 57904    2023  00-0034844  Saquon Barkley  26.0
# 60810    2024  00-0034844  Saquon Barkley  27.0

# %% [markdown]
# ## Create DFs

# %%
df_carries = df_seasons_all.groupby(['player_id', 'season'], as_index=False).agg({
    'carries': 'sum',
    'receptions': 'sum',
    'games': 'max'
})
df_carries["touches"] = df_carries["carries"] + df_carries["receptions"]

# %%
df_touches_over_400 = df_carries.query("touches >= 400")
df_touches_over_400.head()
# Out:
#       player_id  season  carries  receptions  games  touches
# 91   00-0000745    2002      330          74     17      404
# 94   00-0000745    2005      370          57     17      427
# 95   00-0000745    2006      353          60     17      413
# 645  00-0004304    2004      410          24     18      434
# 769  00-0005092    2001      324          97     17      421

# %%
df_rush_all = df_seasons_all.query("season_type == 'REG'")[["player_id", "season", "season_type", "carries", 
                                                            "rushing_yards", "rushing_tds", "rushing_first_downs", 
                                                            "rushing_epa", "games", "fantasy_points_ppr",
                                                            "receptions", "receiving_yards", "receiving_tds"
                                                           ]]

# %%
df_merged_one = df_rush_all.merge(
    df_roster_clean[['player_id', 'season', 'player_name', 'age']],
    on=['player_id', 'season'],
    how='left'
)

# %% [markdown]
# ## Over 400 Carries

# %%
rb_dict = {}
for index, row in df_touches_over_400.iterrows():
    season = row["season"]
    player_id = row["player_id"]

    df_one = df_merged_one.query(f"player_id == '{player_id}' and season == {season}")
    df_two = df_merged_one.query(f"player_id == '{player_id}' and season == {season + 1}")
    
    player = df_one["player_name"].iloc[0]
    age = df_one["age"].iloc[0]
    rb_dict[(player, season)] = {}

    if len(df_one) == 1 and len(df_two) == 1:
        games_0 = df_one['games'].iloc[0]
        games_1 = df_two['games'].iloc[0]

        games_diff = games_1 - games_0
        rb_dict[(player, season)]["games_diff"] = games_diff

        yards_0 = df_one['rushing_yards'].iloc[0]
        yards_1 = df_two['rushing_yards'].iloc[0]

        yards_diff = yards_1 - yards_0
        rb_dict[(player, season)]["yards_diff"] = yards_diff

        ff_0 = df_one["fantasy_points_ppr"].iloc[0]
        ff_1 = df_two["fantasy_points_ppr"].iloc[0]

        ff_diff = ff_1 - ff_0
        rb_dict[(player, season)]["fantasy_points_ppr"] = ff_diff

        rb_dict[(player, season)]["seasons"] = (season, season + 1)
        rb_dict[(player, season)]["age"] = (age, age + 1)

# %%
rb_dict
# Out:
# {('Tiki Barber', 2002): {'games_diff': -1,
#   'yards_diff': -172.0,
#   'fantasy_points_ppr': -76.79999999999998,
#   'seasons': (2002, 2003),
#   'age': (27.0, 28.0)},
#  ('Tiki Barber', 2005): {'games_diff': 0,
#   'yards_diff': -198.0,
#   'fantasy_points_ppr': -60.30000000000001,
#   'seasons': (2005, 2006),
#   'age': (30.0, 31.0)},
#  ('Tiki Barber', 2006): {},
#  ('Corey Dillon', 2004): {'games_diff': -5,
#   'yards_diff': -902.0,
#   'fantasy_points_ppr': -71.4,
#   'seasons': (2004, 2005),
#   'age': (29.0, 30.0)},
#  ('Marshall Faulk', 2001): {'games_diff': -3,
#   'yards_diff': -429.0,
#   'fantasy_points_ppr': -136.70000000000005,
#   'seasons': (2001, 2002),
#   'age': (28.0, 29.0)},
#  ('Eddie George', 1999): {'games_diff': -3,
#   'yards_diff': 178.0,
#   'fantasy_points_ppr': 37.299999999999955,
#   'seasons': (1999, 2000),
#   'age': (25.0, 26.0)},
#  ('Eddie George', 2000): {'games_diff': -1,
#   'yards_diff': -516.0,
#   'fantasy_points_ppr': -149.59999999999997,
#   'seasons': (2000, 2001),
#   'age': (26.0, 27.0)},
#  ('Eddie George', 2002): {'games_diff': 0,
#   'yards_diff': -134.0,
#   'fantasy_points_ppr': -90.6,
#   'seasons': (2002, 2003),
#   'age': (28.0, 29.0)},
#  ('Ahman Green', 2001): {'games_diff': -3,
#   'yards_diff': -147.0,
#   'fantasy_points_ppr': -49.80000000000001,
#   'seasons': (2001, 2002),
#   'age': (24.0, 25.0)},
#  ('Ahman Green', 2003): {'games_diff': -2,
#   'yards_diff': -720.0,
#   'fantasy_points_ppr': -156.4,
#   'seasons': (2003, 2004),
#   'age': (26.0, 27.0)},
#  ('Priest Holmes', 2003): {'games_diff': -9,
#   'yards_diff': -528.0,
#   'fantasy_points_ppr': -232.1,
#   'seasons': (2003, 2004),
#   'age': (29.0, 30.0)},
#  ('Edgerrin James', 1999): {'games_diff': 0,
#   'yards_diff': 216.0,
#   'fantasy_points_ppr': 27.80000000000001,
#   'seasons': (1999, 2000),
#   'age': (21.0, 22.0)},
#  ('Edgerrin James', 2000): {'games_diff': -11,
#   'yards_diff': -1028.0,
#   'fantasy_points_ppr': -262.6,
#   'seasons': (2000, 2001),
#   'age': (22.0, 23.0)},
#  ('Edgerrin James', 2003): {'games_diff': 2,
#   'yards_diff': 291.0,
#   'fantasy_points_ppr': 40.200000000000045,
#   'seasons': (2003, 2004),
#   'age': (25.0, 26.0)},
#  ('Edgerrin James', 2004): {'games_diff': -2,
#   'yards_diff': -42.0,
#   'fantasy_points_ppr': 4.199999999999989,
#   'seasons': (2004, 2005),
#   'age': (26.0, 27.0)},
#  ('Edgerrin James', 2005): {'games_diff': 0,
#   'yards_diff': -347.0,
#   'fantasy_points_ppr': -104.70000000000002,
#   'seasons': (2005, 2006),
#   'age': (27.0, 28.0)},
#  ('Curtis Martin', 1999): {'games_diff': 0,
#   'yards_diff': -297.0,
#   'fantasy_points_ppr': 56.32000000000002,
#   'seasons': (1999, 2000),
#   'age': (26.0, 27.0)},
#  ('Curtis Martin', 2001): {'games_diff': 1,
#   'yards_diff': -419.0,
#   'fantasy_points_ppr': -58.420000000000016,
#   'seasons': (2001, 2002),
#   'age': (28.0, 29.0)},
#  ('Curtis Martin', 2004): {'games_diff': -6,
#   'yards_diff': -962.0,
#   'fantasy_points_ppr': -181.89999999999998,
#   'seasons': (2004, 2005),
#   'age': (31.0, 32.0)},
#  ('Ricky Williams', 2002): {'games_diff': 0,
#   'yards_diff': -481.0,
#   'fantasy_points_ppr': -88.30000000000001,
#   'seasons': (2002, 2003),
#   'age': (25.0, 26.0)},
#  ('Ricky Williams', 2003): {},
#  ('Shaun Alexander', 2005): {'games_diff': -7,
#   'yards_diff': -984.0,
#   'fantasy_points_ppr': -234.4,
#   'seasons': (2005, 2006),
#   'age': (28.0, 29.0)},
#  ('Jamal Lewis', 2000): {},
#  ('Jamal Lewis', 2003): {'games_diff': -5,
#   'yards_diff': -1057.0,
#   'fantasy_points_ppr': -158.60000000000002,
#   'seasons': (2003, 2004),
#   'age': (24.0, 25.0)},
#  ('Deuce McAllister', 2003): {'games_diff': -2,
#   'yards_diff': -567.0,
#   'fantasy_points_ppr': -114.50000000000006,
#   'seasons': (2003, 2004),
#   'age': (24.0, 25.0)},
#  ('LaDainian Tomlinson', 2002): {'games_diff': 0,
#   'yards_diff': -38.0,
#   'fantasy_points_ppr': 59.64000000000004,
#   'seasons': (2002, 2003),
#   'age': (23.0, 24.0)},
#  ('LaDainian Tomlinson', 2003): {'games_diff': 0,
#   'yards_diff': -310.0,
#   'fantasy_points_ppr': -109.72000000000003,
#   'seasons': (2003, 2004),
#   'age': (24.0, 25.0)},
#  ('LaDainian Tomlinson', 2004): {'games_diff': 0,
#   'yards_diff': 129.0,
#   'fantasy_points_ppr': 32.15999999999997,
#   'seasons': (2004, 2005),
#   'age': (25.0, 26.0)},
#  ('LaDainian Tomlinson', 2006): {'games_diff': 2,
#   'yards_diff': -341.0,
#   'fantasy_points_ppr': -113.51999999999998,
#   'seasons': (2006, 2007),
#   'age': (27.0, 28.0)},
#  ('LaDainian Tomlinson', 2007): {'games_diff': -2,
#   'yards_diff': -364.0,
#   'fantasy_points_ppr': -90.48000000000002,
#   'seasons': (2007, 2008),
#   'age': (28.0, 29.0)},
#  ('Clinton Portis', 2005): {'games_diff': -10,
#   'yards_diff': -993.0,
#   'fantasy_points_ppr': -143.57999999999998,
#   'seasons': (2005, 2006),
#   'age': (23.0, 24.0)},
#  ('Larry Johnson', 2006): {'games_diff': -9,
#   'yards_diff': -1230.0,
#   'fantasy_points_ppr': -242.40000000000003,
#   'seasons': (2006, 2007),
#   'age': (26.0, 27.0)},
#  ('Steven Jackson', 2006): {'games_diff': -4,
#   'yards_diff': -526.0,
#   'fantasy_points_ppr': -214.02000000000004,
#   'seasons': (2006, 2007),
#   'age': (23.0, 24.0)},
#  ('Michael Turner', 2008): {'games_diff': -6,
#   'yards_diff': -828.0,
#   'fantasy_points_ppr': -126.39999999999998,
#   'seasons': (2008, 2009),
#   'age': (26.0, 27.0)},
#  ('Adrian Peterson', 2008): {'games_diff': 1,
#   'yards_diff': -368.0,
#   'fantasy_points_ppr': 60.30000000000001,
#   'seasons': (2008, 2009),
#   'age': (23.0, 24.0)},
#  ('Adrian Peterson', 2009): {'games_diff': -3,
#   'yards_diff': -91.0,
#   'fantasy_points_ppr': -45.599999999999966,
#   'seasons': (2009, 2010),
#   'age': (24.0, 25.0)},
#  ('Adrian Peterson', 2012): {'games_diff': -3,
#   'yards_diff': -831.0,
#   'fantasy_points_ppr': -114.69999999999996,
#   'seasons': (2012, 2013),
#   'age': (27.0, 28.0)},
#  ('Marshawn Lynch', 2013): {'games_diff': 0,
#   'yards_diff': 49.0,
#   'fantasy_points_ppr': 27.0,
#   'seasons': (2013, 2014),
#   'age': (27.0, 28.0)},
#  ('Rashard Mendenhall', 2010): {'games_diff': -4,
#   'yards_diff': -345.0,
#   'fantasy_points_ppr': -62.79999999999998,
#   'seasons': (2010, 2011),
#   'age': (23.0, 24.0)},
#  ('Chris Johnson', 2009): {'games_diff': 0,
#   'yards_diff': -642.0,
#   'fantasy_points_ppr': -120.0,
#   'seasons': (2009, 2010),
#   'age': (23.0, 24.0)},
#  ('Ray Rice', 2010): {'games_diff': 0,
#   'yards_diff': 144.0,
#   'fantasy_points_ppr': 96.24000000000001,
#   'seasons': (2010, 2011),
#   'age': (23.0, 24.0)},
#  ('Ray Rice', 2011): {'games_diff': 2,
#   'yards_diff': -221.0,
#   'fantasy_points_ppr': -89.74000000000001,
#   'seasons': (2011, 2012),
#   'age': (24.0, 25.0)},
#  ('Ray Rice', 2012): {'games_diff': -5,
#   'yards_diff': -483.0,
#   'fantasy_points_ppr': -105.00000000000003,
#   'seasons': (2012, 2013),
#   'age': (25.0, 26.0)},
#  ('Arian Foster', 2012): {'games_diff': -10,
#   'yards_diff': -882.0,
#   'fantasy_points_ppr': -193.60000000000002,
#   'seasons': (2012, 2013),
#   'age': (26.0, 27.0)},
#  ('DeMarco Murray', 2014): {'games_diff': -3,
#   'yards_diff': -1143.0,
#   'fantasy_points_ppr': -166.70000000000002,
#   'seasons': (2014, 2015),
#   'age': (26.0, 27.0)},
#  ("Le'Veon Bell", 2016): {'games_diff': 1,
#   'yards_diff': 23.0,
#   'fantasy_points_ppr': 26.000000000000057,
#   'seasons': (2016, 2017),
#   'age': (24.0, 25.0)},
#  ("Le'Veon Bell", 2017): {},
#  ('Derrick Henry', 2019): {'games_diff': -1,
#   'yards_diff': 487.0,
#   'fantasy_points_ppr': 38.5,
#   'seasons': (2019, 2020),
#   'age': (25.0, 26.0)},
#  ('Derrick Henry', 2020): {'games_diff': -8,
#   'yards_diff': -1090.0,
#   'fantasy_points_ppr': -139.8,
#   'seasons': (2020, 2021),
#   'age': (26.0, 27.0)},
#  ('Ezekiel Elliott', 2018): {'games_diff': -1,
#   'yards_diff': -77.0,
#   'fantasy_points_ppr': -17.399999999999977,
#   'seasons': (2018, 2019),
#   'age': (23.0, 24.0)},
#  ('Christian McCaffrey', 2019): {'games_diff': -13,
#   'yards_diff': -1162.0,
#   'fantasy_points_ppr': -380.80000000000007,
#   'seasons': (2019, 2020),
#   'age': (23.0, 24.0)},
#  ('Christian McCaffrey', 2023): {'games_diff': -15,
#   'yards_diff': -1257.0,
#   'fantasy_points_ppr': -343.5,
#   'seasons': (2023, 2024),
#   'age': (27.0, 28.0)},
#  ('Joe Mixon', 2021): {'games_diff': -3,
#   'yards_diff': -391.0,
#   'fantasy_points_ppr': -48.39999999999998,
#   'seasons': (2021, 2022),
#   'age': (25.0, 26.0)},
#  ('Saquon Barkley', 2024): {}}

# %%
for (player, season) in rb_dict:
    if rb_dict[(player, season)]:
        print(player, season, rb_dict[(player, season)]["age"])
        print(rb_dict[(player, season)]["fantasy_points_ppr"])
        print()
# Out:
# Tiki Barber 2002 (27.0, 28.0)
# -76.79999999999998
#
# Tiki Barber 2005 (30.0, 31.0)
# -60.30000000000001
#
# Corey Dillon 2004 (29.0, 30.0)
# -71.4
#
# Marshall Faulk 2001 (28.0, 29.0)
# -136.70000000000005
#
# Eddie George 1999 (25.0, 26.0)
# 37.299999999999955
#
# Eddie George 2000 (26.0, 27.0)
# -149.59999999999997
#
# Eddie George 2002 (28.0, 29.0)
# -90.6
#
# Ahman Green 2001 (24.0, 25.0)
# -49.80000000000001
#
# Ahman Green 2003 (26.0, 27.0)
# -156.4
#
# Priest Holmes 2003 (29.0, 30.0)
# -232.1
#
# Edgerrin James 1999 (21.0, 22.0)
# 27.80000000000001
#
# Edgerrin James 2000 (22.0, 23.0)
# -262.6
#
# Edgerrin James 2003 (25.0, 26.0)
# 40.200000000000045
#
# Edgerrin James 2004 (26.0, 27.0)
# 4.199999999999989
#
# Edgerrin James 2005 (27.0, 28.0)
# -104.70000000000002
#
# Curtis Martin 1999 (26.0, 27.0)
# 56.32000000000002
#
# Curtis Martin 2001 (28.0, 29.0)
# -58.420000000000016
#
# Curtis Martin 2004 (31.0, 32.0)
# -181.89999999999998
#
# Ricky Williams 2002 (25.0, 26.0)
# -88.30000000000001
#
# Shaun Alexander 2005 (28.0, 29.0)
# -234.4
#
# Jamal Lewis 2003 (24.0, 25.0)
# -158.60000000000002
#
# Deuce McAllister 2003 (24.0, 25.0)
# -114.50000000000006
#
# LaDainian Tomlinson 2002 (23.0, 24.0)
# 59.64000000000004
#
# LaDainian Tomlinson 2003 (24.0, 25.0)
# -109.72000000000003
#
# LaDainian Tomlinson 2004 (25.0, 26.0)
# 32.15999999999997
#
# LaDainian Tomlinson 2006 (27.0, 28.0)
# -113.51999999999998
#
# LaDainian Tomlinson 2007 (28.0, 29.0)
# -90.48000000000002
#
# Clinton Portis 2005 (23.0, 24.0)
# -143.57999999999998
#
# Larry Johnson 2006 (26.0, 27.0)
# -242.40000000000003
#
# Steven Jackson 2006 (23.0, 24.0)
# -214.02000000000004
#
# Michael Turner 2008 (26.0, 27.0)
# -126.39999999999998
#
# Adrian Peterson 2008 (23.0, 24.0)
# 60.30000000000001
#
# Adrian Peterson 2009 (24.0, 25.0)
# -45.599999999999966
#
# Adrian Peterson 2012 (27.0, 28.0)
# -114.69999999999996
#
# Marshawn Lynch 2013 (27.0, 28.0)
# 27.0
#
# Rashard Mendenhall 2010 (23.0, 24.0)
# -62.79999999999998
#
# Chris Johnson 2009 (23.0, 24.0)
# -120.0
#
# Ray Rice 2010 (23.0, 24.0)
# 96.24000000000001
#
# Ray Rice 2011 (24.0, 25.0)
# -89.74000000000001
#
# Ray Rice 2012 (25.0, 26.0)
# -105.00000000000003
#
# Arian Foster 2012 (26.0, 27.0)
# -193.60000000000002
#
# DeMarco Murray 2014 (26.0, 27.0)
# -166.70000000000002
#
# Le'Veon Bell 2016 (24.0, 25.0)
# 26.000000000000057
#
# Derrick Henry 2019 (25.0, 26.0)
# 38.5
#
# Derrick Henry 2020 (26.0, 27.0)
# -139.8
#
# Ezekiel Elliott 2018 (23.0, 24.0)
# -17.399999999999977
#
# Christian McCaffrey 2019 (23.0, 24.0)
# -380.80000000000007
#
# Christian McCaffrey 2023 (27.0, 28.0)
# -343.5
#
# Joe Mixon 2021 (25.0, 26.0)
# -48.39999999999998

# %% [markdown]
# ## Over 350 Carries

# %%
df_touches_over_350 = df_carries.query("touches >= 350")
df_touches_over_350.head()
# Out:
#       player_id  season  carries  receptions  games  touches
# 91   00-0000745    2002      330          74     17      404
# 93   00-0000745    2004      322          52     16      374
# 94   00-0000745    2005      370          57     17      427
# 95   00-0000745    2006      353          60     17      413
# 165  00-0001215    2000      352          13     16      365

# %%
rb_dict_350 = {}
for index, row in df_touches_over_350.iterrows():
    season = row["season"]
    player_id = row["player_id"]

    df_one = df_merged_one.query(f"player_id == '{player_id}' and season == {season}")
    df_two = df_merged_one.query(f"player_id == '{player_id}' and season == {season + 1}")
    
    player = df_one["player_name"].iloc[0]
    age = df_one["age"].iloc[0]
    rb_dict_350[(player, season)] = {}

    if len(df_one) == 1 and len(df_two) == 1:
        games_0 = df_one['games'].iloc[0]
        games_1 = df_two['games'].iloc[0]

        games_diff = games_1 - games_0
        rb_dict_350[(player, season)]["games_diff"] = games_diff

        yards_0 = df_one['rushing_yards'].iloc[0]
        yards_1 = df_two['rushing_yards'].iloc[0]

        yards_diff = yards_1 - yards_0
        rb_dict_350[(player, season)]["yards_diff"] = yards_diff

        ff_0 = df_one["fantasy_points_ppr"].iloc[0]
        ff_1 = df_two["fantasy_points_ppr"].iloc[0]

        ff_diff = ff_1 - ff_0
        rb_dict_350[(player, season)]["fantasy_points_ppr"] = ff_diff

        rb_dict_350[(player, season)]["seasons"] = (season, season + 1)
        rb_dict_350[(player, season)]["age"] = (age, age + 1)

# %%
rb_dict_350
# Out:
# {('Tiki Barber', 2002): {'games_diff': -1,
#   'yards_diff': -172.0,
#   'fantasy_points_ppr': -76.79999999999998,
#   'seasons': (2002, 2003),
#   'age': (27.0, 28.0)},
#  ('Tiki Barber', 2004): {'games_diff': 1,
#   'yards_diff': 342.0,
#   'fantasy_points_ppr': 11.399999999999977,
#   'seasons': (2004, 2005),
#   'age': (29.0, 30.0)},
#  ('Tiki Barber', 2005): {'games_diff': 0,
#   'yards_diff': -198.0,
#   'fantasy_points_ppr': -60.30000000000001,
#   'seasons': (2005, 2006),
#   'age': (30.0, 31.0)},
#  ('Tiki Barber', 2006): {},
#  ('Jerome Bettis', 2000): {'games_diff': -4,
#   'yards_diff': -230.0,
#   'fantasy_points_ppr': -49.620000000000005,
#   'seasons': (2000, 2001),
#   'age': (28.0, 29.0)},
#  ('Stephen Davis', 2000): {'games_diff': 1,
#   'yards_diff': 140.0,
#   'fantasy_points_ppr': -33.80000000000001,
#   'seasons': (2000, 2001),
#   'age': (26.0, 27.0)},
#  ('Stephen Davis', 2001): {'games_diff': -4,
#   'yards_diff': -612.0,
#   'fantasy_points_ppr': -58.50000000000003,
#   'seasons': (2001, 2002),
#   'age': (27.0, 28.0)},
#  ('Stephen Davis', 2003): {'games_diff': -16,
#   'yards_diff': -1352.0,
#   'fantasy_points_ppr': -201.9,
#   'seasons': (2003, 2004),
#   'age': (29.0, 30.0)},
#  ('Corey Dillon', 2001): {'games_diff': 0,
#   'yards_diff': -4.0,
#   'fantasy_points_ppr': -16.400000000000006,
#   'seasons': (2001, 2002),
#   'age': (26.0, 27.0)},
#  ('Corey Dillon', 2002): {'games_diff': -3,
#   'yards_diff': -770.0,
#   'fantasy_points_ppr': -157.7,
#   'seasons': (2002, 2003),
#   'age': (27.0, 28.0)},
#  ('Corey Dillon', 2004): {'games_diff': -5,
#   'yards_diff': -902.0,
#   'fantasy_points_ppr': -71.4,
#   'seasons': (2004, 2005),
#   'age': (29.0, 30.0)},
#  ('Marshall Faulk', 1999): {'games_diff': -3,
#   'yards_diff': 74.0,
#   'fantasy_points_ppr': 79.19999999999999,
#   'seasons': (1999, 2000),
#   'age': (26.0, 27.0)},
#  ('Marshall Faulk', 2001): {'games_diff': -3,
#   'yards_diff': -429.0,
#   'fantasy_points_ppr': -136.70000000000005,
#   'seasons': (2001, 2002),
#   'age': (28.0, 29.0)},
#  ('Eddie George', 1999): {'games_diff': -3,
#   'yards_diff': 178.0,
#   'fantasy_points_ppr': 37.299999999999955,
#   'seasons': (1999, 2000),
#   'age': (25.0, 26.0)},
#  ('Eddie George', 2000): {'games_diff': -1,
#   'yards_diff': -516.0,
#   'fantasy_points_ppr': -149.59999999999997,
#   'seasons': (2000, 2001),
#   'age': (26.0, 27.0)},
#  ('Eddie George', 2001): {'games_diff': 2,
#   'yards_diff': 226.0,
#   'fantasy_points_ppr': 85.19999999999999,
#   'seasons': (2001, 2002),
#   'age': (27.0, 28.0)},
#  ('Eddie George', 2002): {'games_diff': 0,
#   'yards_diff': -134.0,
#   'fantasy_points_ppr': -90.6,
#   'seasons': (2002, 2003),
#   'age': (28.0, 29.0)},
#  ('Eddie George', 2003): {'games_diff': -5,
#   'yards_diff': -599.0,
#   'fantasy_points_ppr': -88.9,
#   'seasons': (2003, 2004),
#   'age': (29.0, 30.0)},
#  ('Ahman Green', 2001): {'games_diff': -3,
#   'yards_diff': -147.0,
#   'fantasy_points_ppr': -49.80000000000001,
#   'seasons': (2001, 2002),
#   'age': (24.0, 25.0)},
#  ('Ahman Green', 2002): {'games_diff': 3,
#   'yards_diff': 643.0,
#   'fantasy_points_ppr': 116.69999999999999,
#   'seasons': (2002, 2003),
#   'age': (25.0, 26.0)},
#  ('Ahman Green', 2003): {'games_diff': -2,
#   'yards_diff': -720.0,
#   'fantasy_points_ppr': -156.4,
#   'seasons': (2003, 2004),
#   'age': (26.0, 27.0)},
#  ('Priest Holmes', 2001): {'games_diff': -2,
#   'yards_diff': 60.0,
#   'fantasy_points_ppr': 105.80000000000001,
#   'seasons': (2001, 2002),
#   'age': (27.0, 28.0)},
#  ('Priest Holmes', 2002): {'games_diff': 3,
#   'yards_diff': -195.0,
#   'fantasy_points_ppr': 4.300000000000011,
#   'seasons': (2002, 2003),
#   'age': (28.0, 29.0)},
#  ('Priest Holmes', 2003): {'games_diff': -9,
#   'yards_diff': -528.0,
#   'fantasy_points_ppr': -232.1,
#   'seasons': (2003, 2004),
#   'age': (29.0, 30.0)},
#  ('Edgerrin James', 1999): {'games_diff': 0,
#   'yards_diff': 216.0,
#   'fantasy_points_ppr': 27.80000000000001,
#   'seasons': (1999, 2000),
#   'age': (21.0, 22.0)},
#  ('Edgerrin James', 2000): {'games_diff': -11,
#   'yards_diff': -1028.0,
#   'fantasy_points_ppr': -262.6,
#   'seasons': (2000, 2001),
#   'age': (22.0, 23.0)},
#  ('Edgerrin James', 2003): {'games_diff': 2,
#   'yards_diff': 291.0,
#   'fantasy_points_ppr': 40.200000000000045,
#   'seasons': (2003, 2004),
#   'age': (25.0, 26.0)},
#  ('Edgerrin James', 2004): {'games_diff': -2,
#   'yards_diff': -42.0,
#   'fantasy_points_ppr': 4.199999999999989,
#   'seasons': (2004, 2005),
#   'age': (26.0, 27.0)},
#  ('Edgerrin James', 2005): {'games_diff': 0,
#   'yards_diff': -347.0,
#   'fantasy_points_ppr': -104.70000000000002,
#   'seasons': (2005, 2006),
#   'age': (27.0, 28.0)},
#  ('Edgerrin James', 2006): {'games_diff': 0,
#   'yards_diff': 73.0,
#   'fantasy_points_ppr': 4.200000000000017,
#   'seasons': (2006, 2007),
#   'age': (28.0, 29.0)},
#  ('Curtis Martin', 1999): {'games_diff': 0,
#   'yards_diff': -297.0,
#   'fantasy_points_ppr': 56.32000000000002,
#   'seasons': (1999, 2000),
#   'age': (26.0, 27.0)},
#  ('Curtis Martin', 2000): {'games_diff': 1,
#   'yards_diff': 357.0,
#   'fantasy_points_ppr': -5.5,
#   'seasons': (2000, 2001),
#   'age': (27.0, 28.0)},
#  ('Curtis Martin', 2001): {'games_diff': 1,
#   'yards_diff': -419.0,
#   'fantasy_points_ppr': -58.420000000000016,
#   'seasons': (2001, 2002),
#   'age': (28.0, 29.0)},
#  ('Curtis Martin', 2003): {'games_diff': 2,
#   'yards_diff': 389.0,
#   'fantasy_points_ppr': 112.19999999999999,
#   'seasons': (2003, 2004),
#   'age': (30.0, 31.0)},
#  ('Curtis Martin', 2004): {'games_diff': -6,
#   'yards_diff': -962.0,
#   'fantasy_points_ppr': -181.89999999999998,
#   'seasons': (2004, 2005),
#   'age': (31.0, 32.0)},
#  ('Antowain Smith', 2001): {'games_diff': -3,
#   'yards_diff': -175.0,
#   'fantasy_points_ppr': -22.400000000000006,
#   'seasons': (2001, 2002),
#   'age': (29.0, 30.0)},
#  ('Emmitt Smith', 1999): {'games_diff': 0,
#   'yards_diff': -195.0,
#   'fantasy_points_ppr': -67.5,
#   'seasons': (1999, 2000),
#   'age': (30.0, 31.0)},
#  ('Lamar Smith', 2000): {'games_diff': 1,
#   'yards_diff': -95.0,
#   'fantasy_points_ppr': -55.10000000000002,
#   'seasons': (2000, 2001),
#   'age': (29.0, 30.0)},
#  ('Lamar Smith', 2001): {'games_diff': -6,
#   'yards_diff': -231.0,
#   'fantasy_points_ppr': -39.79999999999998,
#   'seasons': (2001, 2002),
#   'age': (30.0, 31.0)},
#  ('Robert Smith', 2000): {},
#  ('Duce Staley', 1999): {'games_diff': -11,
#   'yards_diff': -926.0,
#   'fantasy_points_ppr': -143.89999999999998,
#   'seasons': (1999, 2000),
#   'age': (24.0, 25.0)},
#  ('Duce Staley', 2002): {'games_diff': 0,
#   'yards_diff': -572.0,
#   'fantasy_points_ppr': -100.1,
#   'seasons': (2002, 2003),
#   'age': (27.0, 28.0)},
#  ('James Stewart', 2000): {'games_diff': -5,
#   'yards_diff': -487.0,
#   'fantasy_points_ppr': -117.50000000000001,
#   'seasons': (2000, 2001),
#   'age': (28.0, 29.0)},
#  ('Fred Taylor', 2003): {},
#  ('Ricky Watters', 1999): {'games_diff': -1,
#   'yards_diff': 25.0,
#   'fantasy_points_ppr': 64.30000000000001,
#   'seasons': (1999, 2000),
#   'age': (30.0, 31.0)},
#  ('Ricky Williams', 2001): {'games_diff': 0,
#   'yards_diff': 608.0,
#   'fantasy_points_ppr': 95.0,
#   'seasons': (2001, 2002),
#   'age': (24.0, 25.0)},
#  ('Ricky Williams', 2002): {'games_diff': 0,
#   'yards_diff': -481.0,
#   'fantasy_points_ppr': -88.30000000000001,
#   'seasons': (2002, 2003),
#   'age': (25.0, 26.0)},
#  ('Ricky Williams', 2003): {},
#  ('Thomas Jones', 2005): {},
#  ('Thomas Jones', 2006): {},
#  ('Thomas Jones', 2009): {},
#  ('Shaun Alexander', 2001): {'games_diff': 0,
#   'yards_diff': -143.0,
#   'fantasy_points_ppr': 30.399999999999977,
#   'seasons': (2001, 2002),
#   'age': (24.0, 25.0)},
#  ('Shaun Alexander', 2002): {'games_diff': 1,
#   'yards_diff': 260.0,
#   'fantasy_points_ppr': -23.5,
#   'seasons': (2002, 2003),
#   'age': (25.0, 26.0)},
#  ('Shaun Alexander', 2003): {'games_diff': 0,
#   'yards_diff': 253.0,
#   'fantasy_points_ppr': 17.80000000000001,
#   'seasons': (2003, 2004),
#   'age': (26.0, 27.0)},
#  ('Shaun Alexander', 2004): {'games_diff': 2,
#   'yards_diff': 192.0,
#   'fantasy_points_ppr': 54.0,
#   'seasons': (2004, 2005),
#   'age': (27.0, 28.0)},
#  ('Shaun Alexander', 2005): {'games_diff': -7,
#   'yards_diff': -984.0,
#   'fantasy_points_ppr': -234.4,
#   'seasons': (2005, 2006),
#   'age': (28.0, 29.0)},
#  ('Jamal Lewis', 2000): {},
#  ('Jamal Lewis', 2002): {'games_diff': 1,
#   'yards_diff': 736.0,
#   'fantasy_points_ppr': 70.9,
#   'seasons': (2002, 2003),
#   'age': (23.0, 24.0)},
#  ('Jamal Lewis', 2003): {'games_diff': -5,
#   'yards_diff': -1057.0,
#   'fantasy_points_ppr': -158.60000000000002,
#   'seasons': (2003, 2004),
#   'age': (24.0, 25.0)},
#  ('Rudi Johnson', 2004): {'games_diff': 1,
#   'yards_diff': 1.0,
#   'fantasy_points_ppr': 16.69999999999999,
#   'seasons': (2004, 2005),
#   'age': (24.0, 25.0)},
#  ('Rudi Johnson', 2005): {'games_diff': -1,
#   'yards_diff': -150.0,
#   'fantasy_points_ppr': -15.599999999999994,
#   'seasons': (2005, 2006),
#   'age': (25.0, 26.0)},
#  ('Rudi Johnson', 2006): {'games_diff': -5,
#   'yards_diff': -811.0,
#   'fantasy_points_ppr': -138.5,
#   'seasons': (2006, 2007),
#   'age': (26.0, 27.0)},
#  ('Travis Henry', 2002): {'games_diff': -1,
#   'yards_diff': -85.0,
#   'fantasy_points_ppr': -50.599999999999994,
#   'seasons': (2002, 2003),
#   'age': (23.0, 24.0)},
#  ('Travis Henry', 2003): {'games_diff': -6,
#   'yards_diff': -1027.0,
#   'fantasy_points_ppr': -188.0,
#   'seasons': (2003, 2004),
#   'age': (24.0, 25.0)},
#  ('Deuce McAllister', 2002): {'games_diff': 1,
#   'yards_diff': 253.0,
#   'fantasy_points_ppr': 13.700000000000045,
#   'seasons': (2002, 2003),
#   'age': (23.0, 24.0)},
#  ('Deuce McAllister', 2003): {'games_diff': -2,
#   'yards_diff': -567.0,
#   'fantasy_points_ppr': -114.50000000000006,
#   'seasons': (2003, 2004),
#   'age': (24.0, 25.0)},
#  ('LaDainian Tomlinson', 2001): {'games_diff': 0,
#   'yards_diff': 447.0,
#   'fantasy_points_ppr': 114.89999999999998,
#   'seasons': (2001, 2002),
#   'age': (22.0, 23.0)},
#  ('LaDainian Tomlinson', 2002): {'games_diff': 0,
#   'yards_diff': -38.0,
#   'fantasy_points_ppr': 59.64000000000004,
#   'seasons': (2002, 2003),
#   'age': (23.0, 24.0)},
#  ('LaDainian Tomlinson', 2003): {'games_diff': 0,
#   'yards_diff': -310.0,
#   'fantasy_points_ppr': -109.72000000000003,
#   'seasons': (2003, 2004),
#   'age': (24.0, 25.0)},
#  ('LaDainian Tomlinson', 2004): {'games_diff': 0,
#   'yards_diff': 129.0,
#   'fantasy_points_ppr': 32.15999999999997,
#   'seasons': (2004, 2005),
#   'age': (25.0, 26.0)},
#  ('LaDainian Tomlinson', 2005): {'games_diff': 1,
#   'yards_diff': 351.0,
#   'fantasy_points_ppr': 114.82000000000005,
#   'seasons': (2005, 2006),
#   'age': (26.0, 27.0)},
#  ('LaDainian Tomlinson', 2006): {'games_diff': 2,
#   'yards_diff': -341.0,
#   'fantasy_points_ppr': -113.51999999999998,
#   'seasons': (2006, 2007),
#   'age': (27.0, 28.0)},
#  ('LaDainian Tomlinson', 2007): {'games_diff': -2,
#   'yards_diff': -364.0,
#   'fantasy_points_ppr': -90.48000000000002,
#   'seasons': (2007, 2008),
#   'age': (28.0, 29.0)},
#  ('Clinton Portis', 2004): {'games_diff': 3,
#   'yards_diff': 201.0,
#   'fantasy_points_ppr': 38.28,
#   'seasons': (2004, 2005),
#   'age': (22.0, 23.0)},
#  ('Clinton Portis', 2005): {'games_diff': -10,
#   'yards_diff': -993.0,
#   'fantasy_points_ppr': -143.57999999999998,
#   'seasons': (2005, 2006),
#   'age': (23.0, 24.0)},
#  ('Clinton Portis', 2007): {'games_diff': -1,
#   'yards_diff': 225.0,
#   'fantasy_points_ppr': -26.200000000000045,
#   'seasons': (2007, 2008),
#   'age': (25.0, 26.0)},
#  ('Clinton Portis', 2008): {'games_diff': -8,
#   'yards_diff': -993.0,
#   'fantasy_points_ppr': -172.4,
#   'seasons': (2008, 2009),
#   'age': (26.0, 27.0)},
#  ('Brian Westbrook', 2006): {'games_diff': -2,
#   'yards_diff': 116.0,
#   'fantasy_points_ppr': 39.799999999999955,
#   'seasons': (2006, 2007),
#   'age': (26.0, 27.0)},
#  ('Brian Westbrook', 2007): {'games_diff': 2,
#   'yards_diff': -397.0,
#   'fantasy_points_ppr': -100.59999999999997,
#   'seasons': (2007, 2008),
#   'age': (27.0, 28.0)},
#  ('Larry Johnson', 2005): {'games_diff': 1,
#   'yards_diff': 39.0,
#   'fantasy_points_ppr': 10.600000000000023,
#   'seasons': (2005, 2006),
#   'age': (25.0, 26.0)},
#  ('Larry Johnson', 2006): {'games_diff': -9,
#   'yards_diff': -1230.0,
#   'fantasy_points_ppr': -242.40000000000003,
#   'seasons': (2006, 2007),
#   'age': (26.0, 27.0)},
#  ('Domanick Williams', 2004): {'games_diff': -4,
#   'yards_diff': -204.0,
#   'fantasy_points_ppr': -118.30000000000001,
#   'seasons': (2004, 2005),
#   'age': (23.0, 24.0)},
#  ('Willis McGahee', 2005): {'games_diff': -2,
#   'yards_diff': -257.0,
#   'fantasy_points_ppr': -33.900000000000006,
#   'seasons': (2005, 2006),
#   'age': (23.0, 24.0)},
#  ('Willie Parker', 2006): {'games_diff': -1,
#   'yards_diff': -178.0,
#   'fantasy_points_ppr': -111.60000000000002,
#   'seasons': (2006, 2007),
#   'age': (25.0, 26.0)},
#  ('Steven Jackson', 2006): {'games_diff': -4,
#   'yards_diff': -526.0,
#   'fantasy_points_ppr': -214.02000000000004,
#   'seasons': (2006, 2007),
#   'age': (23.0, 24.0)},
#  ('Steven Jackson', 2009): {'games_diff': 1,
#   'yards_diff': -183.0,
#   'fantasy_points_ppr': -1.4000000000000057,
#   'seasons': (2009, 2010),
#   'age': (26.0, 27.0)},
#  ('Steven Jackson', 2010): {'games_diff': -1,
#   'yards_diff': -96.0,
#   'fantasy_points_ppr': -18.599999999999994,
#   'seasons': (2010, 2011),
#   'age': (27.0, 28.0)},
#  ('Michael Turner', 2008): {'games_diff': -6,
#   'yards_diff': -828.0,
#   'fantasy_points_ppr': -126.39999999999998,
#   'seasons': (2008, 2009),
#   'age': (26.0, 27.0)},
#  ('Michael Turner', 2010): {'games_diff': 0,
#   'yards_diff': -31.0,
#   'fantasy_points_ppr': 4.200000000000017,
#   'seasons': (2010, 2011),
#   'age': (28.0, 29.0)},
#  ('Frank Gore', 2006): {'games_diff': -1,
#   'yards_diff': -593.0,
#   'fantasy_points_ppr': -84.19999999999999,
#   'seasons': (2006, 2007),
#   'age': (23.0, 24.0)},
#  ('Frank Gore', 2012): {'games_diff': 0,
#   'yards_diff': -86.0,
#   'fantasy_points_ppr': -33.900000000000006,
#   'seasons': (2012, 2013),
#   'age': (29.0, 30.0)},
#  ('Joseph Addai', 2006): {'games_diff': -4,
#   'yards_diff': -9.0,
#   'fantasy_points_ppr': 52.00000000000003,
#   'seasons': (2006, 2007),
#   'age': (23.0, 24.0)},
#  ('Maurice Jones-Drew', 2009): {'games_diff': -2,
#   'yards_diff': -67.0,
#   'fantasy_points_ppr': -89.39999999999998,
#   'seasons': (2009, 2010),
#   'age': (24.0, 25.0)},
#  ('Maurice Jones-Drew', 2011): {'games_diff': -10,
#   'yards_diff': -1192.0,
#   'fantasy_points_ppr': -229.0,
#   'seasons': (2011, 2012),
#   'age': (26.0, 27.0)},
#  ('Adrian Peterson', 2008): {'games_diff': 1,
#   'yards_diff': -368.0,
#   'fantasy_points_ppr': 60.30000000000001,
#   'seasons': (2008, 2009),
#   'age': (23.0, 24.0)},
#  ('Adrian Peterson', 2009): {'games_diff': -3,
#   'yards_diff': -91.0,
#   'fantasy_points_ppr': -45.599999999999966,
#   'seasons': (2009, 2010),
#   'age': (24.0, 25.0)},
#  ('Adrian Peterson', 2012): {'games_diff': -3,
#   'yards_diff': -831.0,
#   'fantasy_points_ppr': -114.69999999999996,
#   'seasons': (2012, 2013),
#   'age': (27.0, 28.0)},
#  ('Adrian Peterson', 2015): {'games_diff': -14,
#   'yards_diff': -1413.0,
#   'fantasy_points_ppr': -251.7,
#   'seasons': (2015, 2016),
#   'age': (30.0, 31.0)},
#  ('Marshawn Lynch', 2012): {'games_diff': 1,
#   'yards_diff': -333.0,
#   'fantasy_points_ppr': 5.699999999999989,
#   'seasons': (2012, 2013),
#   'age': (26.0, 27.0)},
#  ('Marshawn Lynch', 2013): {'games_diff': 0,
#   'yards_diff': 49.0,
#   'fantasy_points_ppr': 27.0,
#   'seasons': (2013, 2014),
#   'age': (27.0, 28.0)},
#  ('Marshawn Lynch', 2014): {'games_diff': -11,
#   'yards_diff': -889.0,
#   'fantasy_points_ppr': -219.60000000000002,
#   'seasons': (2014, 2015),
#   'age': (28.0, 29.0)},
#  ('Rashard Mendenhall', 2010): {'games_diff': -4,
#   'yards_diff': -345.0,
#   'fantasy_points_ppr': -62.79999999999998,
#   'seasons': (2010, 2011),
#   'age': (23.0, 24.0)},
#  ('Chris Johnson', 2009): {'games_diff': 0,
#   'yards_diff': -642.0,
#   'fantasy_points_ppr': -120.0,
#   'seasons': (2009, 2010),
#   'age': (23.0, 24.0)},
#  ('Chris Johnson', 2010): {'games_diff': 0,
#   'yards_diff': -317.0,
#   'fantasy_points_ppr': -47.400000000000034,
#   'seasons': (2010, 2011),
#   'age': (24.0, 25.0)},
#  ('Matt Forte', 2008): {'games_diff': 0,
#   'yards_diff': -302.0,
#   'fantasy_points_ppr': -88.5,
#   'seasons': (2008, 2009),
#   'age': (22.0, 23.0)},
#  ('Matt Forte', 2013): {'games_diff': 0,
#   'yards_diff': -301.0,
#   'fantasy_points_ppr': 9.300000000000011,
#   'seasons': (2013, 2014),
#   'age': (27.0, 28.0)},
#  ('Matt Forte', 2014): {'games_diff': -3,
#   'yards_diff': -140.0,
#   'fantasy_points_ppr': -131.90000000000003,
#   'seasons': (2014, 2015),
#   'age': (28.0, 29.0)},
#  ('Ray Rice', 2009): {'games_diff': 0,
#   'yards_diff': -119.0,
#   'fantasy_points_ppr': -49.5,
#   'seasons': (2009, 2010),
#   'age': (22.0, 23.0)},
#  ('Ray Rice', 2010): {'games_diff': 0,
#   'yards_diff': 144.0,
#   'fantasy_points_ppr': 96.24000000000001,
#   'seasons': (2010, 2011),
#   'age': (23.0, 24.0)},
#  ('Ray Rice', 2011): {'games_diff': 2,
#   'yards_diff': -221.0,
#   'fantasy_points_ppr': -89.74000000000001,
#   'seasons': (2011, 2012),
#   'age': (24.0, 25.0)},
#  ('Ray Rice', 2012): {'games_diff': -5,
#   'yards_diff': -483.0,
#   'fantasy_points_ppr': -105.00000000000003,
#   'seasons': (2012, 2013),
#   'age': (25.0, 26.0)},
#  ('Arian Foster', 2010): {'games_diff': -1,
#   'yards_diff': -390.0,
#   'fantasy_points_ppr': -88.69999999999999,
#   'seasons': (2010, 2011),
#   'age': (24.0, 25.0)},
#  ('Arian Foster', 2011): {'games_diff': 3,
#   'yards_diff': 200.0,
#   'fantasy_points_ppr': -1.0,
#   'seasons': (2011, 2012),
#   'age': (25.0, 26.0)},
#  ('Arian Foster', 2012): {'games_diff': -10,
#   'yards_diff': -882.0,
#   'fantasy_points_ppr': -193.60000000000002,
#   'seasons': (2012, 2013),
#   'age': (26.0, 27.0)},
#  ('LeSean McCoy', 2013): {'games_diff': -1,
#   'yards_diff': -288.0,
#   'fantasy_points_ppr': -131.20000000000002,
#   'seasons': (2013, 2014),
#   'age': (25.0, 26.0)},
#  ('LeSean McCoy', 2017): {'games_diff': -3,
#   'yards_diff': -624.0,
#   'fantasy_points_ppr': -136.40000000000003,
#   'seasons': (2017, 2018),
#   'age': (29.0, 30.0)},
#  ('DeMarco Murray', 2014): {'games_diff': -3,
#   'yards_diff': -1143.0,
#   'fantasy_points_ppr': -166.70000000000002,
#   'seasons': (2014, 2015),
#   'age': (26.0, 27.0)},
#  ('Alfred Morris', 2012): {'games_diff': -1,
#   'yards_diff': -338.0,
#   'fantasy_points_ppr': -73.69999999999999,
#   'seasons': (2012, 2013),
#   'age': (23.0, 24.0)},
#  ('Doug Martin', 2012): {'games_diff': -10,
#   'yards_diff': -998.0,
#   'fantasy_points_ppr': -241.40000000000003,
#   'seasons': (2012, 2013),
#   'age': (23.0, 24.0)},
#  ('Lamar Miller', 2016): {'games_diff': 0,
#   'yards_diff': -185.0,
#   'fantasy_points_ppr': 2.4000000000000057,
#   'seasons': (2016, 2017),
#   'age': (25.0, 26.0)},
#  ("Le'Veon Bell", 2014): {'games_diff': -10,
#   'yards_diff': -805.0,
#   'fantasy_points_ppr': -259.29999999999995,
#   'seasons': (2014, 2015),
#   'age': (22.0, 23.0)},
#  ("Le'Veon Bell", 2016): {'games_diff': 1,
#   'yards_diff': 23.0,
#   'fantasy_points_ppr': 26.000000000000057,
#   'seasons': (2016, 2017),
#   'age': (24.0, 25.0)},
#  ("Le'Veon Bell", 2017): {},
#  ('David Johnson', 2016): {'games_diff': -15,
#   'yards_diff': -1216.0,
#   'fantasy_points_ppr': -394.8,
#   'seasons': (2016, 2017),
#   'age': (24.0, 25.0)},
#  ('Todd Gurley', 2017): {'games_diff': 1,
#   'yards_diff': -54.0,
#   'fantasy_points_ppr': -13.199999999999989,
#   'seasons': (2017, 2018),
#   'age': (23.0, 24.0)},
#  ('Derrick Henry', 2019): {'games_diff': -1,
#   'yards_diff': 487.0,
#   'fantasy_points_ppr': 38.5,
#   'seasons': (2019, 2020),
#   'age': (25.0, 26.0)},
#  ('Derrick Henry', 2020): {'games_diff': -8,
#   'yards_diff': -1090.0,
#   'fantasy_points_ppr': -139.8,
#   'seasons': (2020, 2021),
#   'age': (26.0, 27.0)},
#  ('Derrick Henry', 2022): {'games_diff': 1,
#   'yards_diff': -371.0,
#   'fantasy_points_ppr': -56.099999999999966,
#   'seasons': (2022, 2023),
#   'age': (28.0, 29.0)},
#  ('Derrick Henry', 2024): {},
#  ('Ezekiel Elliott', 2016): {'games_diff': -6,
#   'yards_diff': -648.0,
#   'fantasy_points_ppr': -122.20000000000005,
#   'seasons': (2016, 2017),
#   'age': (21.0, 22.0)},
#  ('Ezekiel Elliott', 2018): {'games_diff': -1,
#   'yards_diff': -77.0,
#   'fantasy_points_ppr': -17.399999999999977,
#   'seasons': (2018, 2019),
#   'age': (23.0, 24.0)},
#  ('Ezekiel Elliott', 2019): {'games_diff': -1,
#   'yards_diff': -378.0,
#   'fantasy_points_ppr': -88.00000000000003,
#   'seasons': (2019, 2020),
#   'age': (24.0, 25.0)},
#  ('Christian McCaffrey', 2019): {'games_diff': -13,
#   'yards_diff': -1162.0,
#   'fantasy_points_ppr': -380.80000000000007,
#   'seasons': (2019, 2020),
#   'age': (23.0, 24.0)},
#  ('Christian McCaffrey', 2022): {'games_diff': -1,
#   'yards_diff': 320.0,
#   'fantasy_points_ppr': 34.94,
#   'seasons': (2022, 2023),
#   'age': (26.0, 27.0)},
#  ('Christian McCaffrey', 2023): {'games_diff': -15,
#   'yards_diff': -1257.0,
#   'fantasy_points_ppr': -343.5,
#   'seasons': (2023, 2024),
#   'age': (27.0, 28.0)},
#  ('Leonard Fournette', 2017): {'games_diff': -8,
#   'yards_diff': -601.0,
#   'fantasy_points_ppr': -109.79999999999998,
#   'seasons': (2017, 2018),
#   'age': (22.0, 23.0)},
#  ('Dalvin Cook', 2020): {'games_diff': -1,
#   'yards_diff': -398.0,
#   'fantasy_points_ppr': -131.5,
#   'seasons': (2020, 2021),
#   'age': (25.0, 26.0)},
#  ('Joe Mixon', 2021): {'games_diff': -3,
#   'yards_diff': -391.0,
#   'fantasy_points_ppr': -48.39999999999998,
#   'seasons': (2021, 2022),
#   'age': (25.0, 26.0)},
#  ('Saquon Barkley', 2018): {'games_diff': -3,
#   'yards_diff': -304.0,
#   'fantasy_points_ppr': -141.7,
#   'seasons': (2018, 2019),
#   'age': (21.0, 22.0)},
#  ('Saquon Barkley', 2022): {'games_diff': -4,
#   'yards_diff': -350.0,
#   'fantasy_points_ppr': -60.79999999999998,
#   'seasons': (2022, 2023),
#   'age': (25.0, 26.0)},
#  ('Saquon Barkley', 2024): {},
#  ('Josh Jacobs', 2022): {'games_diff': -4,
#   'yards_diff': -848.0,
#   'fantasy_points_ppr': -147.20000000000002,
#   'seasons': (2022, 2023),
#   'age': (24.0, 25.0)},
#  ('Josh Jacobs', 2024): {},
#  ('Jonathan Taylor', 2021): {'games_diff': -6,
#   'yards_diff': -950.0,
#   'fantasy_points_ppr': -226.70000000000002,
#   'seasons': (2021, 2022),
#   'age': (22.0, 23.0)},
#  ('Najee Harris', 2021): {'games_diff': -1,
#   'yards_diff': -166.0,
#   'fantasy_points_ppr': -77.23999999999998,
#   'seasons': (2021, 2022),
#   'age': (23.0, 24.0)},
#  ('Rachaad White', 2023): {'games_diff': -3,
#   'yards_diff': -377.0,
#   'fantasy_points_ppr': -68.29999999999998,
#   'seasons': (2023, 2024),
#   'age': (24.0, 25.0)},
#  ('Kyren Williams', 2024): {},
#  ('Bijan Robinson', 2024): {}}

# %%
for (player, season) in rb_dict_350.keys():
    if rb_dict_350[(player, season)]:
        yards_diff = rb_dict_350[(player, season)]["yards_diff"]
        if yards_diff >= 0:
            print(player, season, rb_dict_350[(player, season)]["age"])
            print(yards_diff)
            print(rb_dict_350[(player, season)]["seasons"])
            print("-" * 50)
# Out:
# Tiki Barber 2004 (29.0, 30.0)
# 342.0
# (2004, 2005)
# --------------------------------------------------
# Stephen Davis 2000 (26.0, 27.0)
# 140.0
# (2000, 2001)
# --------------------------------------------------
# Marshall Faulk 1999 (26.0, 27.0)
# 74.0
# (1999, 2000)
# --------------------------------------------------
# Eddie George 1999 (25.0, 26.0)
# 178.0
# (1999, 2000)
# --------------------------------------------------
# Eddie George 2001 (27.0, 28.0)
# 226.0
# (2001, 2002)
# --------------------------------------------------
# Ahman Green 2002 (25.0, 26.0)
# 643.0
# (2002, 2003)
# --------------------------------------------------
# Priest Holmes 2001 (27.0, 28.0)
# 60.0
# (2001, 2002)
# --------------------------------------------------
# Edgerrin James 1999 (21.0, 22.0)
# 216.0
# (1999, 2000)
# --------------------------------------------------
# Edgerrin James 2003 (25.0, 26.0)
# 291.0
# (2003, 2004)
# --------------------------------------------------
# Edgerrin James 2006 (28.0, 29.0)
# 73.0
# (2006, 2007)
# --------------------------------------------------
# Curtis Martin 2000 (27.0, 28.0)
# 357.0
# (2000, 2001)
# --------------------------------------------------
# Curtis Martin 2003 (30.0, 31.0)
# 389.0
# (2003, 2004)
# --------------------------------------------------
# Ricky Watters 1999 (30.0, 31.0)
# 25.0
# (1999, 2000)
# --------------------------------------------------
# Ricky Williams 2001 (24.0, 25.0)
# 608.0
# (2001, 2002)
# --------------------------------------------------
# Shaun Alexander 2002 (25.0, 26.0)
# 260.0
# (2002, 2003)
# --------------------------------------------------
# Shaun Alexander 2003 (26.0, 27.0)
# 253.0
# (2003, 2004)
# --------------------------------------------------
# Shaun Alexander 2004 (27.0, 28.0)
# 192.0
# (2004, 2005)
# --------------------------------------------------
# Jamal Lewis 2002 (23.0, 24.0)
# 736.0
# (2002, 2003)
# --------------------------------------------------
# Rudi Johnson 2004 (24.0, 25.0)
# 1.0
# (2004, 2005)
# --------------------------------------------------
# Deuce McAllister 2002 (23.0, 24.0)
# 253.0
# (2002, 2003)
# --------------------------------------------------
# LaDainian Tomlinson 2001 (22.0, 23.0)
# 447.0
# (2001, 2002)
# --------------------------------------------------
# LaDainian Tomlinson 2004 (25.0, 26.0)
# 129.0
# (2004, 2005)
# --------------------------------------------------
# LaDainian Tomlinson 2005 (26.0, 27.0)
# 351.0
# (2005, 2006)
# --------------------------------------------------
# Clinton Portis 2004 (22.0, 23.0)
# 201.0
# (2004, 2005)
# --------------------------------------------------
# Clinton Portis 2007 (25.0, 26.0)
# 225.0
# (2007, 2008)
# --------------------------------------------------
# Brian Westbrook 2006 (26.0, 27.0)
# 116.0
# (2006, 2007)
# --------------------------------------------------
# Larry Johnson 2005 (25.0, 26.0)
# 39.0
# (2005, 2006)
# --------------------------------------------------
# Marshawn Lynch 2013 (27.0, 28.0)
# 49.0
# (2013, 2014)
# --------------------------------------------------
# Ray Rice 2010 (23.0, 24.0)
# 144.0
# (2010, 2011)
# --------------------------------------------------
# Arian Foster 2011 (25.0, 26.0)
# 200.0
# (2011, 2012)
# --------------------------------------------------
# Le'Veon Bell 2016 (24.0, 25.0)
# 23.0
# (2016, 2017)
# --------------------------------------------------
# Derrick Henry 2019 (25.0, 26.0)
# 487.0
# (2019, 2020)
# --------------------------------------------------
# Christian McCaffrey 2022 (26.0, 27.0)
# 320.0
# (2022, 2023)
# --------------------------------------------------

# %%
for (player, season) in rb_dict_350.keys():
    if rb_dict_350[(player, season)]:
        ff_diff = rb_dict_350[(player, season)]["fantasy_points_ppr"]
        if ff_diff >= 0:
            print(player, season, rb_dict_350[(player, season)]["age"])
            print(ff_diff)
            print(rb_dict_350[(player, season)]["seasons"])
            print("-" * 50)
# Out:
# Tiki Barber 2004 (29.0, 30.0)
# 11.399999999999977
# (2004, 2005)
# --------------------------------------------------
# Marshall Faulk 1999 (26.0, 27.0)
# 79.19999999999999
# (1999, 2000)
# --------------------------------------------------
# Eddie George 1999 (25.0, 26.0)
# 37.299999999999955
# (1999, 2000)
# --------------------------------------------------
# Eddie George 2001 (27.0, 28.0)
# 85.19999999999999
# (2001, 2002)
# --------------------------------------------------
# Ahman Green 2002 (25.0, 26.0)
# 116.69999999999999
# (2002, 2003)
# --------------------------------------------------
# Priest Holmes 2001 (27.0, 28.0)
# 105.80000000000001
# (2001, 2002)
# --------------------------------------------------
# Priest Holmes 2002 (28.0, 29.0)
# 4.300000000000011
# (2002, 2003)
# --------------------------------------------------
# Edgerrin James 1999 (21.0, 22.0)
# 27.80000000000001
# (1999, 2000)
# --------------------------------------------------
# Edgerrin James 2003 (25.0, 26.0)
# 40.200000000000045
# (2003, 2004)
# --------------------------------------------------
# Edgerrin James 2004 (26.0, 27.0)
# 4.199999999999989
# (2004, 2005)
# --------------------------------------------------
# Edgerrin James 2006 (28.0, 29.0)
# 4.200000000000017
# (2006, 2007)
# --------------------------------------------------
# Curtis Martin 1999 (26.0, 27.0)
# 56.32000000000002
# (1999, 2000)
# --------------------------------------------------
# Curtis Martin 2003 (30.0, 31.0)
# 112.19999999999999
# (2003, 2004)
# --------------------------------------------------
# Ricky Watters 1999 (30.0, 31.0)
# 64.30000000000001
# (1999, 2000)
# --------------------------------------------------
# Ricky Williams 2001 (24.0, 25.0)
# 95.0
# (2001, 2002)
# --------------------------------------------------
# Shaun Alexander 2001 (24.0, 25.0)
# 30.399999999999977
# (2001, 2002)
# --------------------------------------------------
# Shaun Alexander 2003 (26.0, 27.0)
# 17.80000000000001
# (2003, 2004)
# --------------------------------------------------
# Shaun Alexander 2004 (27.0, 28.0)
# 54.0
# (2004, 2005)
# --------------------------------------------------
# Jamal Lewis 2002 (23.0, 24.0)
# 70.9
# (2002, 2003)
# --------------------------------------------------
# Rudi Johnson 2004 (24.0, 25.0)
# 16.69999999999999
# (2004, 2005)
# --------------------------------------------------
# Deuce McAllister 2002 (23.0, 24.0)
# 13.700000000000045
# (2002, 2003)
# --------------------------------------------------
# LaDainian Tomlinson 2001 (22.0, 23.0)
# 114.89999999999998
# (2001, 2002)
# --------------------------------------------------
# LaDainian Tomlinson 2002 (23.0, 24.0)
# 59.64000000000004
# (2002, 2003)
# --------------------------------------------------
# LaDainian Tomlinson 2004 (25.0, 26.0)
# 32.15999999999997
# (2004, 2005)
# --------------------------------------------------
# LaDainian Tomlinson 2005 (26.0, 27.0)
# 114.82000000000005
# (2005, 2006)
# --------------------------------------------------
# Clinton Portis 2004 (22.0, 23.0)
# 38.28
# (2004, 2005)
# --------------------------------------------------
# Brian Westbrook 2006 (26.0, 27.0)
# 39.799999999999955
# (2006, 2007)
# --------------------------------------------------
# Larry Johnson 2005 (25.0, 26.0)
# 10.600000000000023
# (2005, 2006)
# --------------------------------------------------
# Michael Turner 2010 (28.0, 29.0)
# 4.200000000000017
# (2010, 2011)
# --------------------------------------------------
# Joseph Addai 2006 (23.0, 24.0)
# 52.00000000000003
# (2006, 2007)
# --------------------------------------------------
# Adrian Peterson 2008 (23.0, 24.0)
# 60.30000000000001
# (2008, 2009)
# --------------------------------------------------
# Marshawn Lynch 2012 (26.0, 27.0)
# 5.699999999999989
# (2012, 2013)
# --------------------------------------------------
# Marshawn Lynch 2013 (27.0, 28.0)
# 27.0
# (2013, 2014)
# --------------------------------------------------
# Matt Forte 2013 (27.0, 28.0)
# 9.300000000000011
# (2013, 2014)
# --------------------------------------------------
# Ray Rice 2010 (23.0, 24.0)
# 96.24000000000001
# (2010, 2011)
# --------------------------------------------------
# Lamar Miller 2016 (25.0, 26.0)
# 2.4000000000000057
# (2016, 2017)
# --------------------------------------------------
# Le'Veon Bell 2016 (24.0, 25.0)
# 26.000000000000057
# (2016, 2017)
# --------------------------------------------------
# Derrick Henry 2019 (25.0, 26.0)
# 38.5
# (2019, 2020)
# --------------------------------------------------
# Christian McCaffrey 2022 (26.0, 27.0)
# 34.94
# (2022, 2023)
# --------------------------------------------------

# %%
print(len(rb_dict_350.keys()))
# Out:
# 148

# %%
df_carries_over_350.query("player_id == '00-0025399'")

# %%
df_merged_one.query("player_name == 'Marshawn Lynch'")
