# %%
import plotly.express as px
import pandas as pd

# %% [markdown]
# # Data Creation

# %% [markdown]
# ## Source Data

# %%
df = pd.read_csv("./df_2020_2023.csv")
# Out:
# /var/folders/yx/gjm2fjs56vl5kkwrb6xf5d2h0000gn/T/ipykernel_22644/1352109313.py:1: DtypeWarning: Columns (46,180,181,183,184,188,189,190,191,194,195,196,197,198,199,204,205,206,207,214,215,216,217,218,219,220,221,223,225,227,234,235,236,237,238,239,244,245,246,249,250,254,255,256,261,263,264,267,268,269,270,278,284,285,303,333) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("./df_2020_2023.csv")

# %%
df_ngs = pd.read_csv("./df_ngs_2020_2023.csv")

# %% [markdown]
# ## QB Data

# %%
cols = [
    'desc',
    'season',
    'possession_team',
    'defteam',
    'offense_formation',
    'offense_personnel',
    'defenders_in_box',
    'defense_personnel',
    'number_of_pass_rushers',
    'players_on_play',
    'offense_players',
    'defense_players',
    'n_offense',
    'n_defense',
    'route',
    'defense_man_zone_type',
    'defense_coverage_type',
    'yards_gained',
    'no_huddle',
    'qb_dropback',
    'qb_kneel',
    'qb_spike',
    'qb_scramble',
    'pass_length',
    'pass_location',
    'ep',
    'epa',
    'td_prob',
    'qb_hit',
    'sack',
    'cp',
    'cpoe',
    'qb_epa',
    'xyac_epa',
    'xyac_mean_yardage',
    'xyac_median_yardage',
    'xyac_success',
    'time_to_throw',
    'was_pressure',
    'number_of_pass_rushers',
    'incomplete_pass',
    'passer_player_id',
    'passer_player_name',
    'passing_yards',
    'receiver_player_id',
    'receiver_player_name',
    'receiving_yards',
    'rusher_player_id',
    'rusher_player_name',
    'interception',
]

# %%
df_detailed = df.query("play_type == 'pass' and season_type=='REG' and penalty==0")[cols]
df_detailed.head(5)
# Out:
#                                                  desc  season possession_team  \
# 6   (12:39) (Shotgun) 10-J.Garoppolo pass short mi...    2020              SF
# 9   (11:50) (Shotgun) 1-K.Murray pass short left t...    2020             ARI
# 10  (11:24) (No Huddle, Shotgun) 1-K.Murray pass s...    2020             ARI
# 12  (10:58) (Shotgun) 1-K.Murray pass incomplete s...    2020             ARI
# 13  (10:55) (No Huddle, Shotgun) 1-K.Murray pass s...    2020             ARI
#
#    defteam offense_formation offense_personnel  defenders_in_box  \
# 6      ARI           SHOTGUN  1 RB, 1 TE, 3 WR               5.0
# 9       SF           SHOTGUN  1 RB, 1 TE, 3 WR               5.0
# 10      SF           SHOTGUN  1 RB, 2 TE, 2 WR               7.0
# 12      SF             EMPTY  1 RB, 1 TE, 3 WR               5.0
# 13      SF             EMPTY  1 RB, 0 TE, 4 WR               4.0
#
#    defense_personnel  number_of_pass_rushers  \
# 6   1 DL, 5 LB, 5 DB                     4.0
# 9   4 DL, 2 LB, 5 DB                     4.0
# 10  4 DL, 3 LB, 4 DB                     4.0
# 12  4 DL, 2 LB, 5 DB                     4.0
# 13  4 DL, 2 LB, 5 DB                     4.0
#
#                                       players_on_play  ... incomplete_pass  \
# 6   46078;38547;45069;46113;38551;41325;45185;4781...  ...             0.0
# 9   42389;47785;39973;38779;39965;44815;46166;4778...  ...             0.0
# 10  42389;47785;39973;38779;44815;39965;46166;4778...  ...             0.0
# 12  46203;42389;47785;39973;38779;39965;44815;4616...  ...             1.0
# 13  41249;46203;42389;47785;39973;38779;39965;4481...  ...             0.0
#
#    passer_player_id  passer_player_name  passing_yards receiver_player_id  \
# 6        00-0031345         J.Garoppolo           11.0         00-0033288
# 9        00-0035228            K.Murray            3.0         00-0030564
# 10       00-0035228            K.Murray            7.0         00-0022921
# 12       00-0035228            K.Murray            NaN         00-0022921
# 13       00-0035228            K.Murray           10.0         00-0022921
#
#    receiver_player_name receiving_yards  rusher_player_id  rusher_player_name  \
# 6              G.Kittle            11.0               NaN                 NaN
# 9             D.Hopkins             3.0               NaN                 NaN
# 10         L.Fitzgerald             7.0               NaN                 NaN
# 12         L.Fitzgerald             NaN               NaN                 NaN
# 13         L.Fitzgerald            10.0               NaN                 NaN
#
#     interception
# 6            0.0
# 9            0.0
# 10           0.0
# 12           0.0
# 13           0.0
#
# [5 rows x 50 columns]

# %%
df_qb = df_detailed.groupby(['possession_team', 'season']).agg({
    'yards_gained': ['mean'],
    'ep': ['mean'],
    'epa': ['mean'],
    'was_pressure': ['mean'],
    'time_to_throw': ['mean'],
    'qb_dropback': ['sum'],
    'cpoe': ['mean'],
    'qb_epa': ['mean'],
    'qb_hit': ['mean'],
    'sack': ['mean'],
    'interception': ['mean']
}).reset_index()

# %%
df_qb.columns = ['_'.join(col).strip() if isinstance(col, tuple) else col for col in df_qb.columns]

# %%
df_qb.head()
# Out:
#   possession_team_  season_  yards_gained_mean   ep_mean  epa_mean  \
# 0              ARI     2020           6.577966  1.929766  0.011524
# 1              ARI     2021           6.812500  2.020169  0.148297
# 2              ARI     2022           5.136558  1.754482 -0.114995
# 3              ARI     2023           4.897384  1.754786 -0.233787
# 4              ATL     2020           6.558912  2.110855  0.096755
#
#    was_pressure_mean  time_to_throw_mean  qb_dropback_sum  cpoe_mean  \
# 0           0.218247            2.713190            590.0   2.024577
# 1           0.232775            2.716082            576.0   5.175116
# 2           0.210769            2.580554            703.0  -1.661053
# 3           0.295154            2.799764            497.0  -3.676265
# 4           0.313916            2.872654            662.0   1.167432
#
#    qb_epa_mean  qb_hit_mean  sack_mean  interception_mean
# 0     0.037631     0.086441   0.049153           0.022034
# 1     0.156033     0.100694   0.064236           0.017361
# 2    -0.103800     0.125178   0.065434           0.022760
# 3    -0.233787     0.162978   0.076459           0.022133
# 4     0.111577     0.161631   0.061934           0.013595

# %%
df_qb.time_to_throw_mean.median()
# Out:
# 2.787819766955219

# %%
df_qb.was_pressure_mean.median()
# Out:
# 0.2983727670606398

# %%
df_qb.epa_mean.median()
# Out:
# 0.0015001145890955405

# %%
df_qb.cpoe_mean.median()
# Out:
# 0.16271523497983859

# %%
# still a producing qb even though we hang onto the ball too much => oline is good? or qb is so good at the pocket?
df_qb.query("qb_epa_mean >= 0 and cpoe_mean >= -0.81 and time_to_throw_mean > 2.78 and qb_dropback_sum >= 100 and was_pressure_mean <= 0.29")
# Out:
#     possession_team_  season_  yards_gained_mean   ep_mean  epa_mean  \
# 8                BAL     2020           6.326389  1.978933  0.090050
# 9                BAL     2021           5.954683  1.895935 -0.004825
# 13               BUF     2021           6.342679  2.283187  0.090858
# 14               BUF     2022           6.830000  2.164458  0.140236
# 15               BUF     2023           7.001764  2.052657  0.131708
# 28               CLE     2020           6.844488  2.043470  0.169362
# 48               HOU     2020           7.494949  2.206920  0.175756
# 60                KC     2020           7.338006  2.244939  0.245866
# 61                KC     2021           6.806916  2.289409  0.193329
# 62                KC     2022           7.417040  2.279024  0.246379
# 63                KC     2023           6.293220  2.034800  0.037933
# 65                LA     2021           7.184834  2.224967  0.158261
# 72                LV     2020           7.368607  2.293658  0.086416
# 73                LV     2021           6.768760  2.049432  0.016388
# 108              SEA     2020           6.476033  2.121254  0.116704
# 109              SEA     2021           6.275472  1.798720 -0.013994
#
#      was_pressure_mean  time_to_throw_mean  qb_dropback_sum  cpoe_mean  \
# 8             0.268170            2.945957            432.0   0.056861
# 9             0.288815            2.828776            662.0   0.346736
# 13            0.289902            2.890655            642.0   2.214961
# 14            0.275132            2.864594            600.0   0.442051
# 15            0.284658            2.894593            567.0   5.481893
# 28            0.228690            3.034988            508.0   2.367474
# 48            0.277778            2.853841            594.0   6.284282
# 60            0.273171            2.866229            642.0   2.441441
# 61            0.255639            2.838168            694.0   2.536501
# 62            0.264062            2.894819            669.0   2.825527
# 63            0.270796            2.952683            590.0   2.106463
# 65            0.252087            2.788718            633.0  -0.716219
# 72            0.289963            2.798879            567.0   2.104181
# 73            0.281967            2.802982            653.0   1.854664
# 108           0.281081            2.967872            605.0   6.665034
# 109           0.284232            2.827116            530.0   3.268831
#
#      qb_epa_mean  qb_hit_mean  sack_mean  interception_mean
# 8       0.090050     0.134259   0.074074           0.023148
# 9       0.005974     0.145015   0.084592           0.027190
# 13      0.097993     0.130841   0.037383           0.023364
# 14      0.161087     0.123333   0.053333           0.021667
# 15      0.163828     0.119929   0.040564           0.029982
# 28      0.189149     0.094488   0.051181           0.013780
# 48      0.203005     0.161616   0.084175           0.011785
# 60      0.274039     0.132399   0.037383           0.010903
# 61      0.205140     0.123919   0.040346           0.018732
# 62      0.266055     0.128550   0.038864           0.017937
# 63      0.071679     0.154237   0.042373           0.027119
# 65      0.158261     0.113744   0.048973           0.028436
# 72      0.120667     0.095238   0.049383           0.017637
# 73      0.038834     0.124043   0.061256           0.019908
# 108     0.128966     0.188430   0.079339           0.021488
# 109     0.005672     0.177358   0.086792           0.013208

# %%
# poor qb play, but with time to throw and low pressure
df_qb.query("qb_epa_mean < 0 and cpoe_mean < -0.81 and time_to_throw_mean > 2.78 and qb_dropback_sum >= 100 and was_pressure_mean <= 0.29")
# Out:
#    possession_team_  season_  yards_gained_mean   ep_mean  epa_mean  \
# 10              BAL     2022           5.833333  1.905782 -0.062212
# 18              CAR     2022           6.037267  1.794412 -0.113941
# 21              CHI     2021           5.224283  1.855027 -0.182269
# 29              CLE     2021           5.752228  1.867490 -0.057791
# 38              DEN     2022           5.672468  1.635388 -0.131573
# 75               LV     2023           5.568047  2.035634 -0.149486
#
#     was_pressure_mean  time_to_throw_mean  qb_dropback_sum  cpoe_mean  \
# 10           0.243187            2.893639            516.0  -1.640974
# 18           0.270089            2.799292            483.0  -5.181804
# 21           0.265537            2.791358            593.0  -2.949300
# 29           0.200393            2.784179            561.0  -2.131275
# 38           0.265845            2.940650            632.0  -1.567890
# 75           0.282979            2.790268            507.0  -4.983904
#
#     qb_epa_mean  qb_hit_mean  sack_mean  interception_mean
# 10    -0.031876     0.110465   0.073643           0.023256
# 18    -0.100406     0.120083   0.070393           0.026915
# 21    -0.182269     0.183811   0.097808           0.033727
# 29    -0.039661     0.135472   0.087344           0.021390
# 38    -0.131573     0.213608   0.099684           0.022152
# 75    -0.140490     0.138067   0.069034           0.035503

# %%
df_qb.query("qb_epa_mean >= 0 and cpoe_mean >= -0.81 and time_to_throw_mean <= 2.78 and qb_dropback_sum >= 100 and was_pressure_mean <= 0.29")
# Out:
#     possession_team_  season_  yards_gained_mean   ep_mean  epa_mean  \
# 0                ARI     2020           6.577966  1.929766  0.011524
