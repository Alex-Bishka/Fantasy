# %%
import plotly.express as px
import pandas as pd

# %% [markdown]
# # Data Creation

# %% [markdown]
# ## Source Data

# %%
df = pd.read_csv("./df_2020_2023.csv")
# Out:
# /var/folders/yx/gjm2fjs56vl5kkwrb6xf5d2h0000gn/T/ipykernel_18166/1352109313.py:1: DtypeWarning: Columns (46,180,181,183,184,188,189,190,191,194,195,196,197,198,199,204,205,206,207,214,215,216,217,218,219,220,221,223,225,227,234,235,236,237,238,239,244,245,246,249,250,254,255,256,261,263,264,267,268,269,270,278,284,285,303,333) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("./df_2020_2023.csv")

# %%
df_ngs = pd.read_csv("./df_ngs_2020_2023.csv")

# %% [markdown]
# ## QB Data

# %%
cols = [
    'desc',
    'season',
    'possession_team',
    'defteam',
    'offense_formation',
    'offense_personnel',
    'defenders_in_box',
    'defense_personnel',
    'number_of_pass_rushers',
    'players_on_play',
    'offense_players',
    'defense_players',
    'n_offense',
    'n_defense',
    'route',
    'defense_man_zone_type',
    'defense_coverage_type',
    'yards_gained',
    'no_huddle',
    'qb_dropback',
    'qb_kneel',
    'qb_spike',
    'qb_scramble',
    'pass_length',
    'pass_location',
    'ep',
    'epa',
    'td_prob',
    'qb_hit',
    'sack',
    'cp',
    'cpoe',
    'qb_epa',
    'xyac_epa',
    'xyac_mean_yardage',
    'xyac_median_yardage',
    'xyac_success',
    'time_to_throw',
    'was_pressure',
    'number_of_pass_rushers',
    'incomplete_pass',
    'passer_player_id',
    'passer_player_name',
    'passing_yards',
    'receiver_player_id',
    'receiver_player_name',
    'receiving_yards',
    'rusher_player_id',
    'rusher_player_name',
    'interception',
]

# %%
df_detailed = df.query("play_type == 'pass' and season_type=='REG' and penalty==0")[cols]
df_detailed.head(5)
# Out:
#                                                  desc  season possession_team  \
# 6   (12:39) (Shotgun) 10-J.Garoppolo pass short mi...    2020              SF
# 9   (11:50) (Shotgun) 1-K.Murray pass short left t...    2020             ARI
# 10  (11:24) (No Huddle, Shotgun) 1-K.Murray pass s...    2020             ARI
# 12  (10:58) (Shotgun) 1-K.Murray pass incomplete s...    2020             ARI
# 13  (10:55) (No Huddle, Shotgun) 1-K.Murray pass s...    2020             ARI
#
#    defteam offense_formation offense_personnel  defenders_in_box  \
# 6      ARI           SHOTGUN  1 RB, 1 TE, 3 WR               5.0
# 9       SF           SHOTGUN  1 RB, 1 TE, 3 WR               5.0
# 10      SF           SHOTGUN  1 RB, 2 TE, 2 WR               7.0
# 12      SF             EMPTY  1 RB, 1 TE, 3 WR               5.0
# 13      SF             EMPTY  1 RB, 0 TE, 4 WR               4.0
#
#    defense_personnel  number_of_pass_rushers  \
# 6   1 DL, 5 LB, 5 DB                     4.0
# 9   4 DL, 2 LB, 5 DB                     4.0
# 10  4 DL, 3 LB, 4 DB                     4.0
# 12  4 DL, 2 LB, 5 DB                     4.0
# 13  4 DL, 2 LB, 5 DB                     4.0
#
#                                       players_on_play  ... incomplete_pass  \
# 6   46078;38547;45069;46113;38551;41325;45185;4781...  ...             0.0
# 9   42389;47785;39973;38779;39965;44815;46166;4778...  ...             0.0
# 10  42389;47785;39973;38779;44815;39965;46166;4778...  ...             0.0
# 12  46203;42389;47785;39973;38779;39965;44815;4616...  ...             1.0
# 13  41249;46203;42389;47785;39973;38779;39965;4481...  ...             0.0
#
#    passer_player_id  passer_player_name  passing_yards receiver_player_id  \
# 6        00-0031345         J.Garoppolo           11.0         00-0033288
# 9        00-0035228            K.Murray            3.0         00-0030564
# 10       00-0035228            K.Murray            7.0         00-0022921
# 12       00-0035228            K.Murray            NaN         00-0022921
# 13       00-0035228            K.Murray           10.0         00-0022921
#
#    receiver_player_name receiving_yards  rusher_player_id  rusher_player_name  \
# 6              G.Kittle            11.0               NaN                 NaN
# 9             D.Hopkins             3.0               NaN                 NaN
# 10         L.Fitzgerald             7.0               NaN                 NaN
# 12         L.Fitzgerald             NaN               NaN                 NaN
# 13         L.Fitzgerald            10.0               NaN                 NaN
#
#     interception
# 6            0.0
# 9            0.0
# 10           0.0
# 12           0.0
# 13           0.0
#
# [5 rows x 50 columns]

# %%
df_qb = df_detailed.groupby(['passer_player_name', 'season']).agg({
    'possession_team': lambda x: x.mode(),
    'yards_gained': ['mean'],
    'ep': ['mean'],
    'epa': ['mean'],
    'was_pressure': ['mean'],
    'time_to_throw': ['mean'],
    'qb_dropback': ['sum'],
    'cpoe': ['mean'],
    'qb_epa': ['mean'],
    'qb_hit': ['mean'],
    'sack': ['mean'],
    'interception': ['mean']
}).reset_index()

# %%
df_qb.columns = ['_'.join(col).strip() if isinstance(col, tuple) else col for col in df_qb.columns]

# %%
df_qb.head()
# Out:
#   passer_player_name_  season_ possession_team_<lambda>  yards_gained_mean  \
# 0             A.Brown     2021                      TEN           0.000000
# 1             A.Brown     2022                      BAL           5.647059
# 2            A.Cooper     2022                      CLE           0.000000
# 3            A.Dalton     2020                      DAL           5.594366
# 4            A.Dalton     2021                      CHI           5.159363
#
#     ep_mean  epa_mean  was_pressure_mean  time_to_throw_mean  qb_dropback_sum  \
# 0  2.609933 -0.625729           1.000000            4.237500              2.0
# 1  1.195549 -0.376920           0.304348            2.574000             51.0
# 2  2.560719 -4.980503           1.000000            4.704000              1.0
# 3  2.249202 -0.023912           0.287009            2.501867            355.0
# 4  1.998448 -0.171837           0.217391            2.650422            251.0
#
#    cpoe_mean  qb_epa_mean  qb_hit_mean  sack_mean  interception_mean
# 0 -37.631195    -0.625729     0.000000   0.000000           0.000000
# 1 -18.991172    -0.287440     0.176471   0.098039           0.039216
# 2 -43.077034    -4.980503     1.000000   0.000000           1.000000
# 3  -0.178714    -0.012627     0.135211   0.067606           0.022535
# 4  -4.576461    -0.171837     0.119522   0.071713           0.035857

# %%
df_qb.time_to_throw_mean.median()
# Out:
# 2.780287403903016

# %%
df_qb.was_pressure_mean.median()
# Out:
# 0.29045112781954885

# %%
# still a producing qb even though we hang onto the ball too much => oline is good? or qb is so good at the pocket?
df_qb.query("qb_epa_mean >= 0 and cpoe_mean >= -0.81 and time_to_throw_mean > 2.78 and qb_dropback_sum >= 100 and was_pressure_mean <= 0.29")
df_qb.query("qb_epa_mean < 0 and cpoe_mean < -0.81 and time_to_throw_mean > 2.78 and qb_dropback_sum >= 100 and was_pressure_mean <= 0.29")
# Out:
#     passer_player_name_  season_ possession_team_<lambda>  yards_gained_mean  \
# 44           B.Mayfield     2021                      CLE           5.835526
# 45           B.Mayfield     2022                      CAR           5.238227
# 139              D.Lock     2020                      DEN           6.037199
# 140              D.Lock     2021                      DEN           6.008547
# 161            D.Watson     2022                      CLE           5.245989
# 166             E.Stick     2023                      LAC           5.407609
# 222            J.Flacco     2023                      CLE           7.347619
# 297            K.Murray     2023                      ARI           5.813149
# 342          M.Trubisky     2023                      PIT           5.192982
# 393            R.Wilson     2022                      DEN           5.864060
# 427            T.DeVito     2023                      NYG           4.240566
# 431          T.Heinicke     2023                      ATL           5.791367
#
#       ep_mean  epa_mean  was_pressure_mean  time_to_throw_mean  \
# 44   1.844107 -0.050655           0.182927            2.813251
# 45   1.803767 -0.160748           0.257669            2.821433
# 139  1.858903 -0.104427           0.283410            2.867751
# 140  1.594874 -0.121558           0.244898            2.875500
# 161  1.854325 -0.164631           0.287425            3.275078
# 166  1.819766 -0.184528           0.220930            2.859337
# 222  1.733744 -0.060730           0.281250            2.983119
# 297  1.812136 -0.057239           0.224852            2.820497
# 342  1.353901 -0.159647           0.264151            2.823736
# 393  1.566905 -0.104444           0.261954            2.981771
# 427  1.521042 -0.245449           0.254335            2.978705
# 431  1.665654 -0.064552           0.246575            2.824329
#
#      qb_dropback_sum  cpoe_mean  qb_epa_mean  qb_hit_mean  sack_mean  \
# 44             456.0  -2.907654    -0.028351     0.127193   0.094298
# 45             361.0  -7.723567    -0.142638     0.144044   0.094183
# 139            457.0  -5.922013    -0.076640     0.131291   0.041575
# 140            117.0  -4.187433    -0.121558     0.136752   0.076923
# 161            187.0  -3.419167    -0.131046     0.160428   0.106952
# 166            184.0  -4.728113    -0.184528     0.135870   0.076087
# 222            210.0  -3.182973    -0.012417     0.095238   0.038095
# 297            289.0  -2.277090    -0.057239     0.107266   0.062284
# 342            114.0  -2.235356    -0.159647     0.157895   0.061404
# 393            537.0  -1.240596    -0.104444     0.221601   0.102421
# 427            212.0  -3.418237    -0.245449     0.207547   0.174528
# 431            139.0  -9.987483    -0.064552     0.151079   0.057554
#
#      interception_mean
# 44            0.026316
# 45            0.022161
# 139           0.032823
# 140           0.017094
# 161           0.026738
# 166           0.005435
# 222           0.038095
# 297           0.017301
# 342           0.043860
# 393           0.020484
# 427           0.014151
# 431           0.028777

# %%
df_qb.query("qb_epa_mean >= 0 and cpoe_mean >= -0.81 and time_to_throw_mean <= 2.78 and qb_dropback_sum >= 100 and was_pressure_mean <= 0.29")
# Out:
#     passer_player_name_  season_ possession_team_<lambda>  yards_gained_mean  \
# 5              A.Dalton     2022                       NO           6.615960
# 16            A.Rodgers     2020                       GB           7.571695
# 17            A.Rodgers     2021                       GB           7.475524
# 23           Aa.Rodgers     2021                       GB           6.479401
# 90              C.McCoy     2021                      ARI           6.750000
# 17             286.0   5.839904     0.295962     0.111888   0.045455
# 23             267.0   5.121603     0.133596     0.146067   0.063670
# 90             104.0   3.431949     0.132458     0.163462   0.057692
# 120            396.0   1.172044     0.168352     0.106061   0.032828
# 150            623.0   2.071974     0.164503     0.117175   0.048154
# 152            625.0   3.677015     0.177450     0.137600   0.062400
# 170            116.0   7.868897     0.127024     0.146552   0.077586
# 198            424.0   1.628989     0.092919     0.176887   0.075472
# 199            560.0   6.671846     0.150780     0.175000   0.089286
# 200            641.0   2.460082     0.123831     0.126365   0.063963
# 226            149.0   0.480585     0.176158     0.167785   0.073826
# 227            459.0   2.302559     0.186104     0.137255   0.063181
# 231            567.0   0.571496     0.044989     0.128748   0.040564
# 244            494.0   2.512433     0.126228     0.109312   0.074899
# 257            605.0   1.035240     0.139017     0.122314   0.049587
# 294            571.0   2.102246     0.055353     0.084063   0.047285
# 295            510.0   4.043254     0.120688     0.082353   0.060784
# 322            545.0   2.120171     0.085625     0.137615   0.051376
# 339            314.0   0.943638     0.079729     0.117834   0.057325
# 341            189.0   0.919285     0.023365     0.105820   0.058201
# 370            557.0   0.614579     0.180842     0.093357   0.032316
# 383            278.0   2.641730     0.146682     0.151079   0.050360
# 420            614.0   3.199299     0.195003     0.115635   0.034202
# 421            735.0   1.943683     0.208074     0.076190   0.029932
# 422            754.0   0.399398     0.080290     0.099469   0.027851
# 424            515.0   3.971701     0.050377     0.128155   0.058252
# 456            403.0   1.736860     0.045492     0.101737   0.049628
# 457            416.0   1.061031     0.220997     0.098558   0.050481
# 458            582.0   4.090291     0.179027     0.097938   0.049828
#
#      interception_mean
# 5             0.022444
# 16            0.009311
# 17            0.003497
# 23            0.011236
# 90            0.009615
# 120           0.015152
# 150           0.014446
# 152           0.014400
# 170           0.025862
# 198           0.011792
# 199           0.023214
# 200           0.017161
# 226           0.026846
# 227           0.026144
# 231           0.022928
# 244           0.012146
# 257           0.016529
# 294           0.021016
# 295           0.019608
# 322           0.023853
# 339           0.025478
# 341           0.026455
# 370           0.019749
# 383           0.028777
# 420           0.019544
# 421           0.014966
# 422           0.011936
# 424           0.021359
# 456           0.024814
# 457           0.019231
# 458           0.024055

# %%
df_qb.query("passer_player_name_ == 'J.Fields'")
# Out:
#     passer_player_name_  season_ possession_team_<lambda>  yards_gained_mean  \
# 216            J.Fields     2021                      CHI           5.304636
# 217            J.Fields     2022                      CHI           5.013298
# 218            J.Fields     2023                      CHI           5.447689
#
#       ep_mean  epa_mean  was_pressure_mean  time_to_throw_mean  \
# 216  1.693101 -0.215284           0.308271            2.899297
# 217  1.837576 -0.220375           0.337539            3.126871
# 218  2.035977 -0.091770           0.460481            3.171828
#
#      qb_dropback_sum  cpoe_mean  qb_epa_mean  qb_hit_mean  sack_mean  \
# 216            302.0  -2.010652    -0.215284     0.231788   0.119205
# 217            376.0  -2.563978    -0.176433     0.215426   0.146277
# 218            411.0   0.848188    -0.072998     0.182482   0.104623
#
#      interception_mean
# 216           0.033113
# 217           0.029255
# 218           0.019465
