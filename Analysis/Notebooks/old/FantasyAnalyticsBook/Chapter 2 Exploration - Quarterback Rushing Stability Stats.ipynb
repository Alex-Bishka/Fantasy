# %% [markdown]
# # Imports

# %%
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
import numpy as np

# %%
import nfl_data_py as nfl

# %% [markdown]
# # Grabbing Data

# %%
seasons = range(2016, 2023 + 1)
df_pbp = nfl.import_pbp_data(seasons)
# Out:
# 2016 done.
# 2017 done.
# 2018 done.
# 2019 done.
# 2020 done.
# 2021 done.
# 2022 done.
# 2023 done.
# Downcasting floats.

# %% [markdown]
# # Grabbing Only Pass Data

# %% [markdown]
# Cleaning and creating our dedicated passing dataframe:

# %%
df_passes = df_pbp.query("play_type == 'pass' & air_yards.notnull() & season_type == 'REG'").reset_index()

# %%
df_passes.head()
# Out:
#    index  play_id          game_id old_game_id home_team away_team  \
# 0      3     85.0  2016_01_BUF_BAL  2016091101       BAL       BUF
# 1      5    130.0  2016_01_BUF_BAL  2016091101       BAL       BUF
# 2      9    216.0  2016_01_BUF_BAL  2016091101       BAL       BUF
# 3     11    261.0  2016_01_BUF_BAL  2016091101       BAL       BUF
# 4     13    310.0  2016_01_BUF_BAL  2016091101       BAL       BUF
#
#   season_type  week posteam posteam_type  ... offense_formation  \
# 0         REG     1     BAL         home  ...           SHOTGUN
# 1         REG     1     BAL         home  ...            I_FORM
# 2         REG     1     BUF         away  ...           SHOTGUN
# 3         REG     1     BUF         away  ...           SHOTGUN
# 4         REG     1     BAL         home  ...           SHOTGUN
#
#   offense_personnel  defenders_in_box defense_personnel  \
# 0  2 RB, 1 TE, 2 WR               6.0  4 DL, 3 LB, 4 DB
# 1  2 RB, 1 TE, 2 WR               7.0  4 DL, 3 LB, 4 DB
# 2  1 RB, 2 TE, 2 WR               7.0  3 DL, 4 LB, 4 DB
# 3  1 RB, 1 TE, 3 WR               6.0  1 DL, 5 LB, 5 DB
# 4  1 RB, 2 TE, 2 WR               7.0  4 DL, 3 LB, 4 DB
#
#    number_of_pass_rushers                                    players_on_play  \
# 0                     3.0  41302;40078;38540;35553;43295;38582;40053;4336...
# 1                     5.0  40078;38540;41302;35553;38582;43295;40053;4336...
# 2                     4.0  34479;40111;41277;37249;41230;36089;37100;3567...
# 3                     3.0  34479;40111;41277;37249;41230;36089;40112;3710...
# 4                     4.0  38540;41302;35553;38582;43295;40053;43369;4011...
#
#                                      offense_players  \
# 0  00-0029892;00-0027714;00-0032965;00-0029893;00...
# 1  00-0029892;00-0027714;00-0032965;00-0029893;00...
# 2  00-0027004;00-0030046;00-0028112;00-0031325;00...
# 3  00-0027004;00-0030046;00-0028112;00-0031325;00...
# 4  00-0027714;00-0032965;00-0029893;00-0026223;00...
#
#                                      defense_players  n_offense  n_defense
# 0  00-0031171;00-0029542;00-0029566;00-0030073;00...       11.0       11.0
# 1  00-0029542;00-0031171;00-0029566;00-0030073;00...       11.0       11.0
# 2  00-0031170;00-0027560;00-0027965;00-0031296;00...       11.0       10.0
# 3  00-0031170;00-0027560;00-0027965;00-0031296;00...       10.0       10.0
# 4  00-0029542;00-0031171;00-0029566;00-0030073;00...       11.0       11.0
#
# [5 rows x 385 columns]

# %% [markdown]
# Distinguishing between long and short passes.

# %%
df_passes["pass_length_air_yards"] = np.where(
      df_passes["air_yards"] >= 20, "long", "short"
)

# %% [markdown]
# Setting null yardage values to 0

# %%
df_passes["passing_yards"] = np.where(
          df_passes["passing_yards"].isnull(), 0,
          df_passes["passing_yards"]
        )

# %% [markdown]
# Accumulating the play by play stats into season stats

# %%
df_passing_yards_by_season = df_passes \
    .groupby(["passer_id", "passer", "season"]) \
    .agg({"passing_yards": ["sum", "count", "mean"], "epa": ["sum"],
          "pass_touchdown": ["sum"], "complete_pass": ["sum"]}
    )

# %%
df_passing_yards_by_season.head()
# Out:
#                           passing_yards                         epa  \
#                                     sum count      mean         sum
# passer_id  passer  season
# 00-0019596 T.Brady 2016          3554.0   431  8.245939  157.785248
#                    2017          4577.0   581  7.877797  201.057358
#                    2018          4355.0   568  7.667253  125.592216
#                    2019          4057.0   613  6.618271   64.109032
#                    2020          4633.0   606  7.645215  154.740570
#
#                           pass_touchdown complete_pass
#                                      sum           sum
# passer_id  passer  season
# 00-0019596 T.Brady 2016             28.0         291.0
#                    2017             32.0         385.0
#                    2018             29.0         375.0
#                    2019             24.0         373.0
#                    2020             40.0         401.0

# %%
df_passing_yards_by_season.columns = list(map("_".join, df_passing_yards_by_season.columns))
df_passing_yards_by_season.reset_index(inplace=True)

# %%
new_cols = ["passer_id", "passer", "season", "passing_yards", "passing_attempts", "yards_per_pass", "total_epa",
            "passing_touchdowns", "completions"]
df_passing_yards_by_season.columns = new_cols

# %%
df_passing_yards_by_season.head()
# Out:
#     passer_id   passer  season  passing_yards  passing_attempts  \
# 0  00-0019596  T.Brady    2016         3554.0               431
# 1  00-0019596  T.Brady    2017         4577.0               581
# 2  00-0019596  T.Brady    2018         4355.0               568
# 3  00-0019596  T.Brady    2019         4057.0               613
# 4  00-0019596  T.Brady    2020         4633.0               606
#
#    yards_per_pass   total_epa  passing_touchdowns  completions
# 0        8.245939  157.785248                28.0        291.0
# 1        7.877797  201.057358                32.0        385.0
# 2        7.667253  125.592216                29.0        375.0
# 3        6.618271   64.109032                24.0        373.0
# 4        7.645215  154.740570                40.0        401.0

# %% [markdown]
# # Grabbing Rushing Stats

# %% [markdown]
# We needed the pass data to filter out other players in non-QB position groups who mave have throw a pass.

# %%
df_runs = df_pbp.query("play_type == 'run' & season_type == 'REG' & rusher_id.notnull()").reset_index()

# %%
df_passing_yards_by_season
# Out:
#       passer_id        passer  season  Passing Yards  Passing Attempts  \
# 0    00-0019596       T.Brady    2016         3554.0               431
# 1    00-0019596       T.Brady    2017         4577.0               581
# 2    00-0019596       T.Brady    2018         4355.0               568
# 3    00-0019596       T.Brady    2019         4057.0               613
# 4    00-0019596       T.Brady    2020         4633.0               606
# ..          ...           ...     ...            ...               ...
# 806  00-0038598        J.Hall    2023          101.0                10
# 807  00-0039150       B.Young    2023         2055.0               381
# 808  00-0039152       W.Levis    2023         1266.0               183
# 809  00-0039163      C.Stroud    2023         3540.0               412
# 810  00-0039164  A.Richardson    2023          577.0                84
#
#      Yards Per Pass   Total EPA  Passing Touchdowns  Completions
# 0          8.245939  157.785248                28.0        291.0
# 1          7.877797  201.057358                32.0        385.0
# 2          7.667253  125.592216                29.0        375.0
# 3          6.618271   64.109032                24.0        373.0
# 4          7.645215  154.740570                40.0        401.0
# ..              ...         ...                 ...          ...
# 806       10.100000    5.916939                 0.0          8.0
# 807        5.393701  -21.672869                 9.0        231.0
# 808        6.918033   17.122780                 7.0        107.0
# 809        8.592233  116.298828                20.0        265.0
# 810        6.869048    8.817724                 3.0         50.0
#
# [811 rows x 9 columns]

# %%
# Extract unique passer IDs from the passing DataFrame
unique_passer_ids = df_passing_yards_by_season.query("Completions > 25")['passer_id'].unique()

# %%
# Filter the rushing DataFrame to only include rows where the rushing_id is in the unique_passer_ids
df_runs_qb = df_runs[df_runs['rusher_id'].isin(unique_passer_ids)]

# %%
df_runs_qb
# Out:
#         index  play_id          game_id old_game_id home_team away_team  \
# 4          19    450.0  2016_01_BUF_BAL  2016091101       BAL       BUF
# 20         65   1478.0  2016_01_BUF_BAL  2016091101       BAL       BUF
# 32        103   2316.0  2016_01_BUF_BAL  2016091101       BAL       BUF
# 63        204   1018.0  2016_01_CAR_DEN  2016090800       DEN       CAR
# 64        209   1119.0  2016_01_CAR_DEN  2016090800       DEN       CAR
# ...       ...      ...              ...         ...       ...       ...
# 97787  375215   1725.0   2023_13_SF_PHI  2023120309       PHI        SF
# 97796  375245   2466.0   2023_13_SF_PHI  2023120309       PHI        SF
# 97797  375248   2543.0   2023_13_SF_PHI  2023120309       PHI        SF
# 97798  375249   2565.0   2023_13_SF_PHI  2023120309       PHI        SF
# 97809  375284   3378.0   2023_13_SF_PHI  2023120309       PHI        SF
#
#       season_type  week posteam posteam_type  ... offense_formation  \
# 4             REG     1     BAL         home  ...           SHOTGUN
# 20            REG     1     BUF         away  ...             JUMBO
# 32            REG     1     BUF         away  ...           SHOTGUN
# 63            REG     1     CAR         away  ...            PISTOL
# 64            REG     1     CAR         away  ...           SHOTGUN
# ...           ...   ...     ...          ...  ...               ...
# 97787         REG    13      SF         away  ...        SINGLEBACK
# 97796         REG    13     PHI         home  ...           SHOTGUN
# 97797         REG    13     PHI         home  ...             JUMBO
# 97798         REG    13     PHI         home  ...             JUMBO
# 97809         REG    13     PHI         home  ...             JUMBO
#
#             offense_personnel  defenders_in_box defense_personnel  \
# 4            1 RB, 2 TE, 2 WR               6.0  3 DL, 3 LB, 5 DB
# 20     6 OL, 2 RB, 2 TE, 0 WR               9.0  4 DL, 4 LB, 3 DB
# 32           1 RB, 1 TE, 3 WR               7.0  2 DL, 4 LB, 5 DB
# 63           1 RB, 1 TE, 3 WR               6.0  3 DL, 4 LB, 4 DB
# 64           1 RB, 1 TE, 3 WR               6.0  3 DL, 4 LB, 4 DB
# ...                       ...               ...               ...
# 97787        1 RB, 1 TE, 3 WR               7.0  3 DL, 3 LB, 5 DB
# 97796        1 RB, 1 TE, 3 WR               6.0  4 DL, 2 LB, 5 DB
# 97797        1 RB, 2 TE, 2 WR               9.0  5 DL, 2 LB, 4 DB
# 97798        1 RB, 2 TE, 2 WR               9.0  5 DL, 2 LB, 4 DB
# 97809        1 RB, 1 TE, 3 WR               6.0  4 DL, 2 LB, 5 DB
#
#        number_of_pass_rushers  \
# 4                         NaN
# 20                        NaN
# 32                        NaN
# 63                        NaN
# 64                        NaN
# ...                       ...
# 97787                     NaN
# 97796                     NaN
# 97797                     NaN
# 97798                     NaN
# 97809                     NaN
#
#                                          players_on_play  \
# 4      41302;38540;37977;43295;38582;40494;37109;4025...
# 20     34479;35575;40111;37249;43619;36089;43694;3567...
# 32     36060;34479;41277;40111;37249;41230;37100;4124...
# 63     39974;32252;33602;38566;37075;38672;37724;4125...
# 64     42546;32252;37075;35764;38672;42366;40038;3772...
# ...                                                  ...
# 97787  45345;55873;53477;54599;54727;41257;54026;4781...
# 97796  53601;46757;47785;52461;46157;39950;55952;3726...
# 97797  53601;46757;52422;54663;47785;53579;46157;5246...
# 97798  53601;46757;52422;54663;47785;53579;46157;5246...
# 97809  52608;53601;46757;47785;42345;47787;46157;5252...
#
#                                          offense_players  \
# 4      00-0028497;00-0032965;00-0029893;00-0026223;00...
# 20     00-0027004;00-0030046;00-0028112;00-0032499;00...
# 32     00-0027004;00-0030046;00-0028112;00-0031325;00...
# 63     00-0025446;00-0026069;00-0031359;00-0031362;00...
# 64     00-0025446;00-0032055;00-0031362;00-0029164;00...
# ...                                                  ...
# 97787  00-0036551;00-0037829;00-0037834;00-0035719;00...
# 97796  00-0036389;00-0030561;00-0028129;00-0038112;00...
# 97797  00-0037086;00-0036919;00-0036389;00-0030561;00...
# 97798  00-0037086;00-0036919;00-0036389;00-0030561;00...
# 97809  00-0036271;00-0032268;00-0036423;00-0030561;00...
#
#                                          defense_players  n_offense  n_defense
# 4      00-0031171;00-0029542;00-0029566;00-0030041;00...       11.0       11.0
# 20     00-0027736;00-0027560;00-0032574;00-0031296;00...       11.0       11.0
# 32     00-0027539;00-0031170;00-0027965;00-0031296;00...       10.0       10.0
# 63     00-0030577;00-0029586;00-0027940;00-0029620;00...       11.0       11.0
# 64     00-0032138;00-0027940;00-0027256;00-0029620;00...       11.0       11.0
# ...                                                  ...        ...        ...
# 97787  00-0033445;00-0038386;00-0031372;00-0036813;00...       11.0       11.0
# 97796  00-0036563;00-0034573;00-0035717;00-0034754;00...       11.0       11.0
# 97797  00-0036563;00-0034573;00-0036260;00-0035717;00...       11.0       11.0
# 97798  00-0036563;00-0034573;00-0036260;00-0035717;00...       11.0       11.0
# 97809  00-0036563;00-0034573;00-0035717;00-0035692;00...       11.0       11.0
#
# [5724 rows x 385 columns]

# %%
df_runs_qb.loc[df_runs_qb.rushing_yards.isnull(), "rushing_yards"] = 0

# %%
df_runs_qb_season = df_runs_qb \
    .groupby(["rusher_id", "rusher", "season"]) \
    .agg({"rushing_yards": ["sum", "count", "mean"], "epa": ["sum"],
          "rush_touchdown": ["sum"]}
    )

# %%
df_runs_qb_season.head()
# Out:
#                           rushing_yards                       epa  \
#                                     sum count      mean       sum
# rusher_id  rusher  season
# 00-0019596 T.Brady 2016            10.0     7  1.428571 -3.487682
#                    2017            14.0     8  1.750000 -7.771545
#                    2018            10.0     8  1.250000  1.753143
#                    2019            13.0     8  1.625000  4.360135
#                    2020            10.0     9  1.111111 -1.123093
#
#                           rush_touchdown
#                                      sum
# rusher_id  rusher  season
# 00-0019596 T.Brady 2016              0.0
#                    2017              0.0
#                    2018              1.0
#                    2019              3.0
#                    2020              3.0

# %%
df_runs_qb_season.columns = list(map("_".join, df_runs_qb_season.columns))
df_runs_qb_season.reset_index(inplace=True)
df_runs_qb_season.head()
# Out:
#     rusher_id   rusher  season  rushing_yards_sum  rushing_yards_count  \
# 0  00-0019596  T.Brady    2016               10.0                    7
# 1  00-0019596  T.Brady    2017               14.0                    8
# 2  00-0019596  T.Brady    2018               10.0                    8
# 3  00-0019596  T.Brady    2019               13.0                    8
# 4  00-0019596  T.Brady    2020               10.0                    9
#
#    rushing_yards_mean   epa_sum  rush_touchdown_sum
# 0            1.428571 -3.487682                 0.0
# 1            1.750000 -7.771545                 0.0
# 2            1.250000  1.753143                 1.0
# 3            1.625000  4.360135                 3.0
# 4            1.111111 -1.123093                 3.0

# %%
new_cols = ["rusher_id", "rusher", "season", "rushing_yards", "carries", "yards_per_carry", "total_epa",
            "rushing_touchdowns"]
df_runs_qb_season.columns = new_cols

# %%
df_runs_qb_season.head()
# Out:
#     rusher_id   rusher  season  rushing_yards  carries  yards_per_carry  \
# 0  00-0019596  T.Brady    2016           10.0        7         1.428571
# 1  00-0019596  T.Brady    2017           14.0        8         1.750000
# 2  00-0019596  T.Brady    2018           10.0        8         1.250000
# 3  00-0019596  T.Brady    2019           13.0        8         1.625000
# 4  00-0019596  T.Brady    2020           10.0        9         1.111111
#
#    total_epa  rushing_touchdowns
# 0  -3.487682                 0.0
# 1  -7.771545                 0.0
# 2   1.753143                 1.0
# 3   4.360135                 3.0
# 4  -1.123093                 3.0

# %%
df_now_runs = df_runs_qb_season.copy()
df_last_runs = df_runs_qb_season.copy()

# %%
df_last_runs.rename(columns= {
        'rushing_yards': 'rushing_yards_last',
        'carries': 'carries_last',
        'yards_per_carry': 'yards_per_carry_last',
        'total_epa': 'total_epa_last',
        'rushing_touchdowns': 'rushing_touchdowns_last',
    }, inplace=True)

# %%
df_last_runs["season"] += 1

# %%
df_lag_runs = df_now_runs.merge(df_last_runs, how="inner", on=["rusher_id", "rusher", "season"])

# %%
df_lag_runs.head()
# Out:
#     rusher_id   rusher  season  rushing_yards  carries  yards_per_carry  \
# 0  00-0019596  T.Brady    2017           14.0        8         1.750000
# 1  00-0019596  T.Brady    2018           10.0        8         1.250000
# 2  00-0019596  T.Brady    2019           13.0        8         1.625000
# 3  00-0019596  T.Brady    2020           10.0        9         1.111111
# 4  00-0019596  T.Brady    2021           14.0        7         2.000000
#
#    total_epa  rushing_touchdowns  rushing_yards_last  carries_last  \
# 0  -7.771545                 0.0                10.0             7
# 1   1.753143                 1.0                14.0             8
# 2   4.360135                 3.0                10.0             8
# 3  -1.123093                 3.0                13.0             8
# 4   6.495685                 2.0                10.0             9
#
#    yards_per_carry_last  total_epa_last  rushing_touchdowns_last
# 0              1.428571       -3.487682                      0.0
# 1              1.750000       -7.771545                      0.0
# 2              1.250000        1.753143                      1.0
# 3              1.625000        4.360135                      3.0
# 4              1.111111       -1.123093                      3.0

# %%
df_lag_runs_20 = df_lag_runs.query("carries > 20")

# %%
df_lag_runs_200_y = df_lag_runs.query("rushing_yards >= 200")

# %%
df_lag_runs_400_y = df_lag_runs.query("rushing_yards >= 400")

# %% [markdown]
# # Correlation for Rushing Stats

# %% [markdown]
# ## Rushing Touchdowns

# %%
df_lag_runs[["rushing_touchdowns", "rushing_touchdowns_last"]].corr()
# Out:
#                          rushing_touchdowns  rushing_touchdowns_last
# rushing_touchdowns                 1.000000                 0.536982
# rushing_touchdowns_last            0.536982                 1.000000

# %%
df_lag_runs_20[["rushing_touchdowns", "rushing_touchdowns_last"]].corr()
# Out:
#                          rushing_touchdowns  rushing_touchdowns_last
# rushing_touchdowns                 1.000000                 0.394226
# rushing_touchdowns_last            0.394226                 1.000000

# %%
df_lag_runs_200_y[["rushing_touchdowns", "rushing_touchdowns_last"]].corr()
# Out:
#                          rushing_touchdowns  rushing_touchdowns_last
# rushing_touchdowns                 1.000000                -0.088577
# rushing_touchdowns_last           -0.088577                 1.000000

# %%
df_lag_runs_400_y[["rushing_touchdowns", "rushing_touchdowns_last"]].corr()
# Out:
#                          rushing_touchdowns  rushing_touchdowns_last
# rushing_touchdowns                 1.000000                 0.104369
# rushing_touchdowns_last            0.104369                 1.000000

# %% [markdown]
# ## EPA

# %%
df_lag_runs[["total_epa", "total_epa_last"]].corr()
# Out:
#                 total_epa  total_epa_last
# total_epa        1.000000        0.215231
# total_epa_last   0.215231        1.000000

# %%
df_lag_runs_20[["total_epa", "total_epa_last"]].corr()
# Out:
#                 total_epa  total_epa_last
# total_epa        1.000000        0.098788
# total_epa_last   0.098788        1.000000

# %%
df_lag_runs_200_y[["total_epa", "total_epa_last"]].corr()
# Out:
#                 total_epa  total_epa_last
# total_epa         1.00000        -0.01465
# total_epa_last   -0.01465         1.00000

# %%
df_lag_runs_400_y[["total_epa", "total_epa_last"]].corr()
# Out:
#                 total_epa  total_epa_last
# total_epa         1.00000         0.38201
# total_epa_last    0.38201         1.00000

# %% [markdown]
# ## Yards per Carry

# %%
df_lag_runs[["yards_per_carry", "yards_per_carry_last"]].corr()
# Out:
#                       yards_per_carry  yards_per_carry_last
# yards_per_carry              1.000000              0.401991
# yards_per_carry_last         0.401991              1.000000

# %%
df_lag_runs_20[["yards_per_carry", "yards_per_carry_last"]].corr()
# Out:
#                       yards_per_carry  yards_per_carry_last
# yards_per_carry              1.000000              0.270109
# yards_per_carry_last         0.270109              1.000000

# %%
df_lag_runs_200_y[["yards_per_carry", "yards_per_carry_last"]].corr()
# Out:
#                       yards_per_carry  yards_per_carry_last
# yards_per_carry              1.000000              0.123528
# yards_per_carry_last         0.123528              1.000000

# %%
df_lag_runs_400_y[["yards_per_carry", "yards_per_carry_last"]].corr()
# Out:
#                       yards_per_carry  yards_per_carry_last
# yards_per_carry              1.000000              0.562382
# yards_per_carry_last         0.562382              1.000000

# %% [markdown]
# ## Carries

# %%
df_lag_runs[["carries", "carries_last"]].corr()
# Out:
#                carries  carries_last
# carries       1.000000      0.770436
# carries_last  0.770436      1.000000

# %%
df_lag_runs_20[["carries", "carries_last"]].corr()
# Out:
#                carries  carries_last
# carries       1.000000      0.605299
# carries_last  0.605299      1.000000

# %%
df_lag_runs_200_y[["carries", "carries_last"]].corr()
# Out:
#                carries  carries_last
# carries       1.000000      0.348746
# carries_last  0.348746      1.000000

# %%
df_lag_runs_400_y[["carries", "carries_last"]].corr()
# Out:
#                carries  carries_last
# carries       1.000000      0.292299
# carries_last  0.292299      1.000000

# %% [markdown]
# ## Rushing Yards

# %%
df_lag_runs[["rushing_yards", "rushing_yards_last"]].corr()
# Out:
#                     rushing_yards  rushing_yards_last
# rushing_yards            1.000000            0.755456
# rushing_yards_last       0.755456            1.000000

# %%
df_lag_runs_20[["rushing_yards", "rushing_yards_last"]].corr()
# Out:
#                     rushing_yards  rushing_yards_last
# rushing_yards            1.000000            0.590032
# rushing_yards_last       0.590032            1.000000

# %%
df_lag_runs_200_y[["rushing_yards", "rushing_yards_last"]].corr()
# Out:
#                     rushing_yards  rushing_yards_last
# rushing_yards            1.000000            0.388971
# rushing_yards_last       0.388971            1.000000

# %%
df_lag_runs_400_y[["rushing_yards", "rushing_yards_last"]].corr()
# Out:
#                     rushing_yards  rushing_yards_last
# rushing_yards            1.000000            0.639419
# rushing_yards_last       0.639419            1.000000
