# %%
import requests
from utils import generate_players_from_csv

# %%
data_path = "./FantasyData"

# %%
players_2022 = generate_players_from_csv(f"{data_path}/2022.csv")

# %%
players_2022.keys()
# Out:
# dict_keys(['QB', 'RB', 'WR', 'TE'])

# %%
qbs = players_2022["QB"]

# %%
qbs
# Out:
# [
#  Player Name: Patrick Mahomes*+
#  Season:
#  Position: QB
#  Age: 27
#  Games: 17
#  Games Started: 17
#  Fantasy Points: 416.0
#  Fantasy PPR: 417.4
#  Fantasy VBD: 136
#  Fantasy Position Rank: 1
#  Fantasy Overall Rank: 1,
#
#  Player Name: Josh Allen*
#  Season:
#  Position: QB
#  Age: 26
#  Games: 16
#  Games Started: 16
#  Fantasy Points: 396.0
#  Fantasy PPR: 395.5
#  Fantasy VBD: 117
#  Fantasy Position Rank: 2
#  Fantasy Overall Rank: 7,
#
#  Player Name: Jalen Hurts*
#  Season:
#  Position: QB
#  Age: 24
#  Games: 15
#  Games Started: 15
#  Fantasy Points: 378.0
#  Fantasy PPR: 378.0
#  Fantasy VBD: 100
#  Fantasy Position Rank: 3
#  Fantasy Overall Rank: 12,
#
#  Player Name: Joe Burrow*
#  Season:
#  Position: QB
#  Age: 26
#  Games: 16
#  Games Started: 16
#  Fantasy Points: 351.0
#  Fantasy PPR: 350.7
#  Fantasy VBD: 74
#  Fantasy Position Rank: 4
#  Fantasy Overall Rank: 17,
#
#  Player Name: Geno Smith*
#  Season:
#  Position: QB
#  Age: 32
#  Games: 17
# ...
